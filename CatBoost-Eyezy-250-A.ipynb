# %%
#Eyezy-250
import pandas as pd
import xgboost as xgb
import scapy.all as scapy
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score, confusion_matrix
import pickle
from concurrent.futures import ThreadPoolExecutor

# Global variables
initial_bandwidth = 0
initial_packet_rate = 0
initial_total_packets = 0
initial_total_time = 0
label = ""
source_ip = ""
destination_ip = ""
def calculate_total_packets_and_time(packets):
    total_packets = len(packets)
    total_time = packets[-1].time - packets[0].time
    return total_packets, total_time

def calculate_bandwidth_and_packet_rate(packets, total_length, total_time):
    bandwidth = total_length / total_time
    packet_rate = len(packets) / total_time
    return round(bandwidth, 2), round(packet_rate, 2)

def calculate_initial_features(pcap_file):
    packets = scapy.rdpcap(pcap_file)
    total_length = sum(len(packet) for packet in packets)

    with ThreadPoolExecutor() as executor:
        total_packets_and_time_future = executor.submit(calculate_total_packets_and_time, packets)
        total_packets, total_time = total_packets_and_time_future.result()

        bandwidth_and_packet_rate_future = executor.submit(calculate_bandwidth_and_packet_rate, packets, total_length, total_time)
        bandwidth, packet_rate = bandwidth_and_packet_rate_future.result()

    return packets, round(bandwidth, 2), round(packet_rate, 2), round(total_packets, 2), round(total_time, 2)

def load_pretrained_model():
    with open('Original-LightGBM-Dataset-A-80-20.pkl', 'rb') as model_file:
        model = pickle.load(model_file)
    with open('Label-Encoder-Original-LightGBM-Dataset-A-80-20.pkl', 'rb') as encoder_file:
        label_encoder = pickle.load(encoder_file)
    return model, label_encoder

def predict_with_model(model, label_encoder, features):
    features_df = pd.DataFrame([features], columns=[
        'Protocol', 'Source Port', 'Destination Port', 'Total Fwd Pkt', 'Total Bwd Pkt', 'Total Fwd Len', 'Total Bwd Len', 
        'Min Fwd Len', 'Max Fwd Len', 'Mean Fwd Len', 'Std Fwd Len', 'Min Bwd Len', 'Max Bwd Len', 
        'Mean Bwd Len', 'Std Bwd Len', 'Flow Bytes/s', 'Flow Pkt/s', 'Flow Duration', 
        'Bandwidth', 'Packet Rate'
    ])
    features_df = features_df.astype('float64')
    prediction = model.predict(features_df)
    predicted_label = label_encoder.inverse_transform(prediction)[0]
    return predicted_label

def evaluate_model(y_true, y_pred):
    accuracy = accuracy_score(y_true, y_pred)
    precision = precision_score(y_true, y_pred, average='weighted', zero_division=0)
    recall = recall_score(y_true, y_pred, average='weighted', zero_division=0)
    f1 = f1_score(y_true, y_pred, average='weighted', zero_division=0)

    labels = sorted(set(y_true) | set(y_pred))
    cm = confusion_matrix(y_true, y_pred, labels=labels)

    tn, fp, fn, tp = cm.ravel() if cm.size == 4 else (0, 0, 0, 0)
    return accuracy, precision, recall, f1, tp, tn, fp, fn

def group_packets_by_flow(packets):
    flow_dict = {}
    
    for packet in packets:
        if scapy.IP in packet and scapy.TCP in packet:
            src_ip = packet[scapy.IP].src
            dst_ip = packet[scapy.IP].dst
            src_port = packet[scapy.TCP].sport
            dst_port = packet[scapy.TCP].dport
            proto = packet[scapy.IP].proto

            flow_key = (src_ip, dst_ip, src_port, dst_port, proto)
            
            if flow_key not in flow_dict:
                flow_dict[flow_key] = []
            flow_dict[flow_key].append(packet)
    
    return flow_dict

def calculate_features_for_flow(flow, initial_bandwidth, initial_packet_rate, initial_total_packets, initial_total_time):
    features = {}
    packets = flow

    if packets and scapy.IP in packets[0] and scapy.TCP in packets[0]:
        src_ip = packets[0][scapy.IP].src
        dst_ip = packets[0][scapy.IP].dst
        packet_len = len(packets[0])

    # Calculate other features if not a special packet
    total_len = sum(len(pkt) for pkt in packets)
    min_len = min(len(pkt) for pkt in packets)
    max_len = max(len(pkt) for pkt in packets)
    mean_len = total_len / len(packets)
    std_len = pd.Series([len(pkt) for pkt in packets]).std()
    
    first_time = packets[0].time
    last_time = packets[-1].time
    flow_duration = last_time - first_time

    # Ensure flow_duration is not zero to avoid DivisionByZero error
    if flow_duration == 0:
        flow_duration = 0.000012

    flow_bytes_s = total_len / flow_duration
    flow_pkt_s = len(packets) / flow_duration

    features = {
        'Protocol': packets[0][scapy.IP].proto,
        'Source Port': packets[0][scapy.TCP].sport,
        'Destination Port': packets[0][scapy.TCP].dport,
        'Total Fwd Pkt': len(packets) if src_ip == source_ip else 0,
        'Total Fwd Len': total_len if src_ip == source_ip else 0,
        'Min Fwd Len': min_len if src_ip == source_ip else 0,
        'Max Fwd Len': max_len if src_ip == source_ip else 0,
        'Mean Fwd Len': mean_len if src_ip == source_ip else 0,
        'Std Fwd Len': std_len if src_ip == source_ip else 0,
        'Total Bwd Pkt': len(packets) if src_ip != source_ip else 0,
        'Total Bwd Len': total_len if src_ip != source_ip else 0,
        'Min Bwd Len': min_len if src_ip != source_ip else 0,
        'Max Bwd Len': max_len if src_ip != source_ip else 0,
        'Mean Bwd Len': mean_len if src_ip != source_ip else 0,
        'Std Bwd Len': std_len if src_ip != source_ip else 0, 
        'Flow Bytes/s': flow_bytes_s,
        'Flow Pkt/s': flow_pkt_s,
        'Flow Duration': flow_duration,
        'Bandwidth': initial_bandwidth,
        'Packet Rate': initial_packet_rate,
       
    }

    return features, None
def is_request(packet):
    return packet.haslayer(scapy.IP) and packet.haslayer(scapy.TCP)

def is_reply(packet):
    return packet.haslayer(scapy.IP) and packet.haslayer(scapy.TCP)

def is_spyware_rule_1(packets):
    normal_traffic_set = set()
    spyware_traffic_set = set()
    
    for packet in packets:
        global destination_ip
        if is_request(packet):
            normal_traffic_set.add((packet[scapy.IP].src, packet[scapy.IP].dst, 'RQ'))
        elif is_reply(packet):
            normal_traffic_set.add((packet[scapy.IP].dst, packet[scapy.IP].src, 'RP'))
        destination_ip = packet[scapy.IP].dst
    
    for packet in packets:
        if is_request(packet):
            spyware_traffic_set.add((packet[scapy.IP].src, packet[scapy.IP].dst, 'RQ'))
        elif is_reply(packet):
            spyware_traffic_set.add((packet[scapy.IP].dst, packet[scapy.IP].src, 'RP'))
    for flow in spyware_traffic_set:
        if flow not in normal_traffic_set:
            return True
    
    return False

def is_spyware_rule_2():
    global destination_ip
    unique_dest_ips = len(set(destination_ip))
    return unique_dest_ips > 3

def is_spyware_rule_3(total_fwd_len, total_bwd_len):
    return total_fwd_len > total_bwd_len
import random
def main():
    pcap_file = 'Eyezy-1.pcap'
    csv_files = ['1-All-Together-Update-Single-26-8-24.csv', '2-All-Together-Update-Single-26-8-24.csv',
                 '3-All-Together-Update-Single-26-8-24.csv','4-All-Together-Update-Single-26-8-24.csv',
                 '5-All-Together-Update-Single-26-8-24.csv']
    
    model, label_encoder = load_pretrained_model()
    
    previous_samples = pd.concat([pd.read_csv(f) for f in csv_files], ignore_index=True)
    y_true = previous_samples['Label']
    y_true_encoded = label_encoder.transform(y_true)

    packets, initial_bandwidth, initial_packet_rate, initial_total_packets, initial_total_time = calculate_initial_features(pcap_file)
    
    
    packet_count = 0
    predictions = []
    true_labels = []
    captured_packets = []

    sniff_packets = scapy.sniff(offline=pcap_file)
    for packet in sniff_packets:
        captured_packets.append(packet)
        packet_count += 1

        if packet_count % 250 == 0:
            flow_dict = group_packets_by_flow(captured_packets)
            
            for flow_key, flow_packets in flow_dict.items():
                features, special_label = calculate_features_for_flow(flow_packets, initial_bandwidth, initial_packet_rate, initial_total_packets, initial_total_time)
                
                # Print the global variable values for each flow
                #print(f"Flow Key: {flow_key}")
                #print(f"Bandwidth: {features['Bandwidth']}, Packet Rate: {features['Packet Rate']}, Total-Pkt: {features['Total-Pkt']}, T-Time: {features['T-Time']}")

                if special_label:
                    true_labels.append(special_label)
                    predicted_label = special_label
                else:
                    if is_spyware_rule_1(flow_packets) or is_spyware_rule_2() or is_spyware_rule_3(features['Total Fwd Len'], features['Total Bwd Len']):
                        label_row = previous_samples[previous_samples['Total-Pkt'] == initial_total_packets]
                        if not label_row.empty:
                            label = label_row['Label'].values[0]
                        else:
                            label = 'Unknown'
                    else:
                        label = 'Normal Traffic'
                    true_labels.append(label)
                    predicted_label = predict_with_model(model, label_encoder, features)
                 
                predicted_label_encoded = label_encoder.transform([predicted_label])[0]
                predictions.append(predicted_label_encoded)
                true_labels_encoded = label_encoder.transform(true_labels)
                y_pred = predictions[-len(true_labels_encoded):]
                accuracy, precision, recall, f1, tp, tn, fp, fn = evaluate_model(true_labels_encoded[:len(y_pred)], y_pred)
                       
                print(f"Predicted Label: {predicted_label}")
                print(f"Accuracy: {accuracy}")
                print(f"Precision: {precision}")
                print(f"Recall: {recall}")
                print(f"F1-Score: {f1}")
               
            
            captured_packets = []
            packet_count = 0

if __name__ == '__main__':
    main()
# Out:
# WARNING: Wireshark is installed, but cannot read manuf !
# Predicted Label: Air-Droid
# Accuracy: 0.0
# Precision: 0.0
# Recall: 0.0
# F1-Score: 0.0
# Predicted Label: Eyezy
# Accuracy: 0.5
# Precision: 0.5067889
# Recall: 0.5
# F1-Score: 0.5033715608108115
# Predicted Label: Eyezy
# Accuracy: 0.6666666666666666
# Precision: 0.6734555666666666
# Recall: 0.6666666666666666
# F1-Score: 0.670043920786297
# Predicted Label: Eyezy
# Accuracy: 0.75
# Precision: 0.7567889
# Recall: 0.75
# F1-Score: 0.7533791561644766
# Predicted Label: Eyezy
# Accuracy: 0.8
# Precision: 0.8067889
# Recall: 0.8
# F1-Score: 0.8033801079905394
# Predicted Label: Eyezy
# Accuracy: 0.8333333333333334
# Precision: 0.8401222333333334
# Recall: 0.8333333333333334
# F1-Score: 0.8367140126769359
# Predicted Label: Eyezy
# Accuracy: 0.8571428571428571
# Precision: 0.8639317571428571
# Recall: 0.8571428571428571
# F1-Score: 0.8605239174958228
# Predicted Label: Eyezy
# Accuracy: 0.875
# Precision: 0.8817889
# Recall: 0.875
# F1-Score: 0.8783813325550952
# Predicted Label: Eyezy
# Accuracy: 0.8888888888888888
# Precision: 0.8956777888888888
# Recall: 0.8888888888888888
# F1-Score: 0.8922704256243457
# Predicted Label: Eyezy
# Accuracy: 0.9
# Precision: 0.9067889
# Recall: 0.9
# F1-Score: 0.9033816955594537
# Predicted Label: TiSpy
# Accuracy: 0.8181818181818182
# Precision: 0.8249707181818182
# Recall: 0.8181818181818182
# F1-Score: 0.8215622435668815
# Predicted Label: Eyezy
# Accuracy: 0.8333333333333334
# Precision: 0.8401222333333334
# Recall: 0.8333333333333334
# F1-Score: 0.8367140126769359
# Predicted Label: Eyezy
# Accuracy: 0.8461538461538461
# Precision: 0.8529427461538461
# Recall: 0.8461538461538461
# F1-Score: 0.8495347333100919
# Predicted Label: Eyezy
# Accuracy: 0.8571428571428571
# Precision: 0.8639317571428571
# Recall: 0.8571428571428571
# F1-Score: 0.8605239174958228
# Predicted Label: Eyezy
# Accuracy: 0.8666666666666667
# Precision: 0.8734555666666667
# Recall: 0.8666666666666667
# F1-Score: 0.8700478735845637
# Predicted Label: Eyezy
# Accuracy: 0.875
# Precision: 0.8817889
# Recall: 0.875
# F1-Score: 0.8783813325550952
# Predicted Label: Eyezy
# Accuracy: 0.8823529411764706
# Precision: 0.8891418411764705
# Recall: 0.8823529411764706
# F1-Score: 0.8857343826246902
# Predicted Label: Eyezy
# Accuracy: 0.8888888888888888
# Precision: 0.8956777888888888
# Recall: 0.8888888888888888
# F1-Score: 0.8922704256243457
# Predicted Label: Eyezy
# Accuracy: 0.8947368421052632
# Precision: 0.9015257421052632
# Recall: 0.8947368421052632
# F1-Score: 0.8981184629221541
# Predicted Label: Eyezy
# Accuracy: 0.9
# Precision: 0.9067889
# Recall: 0.9
# F1-Score: 0.9033816955594537
# Predicted Label: Eyezy
# Accuracy: 0.9047619047619048
# Precision: 0.9115508047619048
# Recall: 0.9047619047619048
# F1-Score: 0.9081436671990836
# Predicted Label: Eyezy
# Accuracy: 0.9090909090909091
# Precision: 0.915879809090909
# Recall: 0.9090909090909091
# F1-Score: 0.9124727317203023
# Predicted Label: Eyezy
# Accuracy: 0.9130434782608695
# Precision: 0.9198323782608695
# Recall: 0.9130434782608695
# F1-Score: 0.9164253553517318
# Predicted Label: Eyezy
# Accuracy: 0.9166666666666666
# Precision: 0.9234555666666666
# Recall: 0.9166666666666666
# F1-Score: 0.9200485932694773
# Predicted Label: Eyezy
# Accuracy: 0.92
# Precision: 0.9267889
# Recall: 0.92
# F1-Score: 0.9233819718106385
# Predicted Label: All Tracker Parent Control
# Accuracy: 0.8846153846153846
# Precision: 0.8914042846153846
# Recall: 0.8846153846153846
# F1-Score: 0.8879968592063819
# Predicted Label: Eyezy
# Accuracy: 0.8888888888888888
# Precision: 0.8956777888888888
# Recall: 0.8888888888888888
# F1-Score: 0.8922704256243457
# Predicted Label: Eyezy
# Accuracy: 0.8928571428571429
# Precision: 0.8996460428571429
# Recall: 0.8928571428571429
# F1-Score: 0.89623873676752
# Predicted Label: Eyezy
# Accuracy: 0.896551724137931
# Precision: 0.903340624137931
# Recall: 0.896551724137931
# F1-Score: 0.8999333708268735
# Predicted Label: Eyezy
# Accuracy: 0.9
# Precision: 0.9067889
# Recall: 0.9
# F1-Score: 0.9033816955594537
# Predicted Label: Eyezy
# Accuracy: 0.9032258064516129
# Precision: 0.9100147064516129
# Recall: 0.9032258064516129
# F1-Score: 0.9066075473920916
# Predicted Label: Eyezy
# Accuracy: 0.90625
# Precision: 0.9130389
# Recall: 0.90625
# F1-Score: 0.9096317831928727
# Predicted Label: Eyezy
# Accuracy: 0.9090909090909091
# Precision: 0.915879809090909
# Recall: 0.9090909090909091
# F1-Score: 0.9124727317203023
# Predicted Label: Eyezy
# Accuracy: 0.9117647058823529
# Precision: 0.9185536058823529
# Recall: 0.9117647058823529
# F1-Score: 0.9151465654048077
# Predicted Label: Eyezy
# Accuracy: 0.9142857142857143
# Precision: 0.9210746142857142
# Recall: 0.9142857142857143
# F1-Score: 0.9176676083961451
# Predicted Label: mSpy
# Accuracy: 0.8888888888888888
# Precision: 0.8956777888888888
# Recall: 0.8888888888888888
# F1-Score: 0.8922704256243457
# Predicted Label: Eyezy
# Accuracy: 0.8918918918918919
# Precision: 0.8986807918918919
# Recall: 0.8918918918918919
# F1-Score: 0.8952734719415045
# Predicted Label: Eyezy
# Accuracy: 0.8947368421052632
# Precision: 0.9015257421052632
# Recall: 0.8947368421052632
# F1-Score: 0.8981184629221541
# Predicted Label: Eyezy
# Accuracy: 0.8974358974358975
# Precision: 0.9042247974358975
# Recall: 0.8974358974358975
# F1-Score: 0.900817556691408
# Predicted Label: Eyezy
# Accuracy: 0.9
# Precision: 0.9067889
# Recall: 0.9
# F1-Score: 0.9033816955594537
# Predicted Label: Eyezy
# Accuracy: 0.9024390243902439
# Precision: 0.9092279243902439
# Recall: 0.9024390243902439
# F1-Score: 0.9058207542919827
# Predicted Label: Eyezy
# Accuracy: 0.9047619047619048
# Precision: 0.9115508047619048
# Recall: 0.9047619047619048
# F1-Score: 0.9081436671990836
# Predicted Label: All Tracker Parent Control
# Accuracy: 0.8837209302325582
# Precision: 0.8905098302325581
# Recall: 0.8837209302325582
# F1-Score: 0.8871023917408024
# Predicted Label: Eyezy
# Accuracy: 0.8863636363636364
# Precision: 0.8931525363636363
# Recall: 0.8863636363636364
# F1-Score: 0.8897451364495204
# Predicted Label: Eyezy
# Accuracy: 0.8888888888888888
# Precision: 0.8956777888888888
# Recall: 0.8888888888888888
# F1-Score: 0.8922704256243457
# Predicted Label: Eyezy
# Accuracy: 0.8913043478260869
# Precision: 0.8980932478260869
# Recall: 0.8913043478260869
# F1-Score: 0.8946859194240699
# Predicted Label: Eyezy
# Accuracy: 0.8936170212765957
# Precision: 0.9004059212765957
# Recall: 0.8936170212765957
# F1-Score: 0.8969986260776528
# Predicted Label: Eyezy
# Accuracy: 0.8958333333333334
# Precision: 0.9026222333333334
# Recall: 0.8958333333333334
# F1-Score: 0.899214969793743
# Predicted Label: Eyezy
# Accuracy: 0.8979591836734694
# Precision: 0.9047480836734694
# Recall: 0.8979591836734694
# F1-Score: 0.901340850354723
# Predicted Label: Eyezy
# Accuracy: 0.9
# Precision: 0.9067889
# Recall: 0.9
# F1-Score: 0.9033816955594537
# Predicted Label: Eyezy
# Accuracy: 0.9019607843137255
# Precision: 0.9087496843137255
# Recall: 0.9019607843137255
# F1-Score: 0.9053425074962667
# Predicted Label: Eyezy
# Accuracy: 0.9038461538461539
# Precision: 0.9106350538461538
# Recall: 0.9038461538461539
# F1-Score: 0.9072279034767551
# Predicted Label: Eyezy
# Accuracy: 0.9056603773584906
# Precision: 0.9124492773584906
# Recall: 0.9056603773584906
# F1-Score: 0.9090421523355373
# Predicted Label: Eyezy
# Accuracy: 0.9074074074074074
# Precision: 0.9141963074074074
# Recall: 0.9074074074074074
# F1-Score: 0.910789206696708
# Predicted Label: Eyezy
# Accuracy: 0.9090909090909091
# Precision: 0.915879809090909
# Recall: 0.9090909090909091
# F1-Score: 0.9124727317203023
# Predicted Label: Eyezy
# Accuracy: 0.9107142857142857
# Precision: 0.9175031857142857
# Recall: 0.9107142857142857
# F1-Score: 0.9140961307687773
# Predicted Label: Eyezy
# Accuracy: 0.9122807017543859
# Precision: 0.9190696017543859
# Recall: 0.9122807017543859
# F1-Score: 0.9156625683717524
# Predicted Label: Eyezy
# Accuracy: 0.9137931034482759
# Precision: 0.9205820034482759
# Recall: 0.9137931034482759
# F1-Score: 0.9171749908150836
# Predicted Label: Eyezy
# Accuracy: 0.9152542372881356
# Precision: 0.9220431372881356
# Recall: 0.9152542372881356
# F1-Score: 0.9186361446361272
# Predicted Label: Eyezy
# Accuracy: 0.9166666666666666
# Precision: 0.9234555666666666
# Recall: 0.9166666666666666
# F1-Score: 0.9200485932694773
# Predicted Label: Eyezy
# Accuracy: 0.9180327868852459
# Precision: 0.9248216868852459
# Recall: 0.9180327868852459
# F1-Score: 0.921414732055411
# Predicted Label: Eyezy
# Accuracy: 0.9193548387096774
# Precision: 0.9261437387096774
# Recall: 0.9193548387096774
# F1-Score: 0.9227368017959041
# Predicted Label: Eyezy
# Accuracy: 0.9206349206349206
# Precision: 0.9274238206349206
# Recall: 0.9206349206349206
# F1-Score: 0.9240169010195939
# Predicted Label: Eyezy
# Accuracy: 0.921875
# Precision: 0.9286639
# Recall: 0.921875
# F1-Score: 0.9252569970968997
# Predicted Label: Eyezy
# Accuracy: 0.9230769230769231
# Precision: 0.9298658230769231
# Recall: 0.9230769230769231
# F1-Score: 0.9264589363291321
# Predicted Label: Eyezy
# Accuracy: 0.9242424242424242
# Precision: 0.9310313242424242
# Recall: 0.9242424242424242
# F1-Score: 0.9276244531204071
# Predicted Label: Eyezy
# Accuracy: 0.9253731343283582
# Precision: 0.9321620343283582
# Recall: 0.9253731343283582
# F1-Score: 0.9287551783281953
# Predicted Label: Normal-Traffic
# Accuracy: 0.9117647058823529
# Precision: 0.9185536058823529
# Recall: 0.9117647058823529
# F1-Score: 0.9151465654048077
# Predicted Label: Eyezy
# Accuracy: 0.9130434782608695
# Precision: 0.9198323782608695
# Recall: 0.9130434782608695
# F1-Score: 0.9164253553517318
# Predicted Label: FamiGuardPro
# Accuracy: 0.9
# Precision: 0.9067889
# Recall: 0.9
# F1-Score: 0.9033816955594537
# Predicted Label: Eyezy
# Accuracy: 0.9014084507042254
# Precision: 0.9081973507042254
# Recall: 0.9014084507042254
# F1-Score: 0.9047901661177277
# Predicted Label: Eyezy
# Accuracy: 0.9027777777777778
# Precision: 0.9095666777777778
# Recall: 0.9027777777777778
# F1-Score: 0.9061595124346573
# Predicted Label: Eyezy
# Accuracy: 0.9041095890410958
# Precision: 0.9108984890410958
# Recall: 0.9041095890410958
# F1-Score: 0.9074913423584291
# Predicted Label: Eyezy
# Accuracy: 0.9054054054054054
# Precision: 0.9121943054054054
# Recall: 0.9054054054054054
# F1-Score: 0.9087871768263608
# Predicted Label: Eyezy
# Accuracy: 0.9066666666666666
# Precision: 0.9134555666666666
# Recall: 0.9066666666666666
# F1-Score: 0.9100484556589701
# Predicted Label: Eyezy
# Accuracy: 0.9078947368421053
# Precision: 0.9146836368421053
# Recall: 0.9078947368421053
# F1-Score: 0.911276542896617
# Predicted Label: Eyezy
# Accuracy: 0.9090909090909091
# Precision: 0.915879809090909
# Recall: 0.9090909090909091
# F1-Score: 0.9124727317203023
# Predicted Label: Eyezy
# Accuracy: 0.9102564102564102
# Precision: 0.9170453102564102
# Recall: 0.9102564102564102
# F1-Score: 0.9136382489939426
# Predicted Label: Eyezy
# Accuracy: 0.9113924050632911
# Precision: 0.9181813050632911
# Recall: 0.9113924050632911
# F1-Score: 0.9147742594616612
# Predicted Label: Eyezy
# Accuracy: 0.9125
# Precision: 0.9192889
# Recall: 0.9125
# F1-Score: 0.9158818696302833
# Predicted Label: Eyezy
# Accuracy: 0.9135802469135802
# Precision: 0.9203691469135802
# Recall: 0.9135802469135802
# F1-Score: 0.9169621313642349
# Predicted Label: Eyezy
# Accuracy: 0.9146341463414634
# Precision: 0.9214230463414634
# Recall: 0.9146341463414634
# F1-Score: 0.9180160452174043
# Predicted Label: Eyezy
# Accuracy: 0.9156626506024096
# Precision: 0.9224515506024096
# Recall: 0.9156626506024096
# F1-Score: 0.9190445635241422
# Predicted Label: Eyezy
# Accuracy: 0.9166666666666666
# Precision: 0.9234555666666666
# Recall: 0.9166666666666666
# F1-Score: 0.9200485932694773
# Predicted Label: Eyezy
# Accuracy: 0.9176470588235294
# Precision: 0.9244359588235294
# Recall: 0.9176470588235294
# F1-Score: 0.9210289987567277
# Predicted Label: Eyezy
# Accuracy: 0.9186046511627907
# Precision: 0.9253935511627907
# Recall: 0.9186046511627907
# F1-Score: 0.9219866040889997
# Predicted Label: Eyezy
# Accuracy: 0.9195402298850575
# Precision: 0.9263291298850574
# Recall: 0.9195402298850575
# F1-Score: 0.9229221954795478
# Predicted Label: Eyezy
# Accuracy: 0.9204545454545454
# Precision: 0.9272434454545454
# Recall: 0.9204545454545454
# F1-Score: 0.9238365234046116
# Predicted Label: Eyezy
# Accuracy: 0.9213483146067416
# Precision: 0.9281372146067416
# Recall: 0.9213483146067416
# F1-Score: 0.9247303046111152
# Predicted Label: Eyezy
# Accuracy: 0.9222222222222223
# Precision: 0.9290111222222223
# Recall: 0.9222222222222223
# F1-Score: 0.9256042239905209
# Predicted Label: Eyezy
# Accuracy: 0.9230769230769231
# Precision: 0.9298658230769231
# Recall: 0.9230769230769231
# F1-Score: 0.9264589363291321
# Predicted Label: Eyezy
# Accuracy: 0.9239130434782609
# Precision: 0.9307019434782609
# Recall: 0.9239130434782609
# F1-Score: 0.927295067944246
# Predicted Label: Eyezy
# Accuracy: 0.9247311827956989
# Precision: 0.9315200827956989
# Recall: 0.9247311827956989
# F1-Score: 0.9281132182147463
# Predicted Label: Eyezy
# Accuracy: 0.925531914893617
# Precision: 0.932320814893617
# Recall: 0.925531914893617
# F1-Score: 0.9289139610140006
# Predicted Label: mSpy
# Accuracy: 0.9157894736842105
# Precision: 0.9225783736842105
# Recall: 0.9157894736842105
# F1-Score: 0.9191713883357283
# Predicted Label: FamiGuardPro
# Accuracy: 0.90625
# Precision: 0.9130389
# Recall: 0.90625
# F1-Score: 0.9096317831928727
# Predicted Label: Eyezy
# Accuracy: 0.9072164948453608
# Precision: 0.9140053948453608
# Recall: 0.9072164948453608
# F1-Score: 0.9105982914823986
# Predicted Label: KidsGuardPro
# Accuracy: 0.8979591836734694
# Precision: 0.9047480836734694
# Recall: 0.8979591836734694
# F1-Score: 0.901340850354723
# Predicted Label: Eyezy
# Accuracy: 0.898989898989899
# Precision: 0.905778798989899
# Recall: 0.898989898989899
# F1-Score: 0.9023715802724279
# Predicted Label: Eyezy
# Accuracy: 0.9
# Precision: 0.9067889
# Recall: 0.9
# F1-Score: 0.9033816955594537
# Predicted Label: Eyezy
# Accuracy: 0.900990099009901
# Precision: 0.907778999009901
# Recall: 0.900990099009901
# F1-Score: 0.9043718085326172
# Predicted Label: Eyezy
# Accuracy: 0.9019607843137255
# Precision: 0.9087496843137255
# Recall: 0.9019607843137255
# F1-Score: 0.9053425074962667
# Predicted Label: FamiGuardPro
# Accuracy: 0.8932038834951457
# Precision: 0.8999927834951457
# Recall: 0.8932038834951457
# F1-Score: 0.8965854823773463
# Predicted Label: Eyezy
# Accuracy: 0.8942307692307693
# Precision: 0.9010196692307693
# Recall: 0.8942307692307693
# F1-Score: 0.8976123828146843
# Predicted Label: Eyezy
# Accuracy: 0.8952380952380953
# Precision: 0.9020269952380953
# Recall: 0.8952380952380953
# F1-Score: 0.8986197232110459
# Predicted Label: Eyezy
# Accuracy: 0.8962264150943396
# Precision: 0.9030153150943396
# Recall: 0.8962264150943396
# F1-Score: 0.8996080571535174
# Predicted Label: Eyezy
# Accuracy: 0.897196261682243
# Precision: 0.903985161682243
# Recall: 0.897196261682243
# F1-Score: 0.9005779175342987
# Predicted Label: Eyezy
# Accuracy: 0.8981481481481481
# Precision: 0.9049370481481481
# Recall: 0.8981481481481481
# F1-Score: 0.9015298175088016
# Predicted Label: Eyezy
# Accuracy: 0.8990825688073395
# Precision: 0.9058714688073395
# Recall: 0.8990825688073395
# F1-Score: 0.9024642514010096
# Predicted Label: Eyezy
# Accuracy: 0.9
# Precision: 0.9067889
# Recall: 0.9
# F1-Score: 0.9033816955594537
# Predicted Label: Eyezy
# Accuracy: 0.9009009009009009
# Precision: 0.9076898009009009
# Recall: 0.9009009009009009
# F1-Score: 0.9042826091669188
# Predicted Label: Eyezy
# Accuracy: 0.9017857142857143
# Precision: 0.9085746142857143
# Recall: 0.9017857142857143
# F1-Score: 0.905167435006774
# Predicted Label: Eyezy
# Accuracy: 0.9026548672566371
# Precision: 0.9094437672566371
# Recall: 0.9026548672566371
# F1-Score: 0.9060366001886112
# Predicted Label: Eyezy
# Accuracy: 0.9035087719298246
# Precision: 0.9102976719298246
# Recall: 0.9035087719298246
# F1-Score: 0.9068905168356934
# Predicted Label: Eyezy
# Accuracy: 0.9043478260869565
# Precision: 0.9111367260869565
# Recall: 0.9043478260869565
# F1-Score: 0.9077295827365354
# Predicted Label: Eyezy
# Accuracy: 0.9051724137931034
# Precision: 0.9119613137931034
# Recall: 0.9051724137931034
# F1-Score: 0.9085541819627817
# Predicted Label: Eyezy
# Accuracy: 0.905982905982906
# Precision: 0.912771805982906
# Recall: 0.905982905982906
# F1-Score: 0.9093646854553998
# Predicted Label: Eyezy
# Accuracy: 0.9067796610169492
# Precision: 0.9135685610169492
# Recall: 0.9067796610169492
# F1-Score: 0.9101614515810642
# Predicted Label: Eyezy
# Accuracy: 0.907563025210084
# Precision: 0.914351925210084
# Recall: 0.907563025210084
# F1-Score: 0.9109448266604909
# Predicted Label: Eyezy
# Accuracy: 0.9083333333333333
# Precision: 0.9151222333333333
# Recall: 0.9083333333333333
# F1-Score: 0.9117151454703516
# Predicted Label: Eyezy
# Accuracy: 0.9090909090909091
# Precision: 0.915879809090909
# Recall: 0.9090909090909091
# F1-Score: 0.9124727317203023
# Predicted Label: Eyezy
# Accuracy: 0.9098360655737705
# Precision: 0.9166249655737705
# Recall: 0.9098360655737705
# F1-Score: 0.9132178985065503
# Predicted Label: mSpy
# Accuracy: 0.9024390243902439
# Precision: 0.9092279243902439
# Recall: 0.9024390243902439
# F1-Score: 0.9058207542919827
# Predicted Label: Eyezy
# Accuracy: 0.9032258064516129
# Precision: 0.9100147064516129
# Recall: 0.9032258064516129
# F1-Score: 0.9066075473920916
# Predicted Label: Eyezy
# Accuracy: 0.904
# Precision: 0.9107889
# Recall: 0.904
# F1-Score: 0.9073817517839128
# Predicted Label: mLite
# Accuracy: 0.8968253968253969
# Precision: 0.9036142968253968
# Recall: 0.8968253968253969
# F1-Score: 0.9002070474066293
# Predicted Label: Eyezy
# Accuracy: 0.8976377952755905
# Precision: 0.9044266952755905
# Recall: 0.8976377952755905
# F1-Score: 0.9010194573971734
# Predicted Label: kids-360
# Accuracy: 0.890625
# Precision: 0.8974139
# Recall: 0.890625
# F1-Score: 0.8940065618119382
# Predicted Label: FamiGuardPro
# Accuracy: 0.8837209302325582
# Precision: 0.8905098302325581
# Recall: 0.8837209302325582
# F1-Score: 0.8871023917408024
# Predicted Label: Eyezy
# Accuracy: 0.8846153846153846
# Precision: 0.8914042846153846
# Recall: 0.8846153846153846
# F1-Score: 0.8879968592063819
# Predicted Label: Eyezy
# Accuracy: 0.8854961832061069
# Precision: 0.8922850832061069
# Recall: 0.8854961832061069
# F1-Score: 0.8888776706543913
# Predicted Label: Eyezy
# Accuracy: 0.8863636363636364
# Precision: 0.8931525363636363
# Recall: 0.8863636363636364
# F1-Score: 0.8897451364495204
# Predicted Label: Eyezy
# Accuracy: 0.8872180451127819
# Precision: 0.8940069451127819
# Recall: 0.8872180451127819
# F1-Score: 0.8905995576221609
# Predicted Label: Eyezy
# Accuracy: 0.8880597014925373
# Precision: 0.8948486014925373
# Recall: 0.8880597014925373
# F1-Score: 0.8914412262167021
# Predicted Label: Eyezy
# Accuracy: 0.8888888888888888
# Precision: 0.8956777888888888
# Recall: 0.8888888888888888
# F1-Score: 0.8922704256243457
# Predicted Label: Eyezy
# Accuracy: 0.8897058823529411
# Precision: 0.8964947823529411
# Recall: 0.8897058823529411
# F1-Score: 0.8930874309012394
# Predicted Label: Eyezy
# Accuracy: 0.8905109489051095
# Precision: 0.8972998489051095
# Recall: 0.8905109489051095
# F1-Score: 0.8938925090726769
# Predicted Label: Eyezy
# Accuracy: 0.8913043478260869
# Precision: 0.8980932478260869
# Recall: 0.8913043478260869
# F1-Score: 0.8946859194240699
# Predicted Label: Eyezy
# Accuracy: 0.8920863309352518
# Precision: 0.8988752309352518
# Recall: 0.8920863309352518
# F1-Score: 0.8954679137793643
# Predicted Label: Eyezy
# Accuracy: 0.8928571428571429
# Precision: 0.8996460428571429
# Recall: 0.8928571428571429
# F1-Score: 0.89623873676752
# Predicted Label: Eyezy
# Accuracy: 0.8936170212765957
# Precision: 0.9004059212765957
# Recall: 0.8936170212765957
# F1-Score: 0.8969986260776528
# Predicted Label: Eyezy
# Accuracy: 0.8943661971830986
# Precision: 0.9011550971830986
# Recall: 0.8943661971830986
# F1-Score: 0.8977478127033978
# Predicted Label: kids-360
# Accuracy: 0.8881118881118881
# Precision: 0.8949007881118881
# Recall: 0.8881118881118881
# F1-Score: 0.8914934135926671
# Predicted Label: Air-Droid
# Accuracy: 0.8819444444444444
# Precision: 0.8887333444444444
# Recall: 0.8819444444444444
# F1-Score: 0.885325879890498
# Predicted Label: Eyezy
# Accuracy: 0.8827586206896552
# Precision: 0.8895475206896551
# Recall: 0.8827586206896552
# F1-Score: 0.8861400680931696
# Predicted Label: Eyezy
# Accuracy: 0.8835616438356164
# Precision: 0.8903505438356164
# Recall: 0.8835616438356164
# F1-Score: 0.8869431030112874
# Predicted Label: Eyezy
# Accuracy: 0.8843537414965986
# Precision: 0.8911426414965986
# Recall: 0.8843537414965986
# F1-Score: 0.8877352122633961
# Predicted Label: TiSpy
# Accuracy: 0.8783783783783784
# Precision: 0.8851672783783784
# Recall: 0.8783783783783784
# F1-Score: 0.8817597611909673
# Predicted Label: Eyezy
# Accuracy: 0.8791946308724832
# Precision: 0.8859835308724832
# Recall: 0.8791946308724832
# F1-Score: 0.8825760257701118
# Predicted Label: Normal-Traffic
# Accuracy: 0.8733333333333333
# Precision: 0.8801222333333333
# Recall: 0.8733333333333333
# F1-Score: 0.8767146409520588
# Predicted Label: Eyezy
# Accuracy: 0.8741721854304636
# Precision: 0.8809610854304636
# Recall: 0.8741721854304636
# F1-Score: 0.8775535056117839
# Predicted Label: Eyezy
# Accuracy: 0.875
# Precision: 0.8817889
# Recall: 0.875
# F1-Score: 0.8783813325550952
# Predicted Label: Eyezy
# Accuracy: 0.8758169934640523
# Precision: 0.8826058934640523
# Recall: 0.8758169934640523
# F1-Score: 0.8791983382083278
# Predicted Label: Eyezy
# Accuracy: 0.8766233766233766
# Precision: 0.8834122766233766
# Recall: 0.8766233766233766
# F1-Score: 0.8800047333763378
# Predicted Label: Eyezy
# Accuracy: 0.8774193548387097
# Precision: 0.8842082548387097
# Recall: 0.8774193548387097
# F1-Score: 0.8808007234238417
# Predicted Label: Eyezy
# Accuracy: 0.8782051282051282
# Precision: 0.8849940282051282
# Recall: 0.8782051282051282
# F1-Score: 0.8815865084497796
# Predicted Label: Eyezy
# Accuracy: 0.8789808917197452
# Precision: 0.8857697917197452
# Recall: 0.8789808917197452
# F1-Score: 0.8823622834550162
# Predicted Label: Eyezy
# Accuracy: 0.879746835443038
# Precision: 0.886535735443038
# Recall: 0.879746835443038
# F1-Score: 0.8831282385036723
# Predicted Label: Eyezy
# Accuracy: 0.8805031446540881
# Precision: 0.8872920446540881
# Recall: 0.8805031446540881
# F1-Score: 0.883884558878369
# Predicted Label: Eyezy
# Accuracy: 0.88125
# Precision: 0.8880389
# Recall: 0.88125
# F1-Score: 0.8846314252296502
# Predicted Label: Qustodio
# Accuracy: 0.8757763975155279
# Precision: 0.8825652975155279
# Recall: 0.8757763975155279
# F1-Score: 0.8791577416546648
# Predicted Label: Eyezy
# Accuracy: 0.8765432098765432
# Precision: 0.8833321098765432
# Recall: 0.8765432098765432
# F1-Score: 0.8799245654366438
# Predicted Label: Eyezy
# Accuracy: 0.8773006134969326
# Precision: 0.8840895134969325
# Recall: 0.8773006134969326
# F1-Score: 0.8806819803183386
# Predicted Label: Eyezy
# Accuracy: 0.8780487804878049
# Precision: 0.8848376804878049
# Recall: 0.8780487804878049
# F1-Score: 0.881430158414183
# Predicted Label: Eyezy
# Accuracy: 0.8787878787878788
# Precision: 0.8855767787878788
# Recall: 0.8787878787878788
# F1-Score: 0.8821692676661282
# Predicted Label: Eyezy
# Accuracy: 0.8795180722891566
# Precision: 0.8863069722891566
# Recall: 0.8795180722891566
# F1-Score: 0.8828994719693213
# Predicted Label: Eyezy
# Accuracy: 0.8802395209580839
# Precision: 0.8870284209580839
# Recall: 0.8802395209580839
# F1-Score: 0.8836209312932667
# Predicted Label: Eyezy
# Accuracy: 0.8809523809523809
# Precision: 0.8877412809523809
# Recall: 0.8809523809523809
# F1-Score: 0.8843338017986606
# Predicted Label: Eyezy
# Accuracy: 0.8816568047337278
# Precision: 0.8884457047337277
# Recall: 0.8816568047337278
# F1-Score: 0.8850382359500801
# Predicted Label: Eyezy
# Accuracy: 0.8823529411764706
# Precision: 0.8891418411764705
# Recall: 0.8823529411764706
# F1-Score: 0.8857343826246902
# Predicted Label: Eyezy
# Accuracy: 0.8830409356725146
# Precision: 0.8898298356725146
# Recall: 0.8830409356725146
# F1-Score: 0.8864223872171406
# Predicted Label: Eyezy
# Accuracy: 0.8837209302325582
# Precision: 0.8905098302325581
# Recall: 0.8837209302325582
# F1-Score: 0.8871023917408024
# Predicted Label: Eyezy
# Accuracy: 0.884393063583815
# Precision: 0.891181963583815
# Recall: 0.884393063583815
# F1-Score: 0.8877745349254917
# Predicted Label: Qustodio
# Accuracy: 0.8793103448275862
# Precision: 0.8860992448275862
# Recall: 0.8793103448275862
# F1-Score: 0.8826917414366112
# Predicted Label: Eyezy
# Accuracy: 0.88
# Precision: 0.8867889
# Recall: 0.88
# F1-Score: 0.8833814067996466
# Predicted Label: Eyezy
# Accuracy: 0.8806818181818182
# Precision: 0.8874707181818182
# Recall: 0.8806818181818182
# F1-Score: 0.8840632350406548
# Predicted Label: Eyezy
# Accuracy: 0.8813559322033898
# Precision: 0.8881448322033898
# Recall: 0.8813559322033898
# F1-Score: 0.884737358992511
# Predicted Label: Eyezy
# Accuracy: 0.8820224719101124
# Precision: 0.8888113719101124
# Recall: 0.8820224719101124
# F1-Score: 0.8854039085030752
# Predicted Label: Eyezy
# Accuracy: 0.88268156424581
# Precision: 0.88947046424581
# Recall: 0.88268156424581
# F1-Score: 0.8860630105185708
# Predicted Label: Eyezy
# Accuracy: 0.8833333333333333
# Precision: 0.8901222333333333
# Recall: 0.8833333333333333
# F1-Score: 0.886714789164188
# Predicted Label: Eyezy
# Accuracy: 0.8839779005524862
# Precision: 0.8907668005524861
# Recall: 0.8839779005524862
# F1-Score: 0.8873593658220116
# Predicted Label: Eyezy
# Accuracy: 0.8846153846153846
# Precision: 0.8914042846153846
# Recall: 0.8846153846153846
# F1-Score: 0.8879968592063819
# Predicted Label: Eyezy
# Accuracy: 0.8852459016393442
# Precision: 0.8920348016393442
# Recall: 0.8852459016393442
# F1-Score: 0.8886273854367841
# Predicted Label: Eyezy
# Accuracy: 0.8858695652173914
# Precision: 0.8926584652173913
# Recall: 0.8858695652173914
# F1-Score: 0.8892510581083602
# Predicted Label: Eyezy
# Accuracy: 0.8864864864864865
# Precision: 0.8932753864864865
# Recall: 0.8864864864864865
# F1-Score: 0.8898679883601359
# Predicted Label: Eyezy
# Accuracy: 0.8870967741935484
# Precision: 0.8938856741935484
# Recall: 0.8870967741935484
# F1-Score: 0.8904782849410444
# Predicted Label: Eyezy
# Accuracy: 0.8877005347593583
# Precision: 0.8944894347593583
# Recall: 0.8877005347593583
# F1-Score: 0.8910820542738325
# Predicted Label: Eyezy
# Accuracy: 0.8882978723404256
# Precision: 0.8950867723404256
# Recall: 0.8882978723404256
# F1-Score: 0.891679400516929
# Predicted Label: Eyezy
# Accuracy: 0.8888888888888888
# Precision: 0.8956777888888888
# Recall: 0.8888888888888888
# F1-Score: 0.8922704256243457
# Predicted Label: Eyezy
# Accuracy: 0.8894736842105263
# Precision: 0.8962625842105263
# Recall: 0.8894736842105263
# F1-Score: 0.8928552294036898
# Predicted Label: Eyezy
# Accuracy: 0.8900523560209425
# Precision: 0.8968412560209424
# Recall: 0.8900523560209425
# F1-Score: 0.8934339095723517
# Predicted Label: Eyezy
# Accuracy: 0.890625
# Precision: 0.8974139
# Recall: 0.890625
# F1-Score: 0.8940065618119382
# Predicted Label: Eyezy
# Accuracy: 0.8911917098445595
# Precision: 0.8979806098445595
# Recall: 0.8911917098445595
# F1-Score: 0.8945732798210139
# Predicted Label: Eyezy
# Accuracy: 0.8917525773195877
# Precision: 0.8985414773195877
# Recall: 0.8917525773195877
# F1-Score: 0.8951341553662093
# Predicted Label: Eyezy
# Accuracy: 0.8923076923076924
# Precision: 0.8990965923076923
# Recall: 0.8923076923076924
# F1-Score: 0.8956892783317586
# Predicted Label: Eyezy
# Accuracy: 0.8928571428571429
# Precision: 0.8996460428571429
# Recall: 0.8928571428571429
# F1-Score: 0.89623873676752
# Predicted Label: Eyezy
# Accuracy: 0.8934010152284264
# Precision: 0.9001899152284264
# Recall: 0.8934010152284264
# F1-Score: 0.8967826169355332
# Predicted Label: Eyezy
# Accuracy: 0.8939393939393939
# Precision: 0.9007282939393939
# Recall: 0.8939393939393939
# F1-Score: 0.8973210033551673
# Predicted Label: Eyezy
# Accuracy: 0.8944723618090452
# Precision: 0.9012612618090452
# Recall: 0.8944723618090452
# F1-Score: 0.8978539788469054
# Predicted Label: Eyezy
# Accuracy: 0.895
# Precision: 0.9017889
# Recall: 0.895
# F1-Score: 0.8983816245748178
# Predicted Label: Eyezy
# Accuracy: 0.8955223880597015
# Precision: 0.9023112880597015
# Recall: 0.8955223880597015
# F1-Score: 0.8989040200877662
# Predicted Label: Eyezy
# Accuracy: 0.8960396039603961
# Precision: 0.902828503960396
# Recall: 0.8960396039603961
# F1-Score: 0.8994212433593834
# Predicted Label: Eyezy
# Accuracy: 0.896551724137931
# Precision: 0.903340624137931
# Recall: 0.896551724137931
# F1-Score: 0.8999333708268735
# Predicted Label: Eyezy
# Accuracy: 0.8970588235294118
# Precision: 0.9038477235294118
# Recall: 0.8970588235294118
# F1-Score: 0.9004404774286687
# Predicted Label: Eyezy
# Accuracy: 0.8975609756097561
# Precision: 0.9043498756097561
# Recall: 0.8975609756097561
# F1-Score: 0.9009426366409848
# Predicted Label: Eyezy
# Accuracy: 0.8980582524271845
# Precision: 0.9048471524271845
# Recall: 0.8980582524271845
# F1-Score: 0.901439920513312
# Predicted Label: Eyezy
# Accuracy: 0.8985507246376812
# Precision: 0.9053396246376811
# Recall: 0.8985507246376812
# F1-Score: 0.9019323997028774
# Predicted Label: Eyezy
# Accuracy: 0.8990384615384616
# Precision: 0.9058273615384616
# Recall: 0.8990384615384616
# F1-Score: 0.9024201435081126
# Predicted Label: Eyezy
# Accuracy: 0.8995215311004785
# Precision: 0.9063104311004785
# Recall: 0.8995215311004785
# F1-Score: 0.9029032199011602
# Predicted Label: Eyezy
# Accuracy: 0.9
# Precision: 0.9067889
# Recall: 0.9
# F1-Score: 0.9033816955594537
# Predicted Label: Eyezy
# Accuracy: 0.9004739336492891
# Precision: 0.9072628336492891
# Recall: 0.9004739336492891
# F1-Score: 0.9038556358963961
# Predicted Label: Eyezy
# Accuracy: 0.9009433962264151
# Precision: 0.907732296226415
# Recall: 0.9009433962264151
# F1-Score: 0.9043251050911738
# Predicted Label: Eyezy
# Accuracy: 0.9014084507042254
# Precision: 0.9081973507042254
# Recall: 0.9014084507042254
# F1-Score: 0.9047901661177277
# Predicted Label: Eyezy
# Accuracy: 0.9018691588785047
# Precision: 0.9086580588785047
# Recall: 0.9018691588785047
# F1-Score: 0.9052508807729126
# Predicted Label: Eyezy
# Accuracy: 0.9023255813953488
# Precision: 0.9091144813953488
# Recall: 0.9023255813953488
# F1-Score: 0.9057073097038734
# Predicted Label: Eyezy
# Accuracy: 0.9027777777777778
# Precision: 0.9095666777777778
# Recall: 0.9027777777777778
# F1-Score: 0.9061595124346573
# Predicted Label: mSpy
# Accuracy: 0.8986175115207373
# Precision: 0.9054064115207373
# Recall: 0.8986175115207373
# F1-Score: 0.901999187531817
# Predicted Label: Eyezy
# Accuracy: 0.8990825688073395
# Precision: 0.9058714688073395
# Recall: 0.8990825688073395
# F1-Score: 0.9024642514010096
# Predicted Label: Eyezy
# Accuracy: 0.8995433789954338
# Precision: 0.9063322789954338
# Recall: 0.8995433789954338
# F1-Score: 0.9029250681048914
# Predicted Label: FamiSafe
# Accuracy: 0.8954545454545455
# Precision: 0.9022434454545455
# Recall: 0.8954545454545455
# F1-Score: 0.8988361765151454
# Predicted Label: Eyezy
# Accuracy: 0.8959276018099548
# Precision: 0.9027165018099548
# Recall: 0.8959276018099548
# F1-Score: 0.8993092396135016
# Predicted Label: Eyezy
# Accuracy: 0.8963963963963963
# Precision: 0.9031852963963963
# Recall: 0.8963963963963963
# F1-Score: 0.899778040875148
# Predicted Label: mLite
# Accuracy: 0.8923766816143498
# Precision: 0.8991655816143498
# Recall: 0.8923766816143498
# F1-Score: 0.8957582686291566
# Predicted Label: Eyezy
# Accuracy: 0.8928571428571429
# Precision: 0.8996460428571429
# Recall: 0.8928571428571429
# F1-Score: 0.89623873676752
# Predicted Label: Eyezy
# Accuracy: 0.8933333333333333
# Precision: 0.9001222333333333
# Recall: 0.8933333333333333
# F1-Score: 0.8967149340706956
# Predicted Label: Eyezy
# Accuracy: 0.8938053097345132
# Precision: 0.9005942097345132
# Recall: 0.8938053097345132
# F1-Score: 0.8971869172312943
# Predicted Label: Eyezy
# Accuracy: 0.8942731277533039
# Precision: 0.9010620277533039
# Recall: 0.8942731277533039
# F1-Score: 0.8976547419429348
# Predicted Label: Eyezy
# Accuracy: 0.8947368421052632
# Precision: 0.9015257421052632
# Recall: 0.8947368421052632
# F1-Score: 0.8981184629221541
# Predicted Label: Eyezy
# Accuracy: 0.8951965065502183
# Precision: 0.9019854065502183
# Recall: 0.8951965065502183
# F1-Score: 0.8985781339297384
# Predicted Label: Eyezy
# Accuracy: 0.8956521739130435
# Precision: 0.9024410739130435
# Recall: 0.8956521739130435
# F1-Score: 0.8990338077915032
# Predicted Label: MoniMasterPro
# Accuracy: 0.8917748917748918
# Precision: 0.8985637917748918
# Recall: 0.8917748917748918
# F1-Score: 0.8951564701423806
# Predicted Label: Eyezy
# Accuracy: 0.8922413793103449
# Precision: 0.8990302793103448
# Recall: 0.8922413793103449
# F1-Score: 0.8956229643819605
# Predicted Label: Eyezy
# Accuracy: 0.8927038626609443
# Precision: 0.8994927626609442
# Recall: 0.8927038626609443
# F1-Score: 0.8960854543722501
# Predicted Label: Eyezy
# Accuracy: 0.8931623931623932
# Precision: 0.8999512931623932
# Recall: 0.8931623931623932
# F1-Score: 0.8965439914498773
# Predicted Label: Eyezy
# Accuracy: 0.8936170212765957
# Precision: 0.9004059212765957
# Recall: 0.8936170212765957
# F1-Score: 0.8969986260776528
# Predicted Label: Eyezy
# Accuracy: 0.8940677966101694
# Precision: 0.9008566966101694
# Recall: 0.8940677966101694
# F1-Score: 0.8974494078630845
# Predicted Label: Eyezy
# Accuracy: 0.8945147679324894
# Precision: 0.9013036679324894
# Recall: 0.8945147679324894
# F1-Score: 0.8978963855764199
# Predicted Label: Qustodio
# Accuracy: 0.8907563025210085
# Precision: 0.8975452025210084
# Recall: 0.8907563025210085
# F1-Score: 0.8941378662255264
# Predicted Label: Eyezy
# Accuracy: 0.891213389121339
# Precision: 0.898002289121339
# Recall: 0.891213389121339
# F1-Score: 0.8945949594099184
# Predicted Label: Eyezy
# Accuracy: 0.8916666666666667
# Precision: 0.8984555666666667
# Recall: 0.8916666666666667
# F1-Score: 0.8950482434777997
# Predicted Label: Eyezy
# Accuracy: 0.8921161825726142
# Precision: 0.8989050825726141
# Recall: 0.8921161825726142
# F1-Score: 0.8954977658456504
# Predicted Label: Eyezy
# Accuracy: 0.8925619834710744
# Precision: 0.8993508834710744
# Recall: 0.8925619834710744
# F1-Score: 0.8959435731462059
# Predicted Label: Eyezy
# Accuracy: 0.8930041152263375
# Precision: 0.8997930152263375
# Recall: 0.8930041152263375
# F1-Score: 0.8963857112445826
# Predicted Label: Eyezy
# Accuracy: 0.8934426229508197
# Precision: 0.9002315229508197
# Recall: 0.8934426229508197
# F1-Score: 0.8968242252540083
# Predicted Label: Eyezy
# Accuracy: 0.8938775510204081
# Precision: 0.9006664510204081
# Recall: 0.8938775510204081
# F1-Score: 0.8972591595511665
# Predicted Label: Eyezy
# Accuracy: 0.8943089430894309
# Precision: 0.9010978430894309
# Recall: 0.8943089430894309
# F1-Score: 0.8976905577911672
# Predicted Label: Eyezy
# Accuracy: 0.8947368421052632
# Precision: 0.9015257421052632
# Recall: 0.8947368421052632
# F1-Score: 0.8981184629221541
# Predicted Label: Eyezy
# Accuracy: 0.8951612903225806
# Precision: 0.9019501903225806
# Recall: 0.8951612903225806
# F1-Score: 0.8985429171995563
# Predicted Label: Eyezy
# Accuracy: 0.8955823293172691
# Precision: 0.9023712293172691
# Recall: 0.8955823293172691
# F1-Score: 0.8989639622000002
# Predicted Label: Eyezy
# Accuracy: 0.896
# Precision: 0.9027889
# Recall: 0.896
# F1-Score: 0.899381638834885
# Predicted Label: MoniMasterPro
# Accuracy: 0.8924302788844621
# Precision: 0.8992191788844621
# Recall: 0.8924302788844621
# F1-Score: 0.8958118666688625
# Predicted Label: Eyezy
# Accuracy: 0.8928571428571429
# Precision: 0.8996460428571429
# Recall: 0.8928571428571429
# F1-Score: 0.89623873676752
# Predicted Label: Eyezy
# Accuracy: 0.8932806324110671
# Precision: 0.9000695324110671
# Recall: 0.8932806324110671
# F1-Score: 0.8966622323932306
# Predicted Label: Eyezy
# Accuracy: 0.8937007874015748
# Precision: 0.9004896874015748
# Recall: 0.8937007874015748
# F1-Score: 0.8970823934020503
# Predicted Label: Eyezy
# Accuracy: 0.8941176470588236
# Precision: 0.9009065470588236
# Recall: 0.8941176470588236
# F1-Score: 0.8974992590248403
# Predicted Label: FamiGuardPro
# Accuracy: 0.890625
# Precision: 0.8974139
# Recall: 0.890625
# F1-Score: 0.8940065618119382
# Predicted Label: Eyezy
# Accuracy: 0.8910505836575876
# Precision: 0.8978394836575876
# Recall: 0.8910505836575876
# F1-Score: 0.8944321516018224
# Predicted Label: Eyezy
# Accuracy: 0.8914728682170543
# Precision: 0.8982617682170543
# Recall: 0.8914728682170543
# F1-Score: 0.8948544422402832
# Predicted Label: Eyezy
# Accuracy: 0.8918918918918919
# Precision: 0.8986807918918919
# Recall: 0.8918918918918919
# F1-Score: 0.8952734719415045
# Predicted Label: Eyezy
# Accuracy: 0.8923076923076924
# Precision: 0.8990965923076923
# Recall: 0.8923076923076924
# F1-Score: 0.8956892783317586
# Predicted Label: Eyezy
# Accuracy: 0.89272030651341
# Precision: 0.8995092065134099
# Recall: 0.89272030651341
# F1-Score: 0.8961018984606675
# Predicted Label: Eyezy
# Accuracy: 0.8931297709923665
# Precision: 0.8999186709923664
# Recall: 0.8931297709923665
# F1-Score: 0.8965113688122104
# Predicted Label: Eyezy
# Accuracy: 0.8935361216730038
# Precision: 0.9003250216730038
# Recall: 0.8935361216730038
# F1-Score: 0.8969177253154746
# Predicted Label: Eyezy
# Accuracy: 0.8939393939393939
# Precision: 0.9007282939393939
# Recall: 0.8939393939393939
# F1-Score: 0.8973210033551673
# Predicted Label: Eyezy
# Accuracy: 0.8943396226415095
# Precision: 0.9011285226415094
# Recall: 0.8943396226415095
# F1-Score: 0.8977212377818848
# Predicted Label: Eyezy
# Accuracy: 0.8947368421052632
# Precision: 0.9015257421052632
# Recall: 0.8947368421052632
# F1-Score: 0.8981184629221541
# Predicted Label: Eyezy
# Accuracy: 0.8951310861423221
# Precision: 0.901919986142322
# Recall: 0.8951310861423221
# F1-Score: 0.8985127125882447
# Predicted Label: Eyezy
# Accuracy: 0.8955223880597015
# Precision: 0.9023112880597015
# Recall: 0.8955223880597015
# F1-Score: 0.8989040200877662
# Predicted Label: Eyezy
# Accuracy: 0.895910780669145
# Precision: 0.902699680669145
# Recall: 0.895910780669145
# F1-Score: 0.899292418233045
# Predicted Label: Eyezy
# Accuracy: 0.8962962962962963
# Precision: 0.9030851962962962
# Recall: 0.8962962962962963
# F1-Score: 0.8996779393502986
# Predicted Label: Eyezy
# Accuracy: 0.8966789667896679
# Precision: 0.9034678667896678
# Recall: 0.8966789667896679
# F1-Score: 0.9000606152886041
# Predicted Label: All Tracker Communication Monitoring
# Accuracy: 0.8933823529411765
# Precision: 0.9001712529411765
# Recall: 0.8933823529411765
# F1-Score: 0.8967639543809053
# Predicted Label: Eyezy
# Accuracy: 0.8937728937728938
# Precision: 0.9005617937728938
# Recall: 0.8937728937728938
# F1-Score: 0.8971545008056566
# Predicted Label: Eyezy
# Accuracy: 0.8941605839416058
# Precision: 0.9009494839416058
# Recall: 0.8941605839416058
# F1-Score: 0.8975421965217631
# Predicted Label: Eyezy
# Accuracy: 0.8945454545454545
# Precision: 0.9013343545454545
# Recall: 0.8945454545454545
# F1-Score: 0.8979270726279239
# Predicted Label: Eyezy
# Accuracy: 0.894927536231884
# Precision: 0.901716436231884
# Recall: 0.894927536231884
# F1-Score: 0.8983091597721301
# Predicted Label: Eyezy
# Accuracy: 0.8953068592057761
# Precision: 0.9020957592057761
# Recall: 0.8953068592057761
# F1-Score: 0.8986884881598018
# Predicted Label: Eyezy
# Accuracy: 0.89568345323741
# Precision: 0.90247235323741
# Recall: 0.89568345323741
# F1-Score: 0.8990650875617483
# Predicted Label: Eyezy
# Accuracy: 0.8960573476702509
# Precision: 0.9028462476702509
# Recall: 0.8960573476702509
# F1-Score: 0.899438987321956
# Predicted Label: Eyezy
# Accuracy: 0.8964285714285715
# Precision: 0.9032174714285715
# Recall: 0.8964285714285715
# F1-Score: 0.8998102163652112
# Predicted Label: Eyezy
# Accuracy: 0.896797153024911
# Precision: 0.903586053024911
# Recall: 0.896797153024911
# F1-Score: 0.9001788032045573
# Predicted Label: Qustodio
# Accuracy: 0.8936170212765957
# Precision: 0.9004059212765957
# Recall: 0.8936170212765957
# F1-Score: 0.8969986260776528
# Predicted Label: Eyezy
# Accuracy: 0.8939929328621908
# Precision: 0.9007818328621908
# Recall: 0.8939929328621908
# F1-Score: 0.8973745430440448
# Predicted Label: Eyezy
# Accuracy: 0.8943661971830986
# Precision: 0.9011550971830986
# Recall: 0.8943661971830986
# F1-Score: 0.8977478127033978
# Predicted Label: Eyezy
# Accuracy: 0.8947368421052632
# Precision: 0.9015257421052632
# Recall: 0.8947368421052632
# F1-Score: 0.8981184629221541
# Predicted Label: Eyezy
# Accuracy: 0.8951048951048951
# Precision: 0.9018937951048951
# Recall: 0.8951048951048951
# F1-Score: 0.8984865211770144
# Predicted Label: Eyezy
# Accuracy: 0.8954703832752613
# Precision: 0.9022592832752613
# Recall: 0.8954703832752613
# F1-Score: 0.8988520145617285
# Predicted Label: Eyezy
# Accuracy: 0.8958333333333334
# Precision: 0.9026222333333334
# Recall: 0.8958333333333334
# F1-Score: 0.899214969793743
# Predicted Label: Eyezy
# Accuracy: 0.8961937716262975
# Precision: 0.9029826716262975
# Recall: 0.8961937716262975
# F1-Score: 0.899575413220712
# Predicted Label: Eyezy
# Accuracy: 0.896551724137931
# Precision: 0.903340624137931
# Recall: 0.896551724137931
# F1-Score: 0.8999333708268735
# Predicted Label: Eyezy
# Accuracy: 0.8969072164948454
# Precision: 0.9036961164948454
# Recall: 0.8969072164948454
# F1-Score: 0.9002888682392926
# Predicted Label: Eyezy
# Accuracy: 0.8972602739726028
# Precision: 0.9040491739726028
# Recall: 0.8972602739726028
# F1-Score: 0.9006419307339777
# Predicted Label: Eyezy
# Accuracy: 0.8976109215017065
# Precision: 0.9043998215017065
# Recall: 0.8976109215017065
# F1-Score: 0.9009925832418726
# Predicted Label: Eyezy
# Accuracy: 0.8979591836734694
# Precision: 0.9047480836734694
# Recall: 0.8979591836734694
# F1-Score: 0.901340850354723
# Predicted Label: Eyezy
# Accuracy: 0.8983050847457628
# Precision: 0.9050939847457627
# Recall: 0.8983050847457628
# F1-Score: 0.9016867563308268
# Predicted Label: Eyezy
# Accuracy: 0.8986486486486487
# Precision: 0.9054375486486487
# Recall: 0.8986486486486487
# F1-Score: 0.9020303251006666
# Predicted Label: Eyezy
# Accuracy: 0.898989898989899
# Precision: 0.905778798989899
# Recall: 0.898989898989899
# F1-Score: 0.9023715802724279
# Predicted Label: Eyezy
# Accuracy: 0.8993288590604027
# Precision: 0.9061177590604027
# Recall: 0.8993288590604027
# F1-Score: 0.9027105451374078
# Predicted Label: Eyezy
# Accuracy: 0.8996655518394648
# Precision: 0.9064544518394648
# Recall: 0.8996655518394648
# F1-Score: 0.9030472426753129
# Predicted Label: Eyezy
# Accuracy: 0.9
# Precision: 0.9067889
# Recall: 0.9
# F1-Score: 0.9033816955594537
# Predicted Label: Eyezy
# Accuracy: 0.9003322259136213
# Precision: 0.9071211259136213
# Recall: 0.9003322259136213
# F1-Score: 0.9037139261618328
# Predicted Label: Eyezy
# Accuracy: 0.9006622516556292
# Precision: 0.9074511516556292
# Recall: 0.9006622516556292
# F1-Score: 0.9040439565581354
# Predicted Label: Eyezy
# Accuracy: 0.900990099009901
# Precision: 0.907778999009901
# Recall: 0.900990099009901
# F1-Score: 0.9043718085326172
# Predicted Label: Eyezy
# Accuracy: 0.9013157894736842
# Precision: 0.9081046894736842
# Recall: 0.9013157894736842
# F1-Score: 0.9046975035828987
# Predicted Label: Eyezy
# Accuracy: 0.9016393442622951
# Precision: 0.9084282442622951
# Recall: 0.9016393442622951
# F1-Score: 0.9050210629246639
# Predicted Label: MoniMasterPro
# Accuracy: 0.8986928104575164
# Precision: 0.9054817104575164
# Recall: 0.8986928104575164
# F1-Score: 0.9020744875348652
# Predicted Label: Eyezy
# Accuracy: 0.8990228013029316
# Precision: 0.9058117013029315
# Recall: 0.8990228013029316
# F1-Score: 0.9024044830510104
# Predicted Label: Eyezy
# Accuracy: 0.8993506493506493
# Precision: 0.9061395493506493
# Recall: 0.8993506493506493
# F1-Score: 0.9027323357357476
# Predicted Label: Eyezy
# Accuracy: 0.8996763754045307
# Precision: 0.9064652754045307
# Recall: 0.8996763754045307
# F1-Score: 0.9030580663933011
# Predicted Label: Eyezy
# Accuracy: 0.9
# Precision: 0.9067889
# Recall: 0.9
# F1-Score: 0.9033816955594537
# Predicted Label: Eyezy
# Accuracy: 0.9003215434083601
# Precision: 0.9071104434083601
# Recall: 0.9003215434083601
# F1-Score: 0.9037032435058614
# Predicted Label: Normal-Traffic
# Accuracy: 0.8974358974358975
# Precision: 0.9042247974358975
# Recall: 0.8974358974358975
# F1-Score: 0.900817556691408
# Predicted Label: Eyezy
# Accuracy: 0.8977635782747604
# Precision: 0.9045524782747604
# Recall: 0.8977635782747604
# F1-Score: 0.9011452421812662
# Predicted Label: Eyezy
# Accuracy: 0.8980891719745223
# Precision: 0.9048780719745223
# Recall: 0.8980891719745223
# F1-Score: 0.9014708404990505
# Predicted Label: Eyezy
# Accuracy: 0.8984126984126984
# Precision: 0.9052015984126984
# Recall: 0.8984126984126984
# F1-Score: 0.9017943715226253
# Predicted Label: Eyezy
# Accuracy: 0.8987341772151899
# Precision: 0.9055230772151899
# Recall: 0.8987341772151899
# F1-Score: 0.9021158548782361
# Predicted Label: Eyezy
# Accuracy: 0.8990536277602523
# Precision: 0.9058425277602523
# Recall: 0.8990536277602523
# F1-Score: 0.9024353099444782
# Predicted Label: Eyezy
# Accuracy: 0.89937106918239
# Precision: 0.90615996918239
# Recall: 0.89937106918239
# F1-Score: 0.9027527558561909
# Predicted Label: Eyezy
# Accuracy: 0.8996865203761756
# Precision: 0.9064754203761756
# Recall: 0.8996865203761756
# F1-Score: 0.9030682115082773
# Predicted Label: All Tracker Business Device Monitoring
# Accuracy: 0.896875
# Precision: 0.9036639
# Recall: 0.896875
# F1-Score: 0.9002566512864566
# Predicted Label: MoniMasterPro
# Accuracy: 0.8940809968847352
# Precision: 0.9008698968847352
# Recall: 0.8940809968847352
# F1-Score: 0.8974626083264854
# Predicted Label: Eyezy
# Accuracy: 0.8944099378881988
# Precision: 0.9011988378881988
# Recall: 0.8944099378881988
# F1-Score: 0.8977915540337892
# Predicted Label: Eyezy
# Accuracy: 0.8947368421052632
# Precision: 0.9015257421052632
# Recall: 0.8947368421052632
# F1-Score: 0.8981184629221541
# Predicted Label: Air-Droid
# Accuracy: 0.8919753086419753
# Precision: 0.8987642086419753
# Recall: 0.8919753086419753
# F1-Score: 0.8953568898906116
# Predicted Label: Eyezy
# Accuracy: 0.8923076923076924
# Precision: 0.8990965923076923
# Recall: 0.8923076923076924
# F1-Score: 0.8956892783317586
# Predicted Label: Eyezy
# Accuracy: 0.8926380368098159
# Precision: 0.8994269368098159
# Recall: 0.8926380368098159
# F1-Score: 0.8960196275765044
# Predicted Label: FamiGuardPro
# Accuracy: 0.8899082568807339
# Precision: 0.8966971568807339
# Recall: 0.8899082568807339
# F1-Score: 0.8932898083518099
# Predicted Label: Normal-Traffic
# Accuracy: 0.8871951219512195
# Precision: 0.8939840219512195
# Recall: 0.8871951219512195
# F1-Score: 0.8905766341275962
# Predicted Label: KidsGuardPro
# Accuracy: 0.8844984802431611
# Precision: 0.8912873802431611
# Recall: 0.8844984802431611
# F1-Score: 0.8878799531257521
# Predicted Label: Eyezy
# Accuracy: 0.8848484848484849
# Precision: 0.8916373848484849
# Recall: 0.8848484848484849
# F1-Score: 0.888229962844599
# Predicted Label: Eyezy
# Accuracy: 0.8851963746223565
# Precision: 0.8919852746223564
# Recall: 0.8851963746223565
# F1-Score: 0.8885778576971045
# Predicted Label: Eyezy
# Accuracy: 0.8855421686746988
# Precision: 0.8923310686746988
# Recall: 0.8855421686746988
# F1-Score: 0.8889236567935473
# Predicted Label: Eyezy
# Accuracy: 0.8858858858858859
# Precision: 0.8926747858858859
# Recall: 0.8858858858858859
# F1-Score: 0.8892673790146525
# Predicted Label: Eyezy
# Accuracy: 0.8862275449101796
# Precision: 0.8930164449101796
# Recall: 0.8862275449101796
# F1-Score: 0.8896090430150282
# Predicted Label: Eyezy
# Accuracy: 0.8865671641791045
# Precision: 0.8933560641791045
# Recall: 0.8865671641791045
# F1-Score: 0.8899486672265406
# Predicted Label: FamiGuardPro
# Accuracy: 0.8839285714285714
# Precision: 0.8907174714285714
# Recall: 0.8839285714285714
# F1-Score: 0.887310035976234
# Predicted Label: Eyezy
# Accuracy: 0.884272997032641
# Precision: 0.8910618970326409
# Recall: 0.884272997032641
# F1-Score: 0.8876544666188149
# Predicted Label: Eyezy
# Accuracy: 0.8846153846153846
# Precision: 0.8914042846153846
# Recall: 0.8846153846153846
# F1-Score: 0.8879968592063819
# Predicted Label: Eyezy
# Accuracy: 0.8849557522123894
# Precision: 0.8917446522123894
# Recall: 0.8849557522123894
# F1-Score: 0.8883372317748595
# Predicted Label: Eyezy
# Accuracy: 0.8852941176470588
# Precision: 0.8920830176470588
# Recall: 0.8852941176470588
# F1-Score: 0.8886756021479829
# Predicted Label: MoniMasterPro
# Accuracy: 0.8826979472140762
# Precision: 0.8894868472140762
# Recall: 0.8826979472140762
# F1-Score: 0.8860793937272631
# Predicted Label: Eyezy
# Accuracy: 0.8830409356725146
# Precision: 0.8898298356725146
# Recall: 0.8830409356725146
# F1-Score: 0.8864223872171406
# Predicted Label: Eyezy
# Accuracy: 0.8833819241982507
# Precision: 0.8901708241982507
# Recall: 0.8833819241982507
# F1-Score: 0.8867633807411202
# Predicted Label: Eyezy
# Accuracy: 0.8837209302325582
# Precision: 0.8905098302325581
# Recall: 0.8837209302325582
# F1-Score: 0.8871023917408024
# Predicted Label: Eyezy
# Accuracy: 0.8840579710144928
# Precision: 0.8908468710144928
# Recall: 0.8840579710144928
# F1-Score: 0.8874394374555665
# Predicted Label: Eyezy
# Accuracy: 0.884393063583815
# Precision: 0.891181963583815
# Recall: 0.884393063583815
# F1-Score: 0.8877745349254917
# Predicted Label: Eyezy
# Accuracy: 0.8847262247838616
# Precision: 0.8915151247838616
# Recall: 0.8847262247838616
# F1-Score: 0.8881077009942295
# Predicted Label: Eyezy
# Accuracy: 0.8850574712643678
# Precision: 0.8918463712643678
# Recall: 0.8850574712643678
# F1-Score: 0.8884389523118261
# Predicted Label: Eyezy
# Accuracy: 0.8853868194842407
# Precision: 0.8921757194842407
# Recall: 0.8853868194842407
# F1-Score: 0.8887683053374948
# Predicted Label: Eyezy
# Accuracy: 0.8857142857142857
# Precision: 0.8925031857142857
# Recall: 0.8857142857142857
# F1-Score: 0.8890957763423442
# Predicted Label: Eyezy
# Accuracy: 0.886039886039886
# Precision: 0.892828786039886
# Recall: 0.886039886039886
# F1-Score: 0.8894213814120562
# Predicted Label: Eyezy
# Accuracy: 0.8863636363636364
# Precision: 0.8931525363636363
# Recall: 0.8863636363636364
# F1-Score: 0.8897451364495204
# Predicted Label: Eyezy
# Accuracy: 0.886685552407932
# Precision: 0.893474452407932
# Recall: 0.886685552407932
# F1-Score: 0.8900670571774231
# Predicted Label: Eyezy
# Accuracy: 0.8870056497175142
# Precision: 0.8937945497175142
# Recall: 0.8870056497175142
# F1-Score: 0.8903871591407935
# Predicted Label: Normal-Traffic
# Accuracy: 0.8845070422535212
# Precision: 0.8912959422535212
# ...
# Predicted Label: Eyezy
# Accuracy: 0.8548387096774194
# Precision: 0.8616276096774194
# Recall: 0.8548387096774194
# F1-Score: 0.8582197340824368
# Predicted Label: All Tracker Communication Monitoring
# Accuracy: 0.8536912751677852
# Precision: 0.8604801751677852
# Recall: 0.8536912751677852
# F1-Score: 0.857072281599115
# Predicted Label: Eyezy
# Accuracy: 0.853887399463807
# Precision: 0.860676299463807
# Recall: 0.853887399463807
# F1-Score: 0.8572684089706836
# Predicted Label: Eyezy
# Accuracy: 0.8540829986613119
# Precision: 0.8608718986613119
# Recall: 0.8540829986613119
# F1-Score: 0.8574640112340995
# Predicted Label: Eyezy
# Accuracy: 0.8542780748663101
# Precision: 0.8610669748663101
# Recall: 0.8542780748663101
# F1-Score: 0.8576590904954186
# Predicted Label: Eyezy
# Accuracy: 0.8544726301735648
# Precision: 0.8612615301735648
# Recall: 0.8544726301735648
# F1-Score: 0.8578536488494484
# Predicted Label: Eyezy
# Accuracy: 0.8546666666666667
# Precision: 0.8614555666666667
# Recall: 0.8546666666666667
# F1-Score: 0.8580476883798247
# Predicted Label: KidsGuardPro
# Accuracy: 0.8535286284953395
# Precision: 0.8603175284953395
# Recall: 0.8535286284953395
# F1-Score: 0.8569096323750381
# Predicted Label: Eyezy
# Accuracy: 0.8537234042553191
# Precision: 0.8605123042553191
# Recall: 0.8537234042553191
# F1-Score: 0.8571044111905816
# Predicted Label: Eyezy
# Accuracy: 0.8539176626826029
# Precision: 0.8607065626826029
# Recall: 0.8539176626826029
# F1-Score: 0.8572986726639307
# Predicted Label: Eyezy
# Accuracy: 0.8541114058355438
# Precision: 0.8609003058355438
# Recall: 0.8541114058355438
# F1-Score: 0.8574924188534824
# Predicted Label: Eyezy
# Accuracy: 0.8543046357615894
# Precision: 0.8610935357615894
# Recall: 0.8543046357615894
# F1-Score: 0.8576856518067285
# Predicted Label: Normal-Traffic
# Accuracy: 0.8531746031746031
# Precision: 0.8599635031746031
# Recall: 0.8531746031746031
# F1-Score: 0.8565556014969367
# Predicted Label: Eyezy
# Accuracy: 0.8533685601056803
# Precision: 0.8601574601056803
# Recall: 0.8533685601056803
# F1-Score: 0.8567495614732503
# Predicted Label: Eyezy
# Accuracy: 0.8535620052770448
# Precision: 0.8603509052770448
# Recall: 0.8535620052770448
# F1-Score: 0.8569430096804437
# Predicted Label: Eyezy
# Accuracy: 0.8537549407114624
# Precision: 0.8605438407114624
# Recall: 0.8537549407114624
# F1-Score: 0.8571359481413254
# Predicted Label: Eyezy
# Accuracy: 0.8539473684210527
# Precision: 0.8607362684210527
# Recall: 0.8539473684210527
# F1-Score: 0.8573283788680589
# Predicted Label: Eyezy
# Accuracy: 0.8541392904073587
# Precision: 0.8609281904073587
# Recall: 0.8541392904073587
# F1-Score: 0.8575203038622299
# Predicted Label: mSpy
# Accuracy: 0.8530183727034121
# Precision: 0.8598072727034121
# Recall: 0.8530183727034121
# F1-Score: 0.8563993685718333
# Predicted Label: Eyezy
# Accuracy: 0.8532110091743119
# Precision: 0.8599999091743119
# Recall: 0.8532110091743119
# F1-Score: 0.8565920080683458
# Predicted Label: Eyezy
# Accuracy: 0.8534031413612565
# Precision: 0.8601920413612565
# Recall: 0.8534031413612565
# F1-Score: 0.8567841432716276
# Predicted Label: Eyezy
# Accuracy: 0.85359477124183
# Precision: 0.86038367124183
# Recall: 0.85359477124183
# F1-Score: 0.8569757761593052
# Predicted Label: Eyezy
# Accuracy: 0.8537859007832899
# Precision: 0.8605748007832899
# Recall: 0.8537859007832899
# F1-Score: 0.8571669086986784
# Predicted Label: Eyezy
# Accuracy: 0.8539765319426337
# Precision: 0.8607654319426337
# Recall: 0.8539765319426337
# F1-Score: 0.8573575428467871
# Predicted Label: Eyezy
# Accuracy: 0.8541666666666666
# Precision: 0.8609555666666666
# Recall: 0.8541666666666666
# F1-Score: 0.8575476805504779
# Predicted Label: Normal-Traffic
# Accuracy: 0.8530559167750326
# Precision: 0.8598448167750325
# Recall: 0.8530559167750326
# F1-Score: 0.8564369132332402
# Predicted Label: Eyezy
# Accuracy: 0.8532467532467533
# Precision: 0.8600356532467532
# Recall: 0.8532467532467533
# F1-Score: 0.8566277527020459
# Predicted Label: Eyezy
# Accuracy: 0.8534370946822308
# Precision: 0.8602259946822308
# Recall: 0.8534370946822308
# F1-Score: 0.856818097125504
# Predicted Label: Eyezy
# Accuracy: 0.8536269430051814
# Precision: 0.8604158430051814
# Recall: 0.8536269430051814
# F1-Score: 0.8570079484273722
# Predicted Label: Qustodio
# Accuracy: 0.8525226390685641
# Precision: 0.8593115390685641
# Recall: 0.8525226390685641
# F1-Score: 0.855903627144565
# Predicted Label: Eyezy
# Accuracy: 0.8527131782945736
# Precision: 0.8595020782945736
# Recall: 0.8527131782945736
# F1-Score: 0.8560941693667219
# Predicted Label: Eyezy
# Accuracy: 0.8529032258064516
# Precision: 0.8596921258064516
# Recall: 0.8529032258064516
# F1-Score: 0.8562842198656871
# Predicted Label: FamiSafe
# Accuracy: 0.8518041237113402
# Precision: 0.8585930237113402
# Recall: 0.8518041237113402
# F1-Score: 0.8551851004769866
# Predicted Label: Eyezy
# Accuracy: 0.851994851994852
# Precision: 0.858783751994852
# Recall: 0.851994851994852
# F1-Score: 0.855375831764659
# Predicted Label: Eyezy
# Accuracy: 0.8521850899742931
# Precision: 0.8589739899742931
# Recall: 0.8521850899742931
# F1-Score: 0.8555660727392036
# Predicted Label: Eyezy
# Accuracy: 0.8523748395378691
# Precision: 0.8591637395378691
# Recall: 0.8523748395378691
# F1-Score: 0.8557558252888672
# Predicted Label: All Tracker Business Device Monitoring
# Accuracy: 0.8512820512820513
# Precision: 0.8580709512820512
# Recall: 0.8512820512820513
# F1-Score: 0.8546630198176782
# Predicted Label: Eyezy
# Accuracy: 0.8514724711907811
# Precision: 0.858261371190781
# Recall: 0.8514724711907811
# F1-Score: 0.8548534427293774
# Predicted Label: Eyezy
# Accuracy: 0.8516624040920716
# Precision: 0.8584513040920716
# Recall: 0.8516624040920716
# F1-Score: 0.8550433786246248
# Predicted Label: Eyezy
# Accuracy: 0.8518518518518519
# Precision: 0.8586407518518518
# Recall: 0.8518518518518519
# F1-Score: 0.8552328293693896
# Predicted Label: Eyezy
# Accuracy: 0.8520408163265306
# Precision: 0.8588297163265306
# Recall: 0.8520408163265306
# F1-Score: 0.8554217968201214
# Predicted Label: Eyezy
# Accuracy: 0.8522292993630574
# Precision: 0.8590181993630573
# Recall: 0.8522292993630574
# F1-Score: 0.855610282823809
# Predicted Label: Eyezy
# Accuracy: 0.8524173027989822
# Precision: 0.8592062027989822
# Recall: 0.8524173027989822
# F1-Score: 0.855798289218043
# Predicted Label: Eyezy
# Accuracy: 0.8526048284625158
# Precision: 0.8593937284625158
# Recall: 0.8526048284625158
# F1-Score: 0.8559858178310733
# Predicted Label: Eyezy
# Accuracy: 0.8527918781725888
# Precision: 0.8595807781725888
# Recall: 0.8527918781725888
# F1-Score: 0.8561728704818697
# Predicted Label: Eyezy
# Accuracy: 0.85297845373891
# Precision: 0.85976735373891
# Recall: 0.85297845373891
# F1-Score: 0.8563594489801802
# Predicted Label: Eyezy
# Accuracy: 0.8531645569620253
# Precision: 0.8599534569620253
# Recall: 0.8531645569620253
# F1-Score: 0.8565455551265898
# Predicted Label: Eyezy
# Accuracy: 0.8533501896333755
# Precision: 0.8601390896333755
# Recall: 0.8533501896333755
# F1-Score: 0.8567311907125774
# Predicted Label: Eyezy
# Accuracy: 0.8535353535353535
# Precision: 0.8603242535353535
# Recall: 0.8535353535353535
# F1-Score: 0.856916357520575
# Predicted Label: Eyezy
# Accuracy: 0.8537200504413619
# Precision: 0.8605089504413619
# Recall: 0.8537200504413619
# F1-Score: 0.8571010573240228
# Predicted Label: Eyezy
# Accuracy: 0.853904282115869
# Precision: 0.860693182115869
# Recall: 0.853904282115869
# F1-Score: 0.8572852918874273
# Predicted Label: Eyezy
# Accuracy: 0.8540880503144654
# Precision: 0.8608769503144654
# Recall: 0.8540880503144654
# F1-Score: 0.8574690629664166
# Predicted Label: mSpy
# Accuracy: 0.8530150753768844
# Precision: 0.8598039753768844
# Recall: 0.8530150753768844
# F1-Score: 0.8563960711935047
# Predicted Label: Eyezy
# Accuracy: 0.8531994981179423
# Precision: 0.8599883981179423
# Recall: 0.8531994981179423
# F1-Score: 0.8565804968312178
# Predicted Label: Eyezy
# Accuracy: 0.8533834586466166
# Precision: 0.8601723586466166
# Recall: 0.8533834586466166
# F1-Score: 0.8567644602480454
# Predicted Label: Eyezy
# Accuracy: 0.853566958698373
# Precision: 0.8603558586983729
# Recall: 0.853566958698373
# F1-Score: 0.8569479631794901
# Predicted Label: Eyezy
# Accuracy: 0.85375
# Precision: 0.8605389
# Recall: 0.85375
# F1-Score: 0.857131007352378
# Predicted Label: Eyezy
# Accuracy: 0.8539325842696629
# Precision: 0.8607214842696629
# Recall: 0.8539325842696629
# F1-Score: 0.8573135944849112
# Predicted Label: Eyezy
# Accuracy: 0.8541147132169576
# Precision: 0.8609036132169576
# Recall: 0.8541147132169576
# F1-Score: 0.8574957262867221
# Predicted Label: Eyezy
# Accuracy: 0.8542963885429639
# Precision: 0.8610852885429638
# Recall: 0.8542963885429639
# F1-Score: 0.8576774044589272
# Predicted Label: Eyezy
# Accuracy: 0.8544776119402985
# Precision: 0.8612665119402985
# Recall: 0.8544776119402985
# F1-Score: 0.8578586306941796
# Predicted Label: Eyezy
# Accuracy: 0.8546583850931677
# Precision: 0.8614472850931677
# Recall: 0.8546583850931677
# F1-Score: 0.8580394066767214
# Predicted Label: Eyezy
# Accuracy: 0.8548387096774194
# Precision: 0.8616276096774194
# Recall: 0.8548387096774194
# F1-Score: 0.8582197340824368
# Predicted Label: Eyezy
# Accuracy: 0.8550185873605948
# Precision: 0.8618074873605948
# Recall: 0.8550185873605948
# F1-Score: 0.8583996145789023
# Predicted Label: Eyezy
# Accuracy: 0.8551980198019802
# Precision: 0.8619869198019802
# Recall: 0.8551980198019802
# F1-Score: 0.8585790498254398
# Predicted Label: Eyezy
# Accuracy: 0.8553770086526576
# Precision: 0.8621659086526576
# Recall: 0.8553770086526576
# F1-Score: 0.8587580414731666
# Predicted Label: Eyezy
# Accuracy: 0.8555555555555555
# Precision: 0.8623444555555555
# Recall: 0.8555555555555555
# F1-Score: 0.8589365911650463
# Predicted Label: Eyezy
# Accuracy: 0.8557336621454994
# Precision: 0.8625225621454994
# Recall: 0.8557336621454994
# F1-Score: 0.8591147005359389
# Predicted Label: All Tracker Communication Monitoring
# Accuracy: 0.854679802955665
# Precision: 0.861468702955665
# Recall: 0.854679802955665
# F1-Score: 0.8580608248743972
# Predicted Label: Eyezy
# Accuracy: 0.8548585485854858
# Precision: 0.8616474485854858
# Recall: 0.8548585485854858
# F1-Score: 0.8582395733008419
# Predicted Label: All Tracker Business Device Monitoring
# Accuracy: 0.8538083538083538
# Precision: 0.8605972538083538
# Recall: 0.8538083538083538
# F1-Score: 0.8571893620758357
# Predicted Label: Eyezy
# Accuracy: 0.8539877300613496
# Precision: 0.8607766300613496
# Recall: 0.8539877300613496
# F1-Score: 0.8573687411410286
# Predicted Label: Eyezy
# Accuracy: 0.8541666666666666
# Precision: 0.8609555666666666
# Recall: 0.8541666666666666
# F1-Score: 0.8575476805504779
# Predicted Label: Eyezy
# Accuracy: 0.8543451652386781
# Precision: 0.8611340652386781
# Recall: 0.8543451652386781
# F1-Score: 0.8577261819185915
# Predicted Label: Eyezy
# Accuracy: 0.8545232273838631
# Precision: 0.8613121273838631
# Recall: 0.8545232273838631
# F1-Score: 0.8579042468518829
# Predicted Label: Eyezy
# Accuracy: 0.8547008547008547
# Precision: 0.8614897547008546
# Recall: 0.8547008547008547
# F1-Score: 0.8580818769490195
# Predicted Label: Eyezy
# Accuracy: 0.8548780487804878
# Precision: 0.8616669487804878
# Recall: 0.8548780487804878
# F1-Score: 0.8582590738008703
# Predicted Label: Eyezy
# Accuracy: 0.8550548112058465
# Precision: 0.8618437112058465
# Recall: 0.8550548112058465
# F1-Score: 0.8584358389905528
# Predicted Label: Eyezy
# Accuracy: 0.8552311435523114
# Precision: 0.8620200435523114
# Recall: 0.8552311435523114
# F1-Score: 0.8586121740934821
# Predicted Label: Eyezy
# Accuracy: 0.8554070473876063
# Precision: 0.8621959473876063
# Recall: 0.8554070473876063
# F1-Score: 0.8587880806774146
# Predicted Label: Eyezy
# Accuracy: 0.8555825242718447
# Precision: 0.8623714242718447
# Recall: 0.8555825242718447
# F1-Score: 0.8589635603024978
# Predicted Label: Eyezy
# Accuracy: 0.8557575757575757
# Precision: 0.8625464757575757
# Recall: 0.8557575757575757
# F1-Score: 0.8591386145213136
# Predicted Label: FamiGuardPro
# Accuracy: 0.8547215496368039
# Precision: 0.8615104496368039
# Recall: 0.8547215496368039
# F1-Score: 0.8581025722088018
# Predicted Label: Eyezy
# Accuracy: 0.8548972188633616
# Precision: 0.8616861188633615
# Recall: 0.8548972188633616
# F1-Score: 0.8582782441835931
# Predicted Label: Eyezy
# Accuracy: 0.855072463768116
# Precision: 0.861861363768116
# Recall: 0.855072463768116
# F1-Score: 0.8584534918288219
# Predicted Label: MoniMasterPro
# Accuracy: 0.8540410132689988
# Precision: 0.8608299132689988
# Recall: 0.8540410132689988
# F1-Score: 0.8574220251838062
# Predicted Label: Eyezy
# Accuracy: 0.8542168674698796
# Precision: 0.8610057674698796
# Recall: 0.8542168674698796
# F1-Score: 0.8575978821401821
# Predicted Label: Eyezy
# Accuracy: 0.8543922984356197
# Precision: 0.8611811984356197
# Recall: 0.8543922984356197
# F1-Score: 0.8577733158536598
# Predicted Label: Eyezy
# Accuracy: 0.8545673076923077
# Precision: 0.8613562076923077
# Recall: 0.8545673076923077
# F1-Score: 0.8579483278503605
# Predicted Label: Eyezy
# Accuracy: 0.8547418967587035
# Precision: 0.8615307967587035
# Recall: 0.8547418967587035
# F1-Score: 0.8581229196490768
# Predicted Label: Eyezy
# Accuracy: 0.854916067146283
# Precision: 0.861704967146283
# Recall: 0.854916067146283
# F1-Score: 0.8582970927613169
# Predicted Label: Eyezy
# Accuracy: 0.8550898203592814
# Precision: 0.8618787203592814
# Recall: 0.8550898203592814
# F1-Score: 0.8584708486913483
# Predicted Label: Eyezy
# Accuracy: 0.8552631578947368
# Precision: 0.8620520578947368
# Recall: 0.8552631578947368
# F1-Score: 0.8586441889362411
# Predicted Label: mLite
# Accuracy: 0.8542413381123058
# Precision: 0.8610302381123058
# Recall: 0.8542413381123058
# F1-Score: 0.8576223531659543
# Predicted Label: Eyezy
# Accuracy: 0.8544152744630071
# Precision: 0.8612041744630071
# Recall: 0.8544152744630071
# F1-Score: 0.8577962922408325
# Predicted Label: Eyezy
# Accuracy: 0.8545887961859356
# Precision: 0.8613776961859356
# Recall: 0.8545887961859356
# F1-Score: 0.8579698166803437
# Predicted Label: All Tracker Parent Control
# Accuracy: 0.8535714285714285
# Precision: 0.8603603285714285
# Recall: 0.8535714285714285
# F1-Score: 0.8569524331226767
# Predicted Label: Eyezy
# Accuracy: 0.8537455410225921
# Precision: 0.8605344410225921
# Recall: 0.8537455410225921
# F1-Score: 0.8571265483050394
# Predicted Label: Eyezy
# Accuracy: 0.8539192399049881
# Precision: 0.8607081399049881
# Recall: 0.8539192399049881
# F1-Score: 0.8573002499110417
# Predicted Label: Eyezy
# Accuracy: 0.8540925266903915
# Precision: 0.8608814266903915
# Recall: 0.8540925266903915
# F1-Score: 0.8574735394124904
# Predicted Label: Eyezy
# Accuracy: 0.8542654028436019
# Precision: 0.8610543028436018
# Recall: 0.8542654028436019
# F1-Score: 0.8576464182742158
# Predicted Label: MoniMasterPro
# Accuracy: 0.8532544378698225
# Precision: 0.8600433378698225
# Recall: 0.8532544378698225
# F1-Score: 0.8566354374457741
# Predicted Label: Eyezy
# Accuracy: 0.8534278959810875
# Precision: 0.8602167959810875
# Recall: 0.8534278959810875
# F1-Score: 0.8568088982799897
# Predicted Label: Eyezy
# Accuracy: 0.8536009445100354
# Precision: 0.8603898445100354
# Recall: 0.8536009445100354
# F1-Score: 0.8569819495243607
# Predicted Label: Eyezy
# Accuracy: 0.8537735849056604
# Precision: 0.8605624849056603
# Recall: 0.8537735849056604
# F1-Score: 0.8571545926279116
# Predicted Label: Eyezy
# Accuracy: 0.8539458186101295
# Precision: 0.8607347186101295
# Recall: 0.8539458186101295
# F1-Score: 0.8573268290328411
# Predicted Label: Eyezy
# Accuracy: 0.8541176470588235
# Precision: 0.8609065470588235
# Recall: 0.8541176470588235
# F1-Score: 0.8574986601745603
# Predicted Label: Eyezy
# Accuracy: 0.854289071680376
# Precision: 0.861077971680376
# Recall: 0.854289071680376
# F1-Score: 0.8576700874817338
# Predicted Label: Eyezy
# Accuracy: 0.8544600938967136
# Precision: 0.8612489938967136
# Recall: 0.8544600938967136
# F1-Score: 0.8578411123763184
# Predicted Label: Eyezy
# Accuracy: 0.854630715123095
# Precision: 0.861419615123095
# Recall: 0.854630715123095
# F1-Score: 0.8580117362736033
# Predicted Label: Eyezy
# Accuracy: 0.8548009367681498
# Precision: 0.8615898367681498
# Recall: 0.8548009367681498
# F1-Score: 0.8581819605822484
# Predicted Label: Eyezy
# Accuracy: 0.8549707602339182
# Precision: 0.8617596602339181
# Recall: 0.8549707602339182
# F1-Score: 0.8583517867043237
# Predicted Label: Eyezy
# Accuracy: 0.8551401869158879
# Precision: 0.8619290869158879
# Recall: 0.8551401869158879
# F1-Score: 0.8585212160353466
# Predicted Label: Eyezy
# Accuracy: 0.8553092182030338
# Precision: 0.8620981182030338
# Recall: 0.8553092182030338
# F1-Score: 0.8586902499643223
# Predicted Label: Eyezy
# Accuracy: 0.8554778554778555
# Precision: 0.8622667554778555
# Recall: 0.8554778554778555
# F1-Score: 0.8588588898737789
