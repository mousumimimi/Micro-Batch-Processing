# %%
from scapy.all import sniff

def process_packet(packet):
    print(packet.summary())  # Replace with your ML model prediction code if needed

# Replace 'Bluetooth Network Connection' with the actual interface name
interface_name = "Ethernet"

# Capture packets from the specified network interface
sniff(iface=interface_name, prn=process_packet, store=False, timeout=180)
# Out:
# 802.3 00:0a:b8:30:d5:8a > 01:80:c2:00:00:00 / LLC / STP / Raw / Padding
# 802.3 00:0a:b8:30:d5:8a > 01:80:c2:00:00:00 / LLC / STP / Raw / Padding
# 802.3 00:0a:b8:30:d5:8a > 01:80:c2:00:00:00 / LLC / STP / Raw / Padding
# 802.3 00:0a:b8:30:d5:8a > 01:80:c2:00:00:00 / LLC / STP / Raw / Padding
# Ether / IP / TCP 10.106.184.11:65273 > 52.111.240.35:https A / Raw
# Ether / IP / TCP 52.111.240.35:https > 10.106.184.11:65273 A
# 802.3 00:0a:b8:30:d5:8a > 01:80:c2:00:00:00 / LLC / STP / Raw / Padding
# Ether / ARP who has 169.254.169.254 says 10.106.184.237 / Padding
# Ether / IP / TCP 10.106.184.11:64926 > 203.106.94.176:https A / Raw
# Ether / IP / TCP 203.106.94.176:https > 10.106.184.11:64926 A
# Ether / ARP who has 169.254.169.254 says 10.106.184.237 / Padding
# 802.3 00:0a:b8:30:d5:8a > 01:80:c2:00:00:00 / LLC / STP / Raw / Padding
# Ether / ARP who has 169.254.169.254 says 10.106.184.237 / Padding
# 802.3 00:0a:b8:30:d5:8a > 01:80:c2:00:00:00 / LLC / STP / Raw / Padding
# Ether / IP / UDP / DNS Qry b'wpad.mmu.edu.my.'
# Ether / IP / UDP / DNS Ans name-error
# Ether / IP / TCP 10.106.184.11:65284 > 204.79.197.203:https A / Raw
# Ether / IP / TCP 204.79.197.203:https > 10.106.184.11:65284 A
# Ether / IP / TCP 10.106.184.11:65287 > 18.161.180.87:https A / Raw
# Ether / IP / TCP 18.161.180.87:https > 10.106.184.11:65287 A
# Ether / IP / TCP 10.106.184.11:65289 > 150.171.27.10:https A / Raw
# Ether / IP / TCP 150.171.27.10:https > 10.106.184.11:65289 A
# Ether / IP / TCP 10.106.184.11:65286 > 52.231.230.148:https A / Raw
# Ether / IP / TCP 10.106.184.11:65294 > 118.215.103.18:http A / Raw
# Ether / IP / TCP 118.215.103.18:http > 10.106.184.11:65294 A
# Ether / IP / TCP 52.231.230.148:https > 10.106.184.11:65286 A
# 802.3 00:0a:b8:30:d5:8a > 01:80:c2:00:00:00 / LLC / STP / Raw / Padding
# Ether / IP / TCP 10.106.184.11:65297 > 23.220.240.182:https A / Raw
# Ether / IP / TCP 23.220.240.182:https > 10.106.184.11:65297 A
# Ether / IP / TCP 10.106.184.11:65288 > 204.79.197.203:https A / Raw
# Ether / IP / TCP 204.79.197.203:https > 10.106.184.11:65288 A
# Ether / IP / TCP 10.106.184.11:64582 > 20.198.119.84:https A / Raw
# Ether / IP / TCP 20.198.119.84:https > 10.106.184.11:64582 A
# Ether / IP / TCP 10.106.184.11:65299 > 202.188.238.201:https A / Raw
# Ether / IP / TCP 202.188.238.201:https > 10.106.184.11:65299 A
# Ether / IP / TCP 10.106.184.11:65301 > 204.79.197.203:https A / Raw
# Ether / IP / TCP 204.79.197.203:https > 10.106.184.11:65301 A
# Ether / IP / TCP 10.106.184.11:65303 > 40.126.35.153:https A / Raw
# Ether / IP / TCP 40.126.35.153:https > 10.106.184.11:65303 A
# 802.3 00:0a:b8:30:d5:8a > 01:80:c2:00:00:00 / LLC / STP / Raw / Padding
# Ether / IP / TCP 10.106.184.11:65298 > 20.42.65.90:https A / Raw
# Ether / IP / TCP 20.42.65.90:https > 10.106.184.11:65298 A
# Ether / IP / TCP 10.106.184.11:65302 > 13.107.6.158:https A / Raw
# Ether / IP / TCP 13.107.6.158:https > 10.106.184.11:65302 A
# Ether / IP / TCP 10.106.184.11:65253 > 20.212.88.117:https A / Raw
# Ether / IP / TCP 20.212.88.117:https > 10.106.184.11:65253 A
# Ether / IP / TCP 10.106.184.11:65300 > 204.79.197.203:https A / Raw
# Ether / IP / TCP 204.79.197.203:https > 10.106.184.11:65300 A
# 802.3 00:0a:b8:30:d5:8a > 01:80:c2:00:00:00 / LLC / STP / Raw / Padding
# Ether / IP / TCP 10.106.184.11:65285 > 20.42.65.90:https A / Raw
# Ether / IP / TCP 20.42.65.90:https > 10.106.184.11:65285 A
# Ether / IP / TCP 10.106.184.11:65304 > 57.155.146.244:https A / Raw
# Ether / IP / UDP 10.106.184.11:56912 > 203.106.94.152:https / Raw
# Ether / IP / UDP 10.106.184.11:56912 > 203.106.94.152:https / Raw
# Ether / IP / UDP 10.106.184.11:56912 > 203.106.94.152:https / Raw
# Ether / IP / TCP 57.155.146.244:https > 10.106.184.11:65304 A
# Ether / IP / UDP 203.106.94.152:https > 10.106.184.11:56912 / Raw
# Ether / IP / UDP 203.106.94.152:https > 10.106.184.11:56912 / Raw
# Ether / IP / UDP 203.106.94.152:https > 10.106.184.11:56912 / Raw
# Ether / IP / UDP 10.106.184.11:56912 > 203.106.94.152:https / Raw
# Ether / IP / UDP 203.106.94.152:https > 10.106.184.11:56912 / Raw
# Ether / IP / UDP 203.106.94.152:https > 10.106.184.11:56912 / Raw
# Ether / IP / UDP 203.106.94.152:https > 10.106.184.11:56912 / Raw
# Ether / IP / UDP 203.106.94.152:https > 10.106.184.11:56912 / Raw
# Ether / IP / UDP 203.106.94.152:https > 10.106.184.11:56912 / Raw
# Ether / IP / UDP 10.106.184.11:56912 > 203.106.94.152:https / Raw
# Ether / IP / UDP 10.106.184.11:56912 > 203.106.94.152:https / Raw
# Ether / IP / UDP 203.106.94.152:https > 10.106.184.11:56912 / Raw
# 802.3 00:0a:b8:30:d5:8a > 01:80:c2:00:00:00 / LLC / STP / Raw / Padding
# 802.3 00:0a:b8:30:d5:8a > 01:80:c2:00:00:00 / LLC / STP / Raw / Padding
# Ether / IP / TCP 10.106.184.11:65274 > 13.107.21.239:https A / Raw
# Ether / IP / TCP 13.107.21.239:https > 10.106.184.11:65274 A
# Ether / IP / UDP / mDNS Qry b'_microsoft_mcc._tcp.local.'
# Ether / IPv6 / UDP / mDNS Qry b'_microsoft_mcc._tcp.local.'
# Ether / IP / TCP 10.106.184.235:57151 > 10.106.184.11:ms_do S
# Ether / IP / TCP 10.106.184.11:ms_do > 10.106.184.235:57151 SA
# Ether / IP / TCP 10.106.184.235:57151 > 10.106.184.11:ms_do A / Padding
# Ether / IP / TCP 10.106.184.235:57151 > 10.106.184.11:ms_do PA / Raw
# Ether / IP / TCP 10.106.184.11:ms_do > 10.106.184.235:57151 FA
# Ether / IP / TCP 10.106.184.235:57151 > 10.106.184.11:ms_do A / Padding
# Ether / IP / TCP 10.106.184.235:57151 > 10.106.184.11:ms_do FA / Padding
# Ether / IP / TCP 10.106.184.11:ms_do > 10.106.184.235:57151 A
# Ether / IP / TCP 203.106.94.176:https > 10.106.184.11:64926 PA / Raw
# Ether / IP / TCP 10.106.184.11:64926 > 203.106.94.176:https A
# 802.3 00:0a:b8:30:d5:8a > 01:80:c2:00:00:00 / LLC / STP / Raw / Padding
# Ether / IP / UDP / mDNS Qry b'_microsoft_mcc._tcp.local.'
# Ether / IPv6 / UDP / mDNS Qry b'_microsoft_mcc._tcp.local.'
# 802.3 00:0a:b8:30:d5:8a > 01:80:c2:00:00:00 / LLC / STP / Raw / Padding
# 802.3 00:0a:b8:30:d5:8a > 01:00:0c:cc:cc:cc / LLC / SNAP / Raw
# Ether / IP / TCP 10.106.184.11:65273 > 52.111.240.35:https PA / Raw
# Ether / IP / TCP 10.106.184.11:65273 > 52.111.240.35:https PA / Raw
# Ether / IP / TCP 10.106.184.11:65273 > 52.111.240.35:https PA / Raw
# Ether / IP / TCP 52.111.240.35:https > 10.106.184.11:65273 A / Padding
# Ether / IP / TCP 52.111.240.35:https > 10.106.184.11:65273 PA / Raw
# Ether / IP / TCP 52.111.240.35:https > 10.106.184.11:65273 PA / Raw
# Ether / IP / TCP 10.106.184.11:65273 > 52.111.240.35:https A
# Ether / IP / TCP 52.111.240.35:https > 10.106.184.11:65273 PA / Raw
# Ether / IP / TCP 52.111.240.35:https > 10.106.184.11:65273 PA / Raw
# Ether / IP / TCP 10.106.184.11:65273 > 52.111.240.35:https A
# Ether / IP / TCP 10.106.184.11:65273 > 52.111.240.35:https PA / Raw
# Ether / IP / TCP 52.111.240.35:https > 10.106.184.11:65273 A / Padding
# Ether / IP / TCP 10.106.184.11:65274 > 13.107.21.239:https PA / Raw
# Ether / IP / TCP 10.106.184.11:65274 > 13.107.21.239:https PA / Raw
# Ether / IP / TCP 10.106.184.11:65274 > 13.107.21.239:https PA / Raw
# Ether / IP / TCP 13.107.21.239:https > 10.106.184.11:65274 A / Padding
# Ether / IP / TCP 13.107.21.239:https > 10.106.184.11:65274 A / Padding
# Ether / IP / TCP 13.107.21.239:https > 10.106.184.11:65274 PA / Raw
# Ether / IP / TCP 10.106.184.11:65274 > 13.107.21.239:https A
# Ether / IP / TCP 13.107.21.239:https > 10.106.184.11:65274 PA / Raw
# Ether / IP / TCP 10.106.184.11:65274 > 13.107.21.239:https PA / Raw
# Ether / IP / TCP 13.107.21.239:https > 10.106.184.11:65274 A / Padding
# 802.3 00:0a:b8:30:d5:8a > 01:80:c2:00:00:00 / LLC / STP / Raw / Padding
# Ether / IP / UDP / DNS Qry b'aefd.nelreports.net.'
# 802.3 00:0a:b8:30:d5:8a > 01:80:c2:00:00:00 / LLC / STP / Raw / Padding
# Ether / IP / UDP / DNS Ans b'aefd.nelreports.net.akamaized.net.'
# Ether / IP / UDP 10.106.184.11:53824 > 202.188.238.154:https / Raw
# Ether / IP / UDP 10.106.184.11:53824 > 202.188.238.154:https / Raw
# Ether / IP / TCP 10.106.184.11:65299 > 202.188.238.201:https PA / Raw
# Ether / IP / TCP 202.188.238.201:https > 10.106.184.11:65299 A / Padding
# Ether / IP / TCP 202.188.238.201:https > 10.106.184.11:65299 PA / Raw
# Ether / IP / UDP 202.188.238.154:https > 10.106.184.11:53824 / Raw
# Ether / IP / UDP 202.188.238.154:https > 10.106.184.11:53824 / Raw
# Ether / IP / UDP 202.188.238.154:https > 10.106.184.11:53824 / Raw
# Ether / IP / UDP 202.188.238.154:https > 10.106.184.11:53824 / Raw
# Ether / IP / UDP 202.188.238.154:https > 10.106.184.11:53824 / Raw
# Ether / IP / UDP 10.106.184.11:53824 > 202.188.238.154:https / Raw
# Ether / IP / UDP 10.106.184.11:53824 > 202.188.238.154:https / Raw
# Ether / IP / UDP 10.106.184.11:53824 > 202.188.238.154:https / Raw
# Ether / IP / UDP 10.106.184.11:53824 > 202.188.238.154:https / Raw
# Ether / IP / UDP 202.188.238.154:https > 10.106.184.11:53824 / Raw
# Ether / IP / UDP 202.188.238.154:https > 10.106.184.11:53824 / Raw
# Ether / IP / UDP 202.188.238.154:https > 10.106.184.11:53824 / Raw
# Ether / IP / UDP 202.188.238.154:https > 10.106.184.11:53824 / Raw
# Ether / IP / UDP 202.188.238.154:https > 10.106.184.11:53824 / Raw
# Ether / IP / UDP 10.106.184.11:53824 > 202.188.238.154:https / Raw
# Ether / IP / UDP 10.106.184.11:53824 > 202.188.238.154:https / Raw
# Ether / IP / TCP 10.106.184.11:65299 > 202.188.238.201:https A
# Ether / IP / UDP 202.188.238.154:https > 10.106.184.11:53824 / Raw
# Ether / IP / UDP 10.106.184.11:53824 > 202.188.238.154:https / Raw
# Ether / IP / TCP 10.106.184.11:65301 > 204.79.197.203:https FA
# Ether / IP / TCP 204.79.197.203:https > 10.106.184.11:65301 A / Padding
# Ether / IP / TCP 204.79.197.203:https > 10.106.184.11:65301 RA / Padding
# Ether / IP / TCP 13.107.6.158:https > 10.106.184.11:65262 RA / Padding
# 802.3 00:0a:b8:30:d5:8a > 01:80:c2:00:00:00 / LLC / STP / Raw / Padding
# Ether / IP / TCP 13.107.42.254:https > 10.106.184.11:65265 RA / Padding
# Ether / IP / TCP 10.106.184.11:65258 > 13.69.116.104:https A / Raw
# Ether / IP / TCP 13.69.116.104:https > 10.106.184.11:65258 A
# Ether / IP / TCP 10.106.184.11:65454 > 10.106.184.235:ms_do S
# Ether / IP / TCP 10.106.184.11:65455 > 10.106.184.237:ms_do S
# Ether / IP / TCP 10.106.184.235:ms_do > 10.106.184.11:65454 SA
# Ether / IP / TCP 10.106.184.11:65454 > 10.106.184.235:ms_do A
# Ether / IP / TCP 10.106.184.11:65454 > 10.106.184.235:ms_do PA / Raw
# Ether / IP / TCP 10.106.184.235:ms_do > 10.106.184.11:65454 PA / Raw
# Ether / IP / TCP 10.106.184.11:65454 > 10.106.184.235:ms_do PA / Raw
# Ether / IP / TCP 10.106.184.237:ms_do > 10.106.184.11:65455 SA
# Ether / IP / TCP 10.106.184.11:65455 > 10.106.184.237:ms_do A
# Ether / IP / TCP 10.106.184.11:65455 > 10.106.184.237:ms_do PA / Raw
# Ether / IP / TCP 10.106.184.235:ms_do > 10.106.184.11:65454 PA / Raw
# Ether / IP / TCP 10.106.184.235:ms_do > 10.106.184.11:65454 FA / Padding
# Ether / IP / TCP 10.106.184.11:65454 > 10.106.184.235:ms_do A
# Ether / IP / TCP 10.106.184.11:65454 > 10.106.184.235:ms_do FA
# Ether / IP / TCP 10.106.184.235:ms_do > 10.106.184.11:65454 A / Padding
# Ether / IP / TCP 10.106.184.237:ms_do > 10.106.184.11:65455 FA / Padding
# Ether / IP / TCP 10.106.184.11:65455 > 10.106.184.237:ms_do A
# Ether / IP / TCP 10.106.184.11:65455 > 10.106.184.237:ms_do FA
# Ether / IP / TCP 10.106.184.237:ms_do > 10.106.184.11:65455 A / Padding
# 802.3 00:0a:b8:30:d5:8a > 01:80:c2:00:00:00 / LLC / STP / Raw / Padding
# Ether / IP / TCP 203.106.94.147:https > 10.106.184.11:65260 PA / Raw
# Ether / IP / TCP 203.106.94.147:https > 10.106.184.11:65260 FA / Padding
# Ether / IP / TCP 10.106.184.11:65260 > 203.106.94.147:https A
# Ether / IP / TCP 13.107.4.254:https > 10.106.184.11:65266 RA / Padding
# Ether / IP / TCP 204.79.197.222:https > 10.106.184.11:65267 RA / Padding
# 802.3 00:0a:b8:30:d5:8a > 01:80:c2:00:00:00 / LLC / STP / Raw / Padding
# Ether / IP / TCP 204.79.197.254:https > 10.106.184.11:65264 RA / Padding
# Ether / IP / TCP 10.106.184.11:65273 > 52.111.240.35:https PA / Raw
# Ether / IP / TCP 10.106.184.11:65273 > 52.111.240.35:https PA / Raw
# Ether / IP / TCP 10.106.184.11:65273 > 52.111.240.35:https PA / Raw
# Ether / IP / TCP 52.111.240.35:https > 10.106.184.11:65273 A / Padding
# Ether / IP / TCP 52.111.240.35:https > 10.106.184.11:65273 PA / Raw
# Ether / IP / TCP 52.111.240.35:https > 10.106.184.11:65273 PA / Raw
# Ether / IP / TCP 10.106.184.11:65273 > 52.111.240.35:https A
# Ether / IP / TCP 52.111.240.35:https > 10.106.184.11:65273 A / Raw
# Ether / IP / TCP 52.111.240.35:https > 10.106.184.11:65273 PA / Raw
# Ether / IP / TCP 10.106.184.11:65273 > 52.111.240.35:https A
# Ether / IP / TCP 52.111.240.35:https > 10.106.184.11:65273 PA / Raw
# Ether / IP / TCP 10.106.184.11:65273 > 52.111.240.35:https PA / Raw
# Ether / IP / TCP 52.111.240.35:https > 10.106.184.11:65273 A / Padding
# Ether / IP / TCP 10.106.184.11:65456 > 10.106.184.237:ms_do S
# Ether / IP / TCP 10.106.184.237:ms_do > 10.106.184.11:65456 SA
# Ether / IP / TCP 10.106.184.11:65456 > 10.106.184.237:ms_do A
# Ether / IP / TCP 10.106.184.11:65456 > 10.106.184.237:ms_do PA / Raw
# Ether / IP / TCP 10.106.184.237:ms_do > 10.106.184.11:65456 FA / Padding
# Ether / IP / TCP 10.106.184.11:65456 > 10.106.184.237:ms_do A
# Ether / IP / TCP 10.106.184.11:65456 > 10.106.184.237:ms_do FA
# Ether / IP / TCP 10.106.184.237:ms_do > 10.106.184.11:65456 A / Padding
# 802.3 00:0a:b8:30:d5:8a > 01:80:c2:00:00:00 / LLC / STP / Raw / Padding
# Ether / IP / UDP 203.106.94.152:https > 10.106.184.11:56912 / Raw
# Ether / IP / UDP 203.106.94.152:https > 10.106.184.11:56912 / Raw
# Ether / IP / UDP 10.106.184.11:56912 > 203.106.94.152:https / Raw
# Ether / IP / UDP 203.106.94.152:https > 10.106.184.11:56912 / Raw
# Ether / IP / UDP 10.106.184.11:56912 > 203.106.94.152:https / Raw
# 802.3 00:0a:b8:30:d5:8a > 01:80:c2:00:00:00 / LLC / STP / Raw / Padding
# Ether / IP / TCP 10.106.184.11:65275 > 13.107.21.239:https A / Raw
# Ether / IP / TCP 13.107.21.239:https > 10.106.184.11:65275 A
# 802.3 00:0a:b8:30:d5:8a > 01:80:c2:00:00:00 / LLC / STP / Raw / Padding
# 802.3 00:0a:b8:30:d5:8a > 01:80:c2:00:00:00 / LLC / STP / Raw / Padding
# Ether / IP / UDP / DNS Qry b'array621.prod.do.dsp.mp.microsoft.com.'
# Ether / IP / UDP / DNS Ans 40.69.76.189
# Ether / IP / TCP 10.106.184.11:65457 > 40.69.76.189:https S
# Ether / IP / TCP 40.69.76.189:https > 10.106.184.11:65457 SA
# Ether / IP / TCP 10.106.184.11:65457 > 40.69.76.189:https A
# Ether / IP / TCP 10.106.184.11:65457 > 40.69.76.189:https PA / Raw
# Ether / IP / TCP 40.69.76.189:https > 10.106.184.11:65457 A / Raw
# Ether / IP / TCP 40.69.76.189:https > 10.106.184.11:65457 PA / Raw
# Ether / IP / TCP 10.106.184.11:65457 > 40.69.76.189:https A
# Ether / IP / TCP 10.106.184.11:65457 > 40.69.76.189:https PA / Raw
# Ether / IP / TCP 40.69.76.189:https > 10.106.184.11:65457 PA / Raw
# Ether / IP / TCP 40.69.76.189:https > 10.106.184.11:65457 PA / Raw
# Ether / IP / TCP 10.106.184.11:65457 > 40.69.76.189:https A
# Ether / IP / TCP 10.106.184.11:65457 > 40.69.76.189:https PA / Raw
# Ether / IP / TCP 10.106.184.11:65457 > 40.69.76.189:https PA / Raw
# Ether / IP / TCP 10.106.184.11:65457 > 40.69.76.189:https PA / Raw
# Ether / IP / TCP 10.106.184.11:65457 > 40.69.76.189:https PA / Raw
# Ether / IP / TCP 40.69.76.189:https > 10.106.184.11:65457 A / Padding
# Ether / IP / TCP 40.69.76.189:https > 10.106.184.11:65457 PA / Raw
# Ether / IP / TCP 40.69.76.189:https > 10.106.184.11:65457 A / Padding
# Ether / IP / TCP 40.69.76.189:https > 10.106.184.11:65457 PA / Raw
# Ether / IP / TCP 10.106.184.11:65457 > 40.69.76.189:https A
# Ether / IP / TCP 40.69.76.189:https > 10.106.184.11:65457 PA / Raw
# Ether / IP / UDP / DNS Qry b'kv601.prod.do.dsp.mp.microsoft.com.'
# Ether / IP / UDP / DNS Ans b'kv601.prod.do.dsp.mp.microsoft.com.edgekey.net.'
# Ether / IP / TCP 10.106.184.11:65458 > 23.220.242.47:https S
# Ether / IP / TCP 23.220.242.47:https > 10.106.184.11:65458 SA
# Ether / IP / TCP 10.106.184.11:65458 > 23.220.242.47:https A
# Ether / IP / TCP 10.106.184.11:65458 > 23.220.242.47:https PA / Raw
# Ether / IP / TCP 23.220.242.47:https > 10.106.184.11:65458 A / Padding
# Ether / IP / TCP 23.220.242.47:https > 10.106.184.11:65458 A / Raw
# Ether / IP / TCP 23.220.242.47:https > 10.106.184.11:65458 PA / Raw
# Ether / IP / TCP 10.106.184.11:65458 > 23.220.242.47:https A
# Ether / IP / TCP 23.220.242.47:https > 10.106.184.11:65458 PA / Raw
# Ether / IP / TCP 23.220.242.47:https > 10.106.184.11:65458 A / Raw
# Ether / IP / TCP 10.106.184.11:65458 > 23.220.242.47:https A
# Ether / IP / TCP 23.220.242.47:https > 10.106.184.11:65458 PA / Raw
# Ether / IP / TCP 10.106.184.11:65458 > 23.220.242.47:https PA / Raw
# Ether / IP / TCP 23.220.242.47:https > 10.106.184.11:65458 PA / Raw
# Ether / IP / TCP 10.106.184.11:65458 > 23.220.242.47:https PA / Raw
# Ether / IP / TCP 23.220.242.47:https > 10.106.184.11:65458 PA / Raw
# Ether / IP / TCP 10.106.184.11:65457 > 40.69.76.189:https A
# Ether / IP / TCP 10.106.184.11:65458 > 23.220.242.47:https A
# 802.3 00:0a:b8:30:d5:8a > 01:80:c2:00:00:00 / LLC / STP / Raw / Padding
# 802.3 00:0a:b8:30:d5:8a > 01:80:c2:00:00:00 / LLC / STP / Raw / Padding
# Ether / IP / UDP 203.106.94.152:https > 10.106.184.11:56912 / Raw
# Ether / IP / UDP 202.188.238.154:https > 10.106.184.11:53824 / Raw
# Ether / IP / UDP 10.106.184.11:53824 > 202.188.238.154:https / Raw
# 802.3 00:0a:b8:30:d5:8a > 01:80:c2:00:00:00 / LLC / STP / Raw / Padding
# Ether / IP / UDP 202.188.238.154:https > 10.106.184.11:53824 / Raw
# Ether / IP / UDP 10.106.184.11:53824 > 202.188.238.154:https / Raw
# Ether / IP / TCP 118.215.103.18:http > 10.106.184.11:65294 FA / Padding
# Ether / IP / TCP 10.106.184.11:65294 > 118.215.103.18:http A
# Ether / IP / TCP 10.106.184.11:65294 > 118.215.103.18:http FA
# Ether / IP / TCP 118.215.103.18:http > 10.106.184.11:65294 A / Padding
# 802.3 00:0a:b8:30:d5:8a > 01:80:c2:00:00:00 / LLC / STP / Raw / Padding
# 802.3 00:0a:b8:30:d5:8a > 01:80:c2:00:00:00 / LLC / STP / Raw / Padding
# Ether / IP / TCP 10.106.184.11:65459 > 40.69.76.189:https S
# Ether / IP / TCP 40.69.76.189:https > 10.106.184.11:65459 SA
# Ether / IP / TCP 10.106.184.11:65459 > 40.69.76.189:https A
# Ether / IP / TCP 10.106.184.11:65459 > 40.69.76.189:https PA / Raw
# Ether / IP / TCP 40.69.76.189:https > 10.106.184.11:65459 A / Raw
# Ether / IP / TCP 40.69.76.189:https > 10.106.184.11:65459 PA / Raw
# Ether / IP / TCP 10.106.184.11:65459 > 40.69.76.189:https A
# Ether / IP / TCP 10.106.184.11:65459 > 40.69.76.189:https PA / Raw
# Ether / IP / TCP 40.69.76.189:https > 10.106.184.11:65459 PA / Raw
# Ether / IP / TCP 40.69.76.189:https > 10.106.184.11:65459 PA / Raw
# Ether / IP / TCP 10.106.184.11:65459 > 40.69.76.189:https A
# Ether / IP / TCP 10.106.184.11:65459 > 40.69.76.189:https PA / Raw
# Ether / IP / TCP 10.106.184.11:65459 > 40.69.76.189:https PA / Raw
# Ether / IP / TCP 10.106.184.11:65459 > 40.69.76.189:https PA / Raw
# Ether / IP / TCP 10.106.184.11:65459 > 40.69.76.189:https PA / Raw
# Ether / IP / TCP 40.69.76.189:https > 10.106.184.11:65459 A / Padding
# Ether / IP / TCP 40.69.76.189:https > 10.106.184.11:65459 PA / Raw
# Ether / IP / TCP 40.69.76.189:https > 10.106.184.11:65459 PA / Raw
# Ether / IP / TCP 10.106.184.11:65459 > 40.69.76.189:https A
# Ether / IP / TCP 40.69.76.189:https > 10.106.184.11:65459 PA / Raw
# Ether / IP / TCP 10.106.184.11:65460 > 23.220.242.47:https S
# Ether / IP / TCP 23.220.242.47:https > 10.106.184.11:65460 SA
# Ether / IP / TCP 10.106.184.11:65460 > 23.220.242.47:https A
# Ether / IP / TCP 10.106.184.11:65460 > 23.220.242.47:https PA / Raw
# Ether / IP / TCP 23.220.242.47:https > 10.106.184.11:65460 A / Padding
# Ether / IP / TCP 23.220.242.47:https > 10.106.184.11:65460 A / Raw
# Ether / IP / TCP 23.220.242.47:https > 10.106.184.11:65460 PA / Raw
# Ether / IP / TCP 10.106.184.11:65460 > 23.220.242.47:https A
# Ether / IP / TCP 23.220.242.47:https > 10.106.184.11:65460 PA / Raw
# Ether / IP / TCP 23.220.242.47:https > 10.106.184.11:65460 A / Raw
# Ether / IP / TCP 10.106.184.11:65460 > 23.220.242.47:https A
# Ether / IP / TCP 23.220.242.47:https > 10.106.184.11:65460 PA / Raw
# Ether / IP / TCP 10.106.184.11:65460 > 23.220.242.47:https PA / Raw
# Ether / IP / TCP 23.220.242.47:https > 10.106.184.11:65460 PA / Raw
# Ether / IP / TCP 10.106.184.11:65460 > 23.220.242.47:https PA / Raw
# Ether / IP / TCP 23.220.242.47:https > 10.106.184.11:65460 PA / Raw
# Ether / IP / TCP 10.106.184.11:65459 > 40.69.76.189:https A
# Ether / IP / TCP 10.106.184.11:65460 > 23.220.242.47:https A
# 802.3 00:0a:b8:30:d5:8a > 01:80:c2:00:00:00 / LLC / STP / Raw / Padding
# 802.3 00:0a:b8:30:d5:8a > 01:80:c2:00:00:00 / LLC / STP / Raw / Padding
# Ether / IP / UDP 10.106.184.11:58877 > 203.106.94.144:https / Raw
# Ether / IP / UDP 10.106.184.11:58877 > 203.106.94.144:https / Raw
# Ether / IP / UDP 10.106.184.11:58877 > 203.106.94.144:https / Raw
# Ether / IP / UDP / DNS Qry b'wpad.mmu.edu.my.'
# Ether / IP / UDP / DNS Ans name-error
# Ether / IP / UDP 203.106.94.144:https > 10.106.184.11:58877 / Raw
# Ether / IP / UDP 203.106.94.144:https > 10.106.184.11:58877 / Raw
# Ether / IP / UDP 203.106.94.144:https > 10.106.184.11:58877 / Raw
# Ether / IP / UDP 10.106.184.11:58877 > 203.106.94.144:https / Raw
# Ether / IP / UDP 10.106.184.11:58877 > 203.106.94.144:https / Raw
# Ether / IP / UDP 10.106.184.11:58877 > 203.106.94.144:https / Raw
# Ether / IP / UDP 10.106.184.11:58877 > 203.106.94.144:https / Raw
# Ether / IP / UDP 10.106.184.11:58877 > 203.106.94.144:https / Raw
# Ether / IP / UDP 203.106.94.144:https > 10.106.184.11:58877 / Raw
# Ether / IP / UDP 203.106.94.144:https > 10.106.184.11:58877 / Raw
# Ether / IP / UDP 203.106.94.144:https > 10.106.184.11:58877 / Raw
# Ether / IP / UDP 10.106.184.11:58877 > 203.106.94.144:https / Raw
# Ether / IP / UDP 203.106.94.144:https > 10.106.184.11:58877 / Raw
# Ether / IP / UDP 10.106.184.11:58877 > 203.106.94.144:https / Raw
# Ether / IP / UDP 203.106.94.144:https > 10.106.184.11:58877 / Raw
# Ether / IP / TCP 10.106.184.11:65284 > 204.79.197.203:https A / Raw
# Ether / IP / TCP 204.79.197.203:https > 10.106.184.11:65284 A
# Ether / IP / UDP 203.106.94.144:https > 10.106.184.11:58877 / Raw
# Ether / IP / UDP 10.106.184.11:58877 > 203.106.94.144:https / Raw
# Ether / IP / TCP 10.106.184.11:65287 > 18.161.180.87:https A / Raw
# Ether / IP / TCP 18.161.180.87:https > 10.106.184.11:65287 A
# Ether / IP / UDP 10.106.184.11:58877 > 203.106.94.144:https / Raw
# Ether / IP / UDP 203.106.94.144:https > 10.106.184.11:58877 / Raw
# Ether / IP / TCP 10.106.184.11:65289 > 150.171.27.10:https A / Raw
# Ether / IP / TCP 150.171.27.10:https > 10.106.184.11:65289 A
# Ether / IP / UDP 203.106.94.144:https > 10.106.184.11:58877 / Raw
# Ether / IP / UDP 203.106.94.144:https > 10.106.184.11:58877 / Raw
# Ether / IP / UDP 10.106.184.11:58877 > 203.106.94.144:https / Raw
# Ether / IP / UDP 203.106.94.144:https > 10.106.184.11:58877 / Raw
# Ether / IP / TCP 10.106.184.11:65286 > 52.231.230.148:https A / Raw
# Ether / IP / TCP 52.231.230.148:https > 10.106.184.11:65286 A
# Ether / IP / TCP 10.106.184.11:65297 > 23.220.240.182:https A / Raw
# Ether / IP / TCP 23.220.240.182:https > 10.106.184.11:65297 A
# Ether / IP / TCP 10.106.184.11:65288 > 204.79.197.203:https A / Raw
# Ether / IP / TCP 204.79.197.203:https > 10.106.184.11:65288 A
# Ether / IP / UDP 202.188.238.154:https > 10.106.184.11:53824 / Raw
# 802.3 00:0a:b8:30:d5:8a > 01:80:c2:00:00:00 / LLC / STP / Raw / Padding
# Ether / IP / TCP 10.106.184.11:65303 > 40.126.35.153:https A / Raw
# Ether / IP / TCP 40.126.35.153:https > 10.106.184.11:65303 A
# Ether / IP / TCP 10.106.184.11:65298 > 20.42.65.90:https A / Raw
# Ether / IP / TCP 20.42.65.90:https > 10.106.184.11:65298 A
# Ether / IP / TCP 10.106.184.11:65302 > 13.107.6.158:https A / Raw
# Ether / IP / TCP 13.107.6.158:https > 10.106.184.11:65302 A
# Ether / IP / TCP 51.116.253.169:https > 10.106.184.11:65259 RA / Padding
# Ether / IP / TCP 10.106.184.11:65253 > 20.212.88.117:https A / Raw
# Ether / IP / TCP 20.212.88.117:https > 10.106.184.11:65253 A
# Ether / IP / TCP 10.106.184.11:65300 > 204.79.197.203:https A / Raw
# Ether / IP / TCP 204.79.197.203:https > 10.106.184.11:65300 A
# 802.3 00:0a:b8:30:d5:8a > 01:80:c2:00:00:00 / LLC / STP / Raw / Padding
# Ether / IP / TCP 10.106.184.11:65285 > 20.42.65.90:https A / Raw
# Ether / IP / TCP 10.106.184.11:65304 > 57.155.146.244:https A / Raw
# Ether / IP / TCP 57.155.146.244:https > 10.106.184.11:65304 A
# Ether / IP / TCP 20.42.65.90:https > 10.106.184.11:65285 A
# Ether / IP / TCP 10.106.184.235:57152 > 10.106.184.11:ms_do S
# Ether / IP / TCP 10.106.184.11:ms_do > 10.106.184.235:57152 SA
# Ether / IP / TCP 10.106.184.235:57152 > 10.106.184.11:ms_do A / Padding
# Ether / IP / TCP 10.106.184.235:57152 > 10.106.184.11:ms_do PA / Raw
# Ether / IP / TCP 10.106.184.11:ms_do > 10.106.184.235:57152 FA
# Ether / IP / TCP 10.106.184.235:57152 > 10.106.184.11:ms_do A / Padding
# Ether / IP / TCP 10.106.184.235:57152 > 10.106.184.11:ms_do FA / Padding
# Ether / IP / TCP 10.106.184.11:ms_do > 10.106.184.235:57152 A
# 802.3 00:0a:b8:30:d5:8a > 01:80:c2:00:00:00 / LLC / STP / Raw / Padding
# 802.3 00:0a:b8:30:d5:8a > 01:80:c2:00:00:00 / LLC / STP / Raw / Padding
# Ether / IP / TCP 10.106.184.11:49922 > 20.198.119.84:https PA / Raw
# Ether / IP / TCP 20.198.119.84:https > 10.106.184.11:49922 PA / Raw
# 802.3 00:0a:b8:30:d5:8a > 01:80:c2:00:00:00 / LLC / STP / Raw / Padding
# Ether / IP / TCP 10.106.184.11:64926 > 203.106.94.176:https A / Raw
# Ether / IP / TCP 203.106.94.176:https > 10.106.184.11:64926 A
# Ether / IP / TCP 10.106.184.11:49922 > 20.198.119.84:https A
# Ether / IP / TCP 10.106.184.11:65461 > 204.79.197.203:https S
# Ether / IP / TCP 204.79.197.203:https > 10.106.184.11:65461 SA
# Ether / IP / TCP 10.106.184.11:65461 > 204.79.197.203:https A
# Ether / IP / TCP 10.106.184.11:65461 > 204.79.197.203:https PA / Raw
# Ether / IP / TCP 204.79.197.203:https > 10.106.184.11:65461 A / Padding
# Ether / IP / TCP 204.79.197.203:https > 10.106.184.11:65461 A / Raw
# Ether / IP / TCP 10.106.184.11:65461 > 204.79.197.203:https A
# Ether / IP / TCP 204.79.197.203:https > 10.106.184.11:65461 A / Raw
# Ether / IP / TCP 10.106.184.11:65461 > 204.79.197.203:https A
# Ether / IP / TCP 204.79.197.203:https > 10.106.184.11:65461 A / Raw
# Ether / IP / TCP 10.106.184.11:65461 > 204.79.197.203:https A
# Ether / IP / TCP 204.79.197.203:https > 10.106.184.11:65461 A / Raw
# Ether / IP / TCP 10.106.184.11:65461 > 204.79.197.203:https A
# Ether / IP / TCP 204.79.197.203:https > 10.106.184.11:65461 PA / Raw
# Ether / IP / TCP 10.106.184.11:65461 > 204.79.197.203:https A
# Ether / IP / TCP 10.106.184.11:65461 > 204.79.197.203:https PA / Raw
# Ether / IP / TCP 10.106.184.11:65461 > 204.79.197.203:https PA / Raw
# Ether / IP / TCP 10.106.184.11:65461 > 204.79.197.203:https PA / Raw
# Ether / IP / TCP 204.79.197.203:https > 10.106.184.11:65461 A / Padding
# Ether / IP / TCP 204.79.197.203:https > 10.106.184.11:65461 A / Padding
# Ether / IP / TCP 204.79.197.203:https > 10.106.184.11:65461 PA / Raw
# Ether / IP / TCP 10.106.184.11:65461 > 204.79.197.203:https A
# Ether / IP / TCP 204.79.197.203:https > 10.106.184.11:65461 PA / Raw
# Ether / IP / TCP 10.106.184.11:65461 > 204.79.197.203:https A
# Ether / IP / TCP 10.106.184.11:65461 > 204.79.197.203:https PA / Raw
# Ether / IP / TCP 204.79.197.203:https > 10.106.184.11:65461 PA / Raw
# Ether / IP / TCP 10.106.184.11:65461 > 204.79.197.203:https A
# Ether / IP / TCP 204.79.197.203:https > 10.106.184.11:65461 A / Padding
# Ether / IP / TCP 204.79.197.203:https > 10.106.184.11:65461 A / Padding
# Ether / IP / TCP 204.79.197.203:https > 10.106.184.11:65461 A / Padding
# Ether / IP / TCP 204.79.197.203:https > 10.106.184.11:65461 A / Raw
# Ether / IP / TCP 204.79.197.203:https > 10.106.184.11:65461 A / Raw
# Ether / IP / TCP 204.79.197.203:https > 10.106.184.11:65461 PA / Raw
# Ether / IP / TCP 10.106.184.11:65461 > 204.79.197.203:https A
# Ether / IP / TCP 204.79.197.203:https > 10.106.184.11:65461 A / Raw
# Ether / IP / TCP 204.79.197.203:https > 10.106.184.11:65461 PA / Raw
# Ether / IP / TCP 10.106.184.11:65461 > 204.79.197.203:https A
# Ether / IP / TCP 204.79.197.203:https > 10.106.184.11:65461 A / Raw
# Ether / IP / TCP 10.106.184.11:65461 > 204.79.197.203:https A
# Ether / IP / TCP 204.79.197.203:https > 10.106.184.11:65461 PA / Raw
# Ether / IP / TCP 10.106.184.11:65461 > 204.79.197.203:https A
# Ether / IP / TCP 204.79.197.203:https > 10.106.184.11:65461 A / Raw
# Ether / IP / TCP 10.106.184.11:65461 > 204.79.197.203:https A
# Ether / IP / TCP 204.79.197.203:https > 10.106.184.11:65461 A / Raw
# Ether / IP / TCP 10.106.184.11:65461 > 204.79.197.203:https A
# Ether / IP / TCP 204.79.197.203:https > 10.106.184.11:65461 PA / Raw
# Ether / IP / TCP 204.79.197.203:https > 10.106.184.11:65461 PA / Raw
# Ether / IP / TCP 10.106.184.11:65461 > 204.79.197.203:https A
# Ether / IP / TCP 204.79.197.203:https > 10.106.184.11:65461 PA / Raw
# Ether / IP / TCP 10.106.184.11:65461 > 204.79.197.203:https A
# Ether / IP / TCP 204.79.197.203:https > 10.106.184.11:65461 A / Raw
# Ether / IP / TCP 10.106.184.11:65461 > 204.79.197.203:https A
# Ether / IP / TCP 204.79.197.203:https > 10.106.184.11:65461 A / Raw
# Ether / IP / TCP 10.106.184.11:65461 > 204.79.197.203:https A
# Ether / IP / TCP 204.79.197.203:https > 10.106.184.11:65461 PA / Raw
# Ether / IP / TCP 204.79.197.203:https > 10.106.184.11:65461 PA / Raw
# Ether / IP / TCP 10.106.184.11:65461 > 204.79.197.203:https A
# Ether / IP / TCP 204.79.197.203:https > 10.106.184.11:65461 A / Raw
# Ether / IP / TCP 10.106.184.11:65461 > 204.79.197.203:https A
# Ether / IP / TCP 204.79.197.203:https > 10.106.184.11:65461 A / Raw
# Ether / IP / TCP 10.106.184.11:65461 > 204.79.197.203:https A
# Ether / IP / TCP 204.79.197.203:https > 10.106.184.11:65461 PA / Raw
# Ether / IP / TCP 204.79.197.203:https > 10.106.184.11:65461 PA / Raw
# Ether / IP / TCP 10.106.184.11:65461 > 204.79.197.203:https A
# Ether / IP / UDP / DNS Qry b'wpad.mmu.edu.my.'
# Ether / IP / UDP / DNS Ans name-error
# 802.3 00:0a:b8:30:d5:8a > 01:80:c2:00:00:00 / LLC / STP / Raw / Padding
# Ether / IP / UDP / DNS Qry b'wpad.mmu.edu.my.'
# Ether / IP / UDP / DNS Ans name-error
# Ether / IP / TCP 10.106.184.11:65274 > 13.107.21.239:https A / Raw
# Ether / IP / TCP 13.107.21.239:https > 10.106.184.11:65274 A
# 802.3 00:0a:b8:30:d5:8a > 01:80:c2:00:00:00 / LLC / STP / Raw / Padding
# Ether / IP / TCP 10.106.184.11:65462 > 10.106.184.235:ms_do S
# Ether / IP / TCP 10.106.184.11:65463 > 10.106.184.237:ms_do S
# Ether / IP / TCP 10.106.184.235:ms_do > 10.106.184.11:65462 SA
# Ether / IP / TCP 10.106.184.11:65462 > 10.106.184.235:ms_do A
# Ether / IP / TCP 10.106.184.11:65462 > 10.106.184.235:ms_do PA / Raw
# Ether / IP / TCP 10.106.184.235:ms_do > 10.106.184.11:65462 PA / Raw
# Ether / IP / TCP 10.106.184.11:65462 > 10.106.184.235:ms_do PA / Raw
# Ether / IP / TCP 10.106.184.235:ms_do > 10.106.184.11:65462 PA / Raw
# Ether / IP / TCP 10.106.184.235:ms_do > 10.106.184.11:65462 FA / Padding
# Ether / IP / TCP 10.106.184.11:65462 > 10.106.184.235:ms_do A
# Ether / IP / TCP 10.106.184.11:65462 > 10.106.184.235:ms_do FA
# Ether / IP / TCP 10.106.184.235:ms_do > 10.106.184.11:65462 A / Padding
# Ether / IP / TCP 10.106.184.237:ms_do > 10.106.184.11:65463 SA
# Ether / IP / TCP 10.106.184.11:65463 > 10.106.184.237:ms_do A
# Ether / IP / TCP 10.106.184.11:65463 > 10.106.184.237:ms_do PA / Raw
# Ether / IP / TCP 10.106.184.237:ms_do > 10.106.184.11:65463 FA / Padding
# Ether / IP / TCP 10.106.184.11:65463 > 10.106.184.237:ms_do A
# Ether / IP / TCP 10.106.184.11:65463 > 10.106.184.237:ms_do FA
# Ether / IP / TCP 10.106.184.237:ms_do > 10.106.184.11:65463 A / Padding
# 802.3 00:0a:b8:30:d5:8a > 01:80:c2:00:00:00 / LLC / STP / Raw / Padding
# Ether / IP / TCP 10.106.184.11:65299 > 202.188.238.201:https A / Raw
# Ether / IP / TCP 202.188.238.201:https > 10.106.184.11:65299 A
# Ether / IP / TCP 13.107.21.239:https > 10.106.184.11:65275 RA / Padding
# 802.3 00:0a:b8:30:d5:8a > 01:80:c2:00:00:00 / LLC / STP / Raw / Padding
# Ether / IP / TCP 10.106.184.11:65464 > 10.106.184.237:ms_do S
# Ether / IP / TCP 10.106.184.237:ms_do > 10.106.184.11:65464 SA
# Ether / IP / TCP 10.106.184.11:65464 > 10.106.184.237:ms_do A
# Ether / IP / TCP 10.106.184.11:65464 > 10.106.184.237:ms_do PA / Raw
# Ether / IP / TCP 10.106.184.237:ms_do > 10.106.184.11:65464 FA / Padding
# Ether / IP / TCP 10.106.184.11:65464 > 10.106.184.237:ms_do A
# Ether / IP / TCP 10.106.184.11:65464 > 10.106.184.237:ms_do FA
# Ether / IP / TCP 10.106.184.237:ms_do > 10.106.184.11:65464 A / Padding
# 802.3 00:0a:b8:30:d5:8a > 01:80:c2:00:00:00 / LLC / STP / Raw / Padding
# Ether / IP / TCP 10.106.184.11:65258 > 13.69.116.104:https A / Raw
# Ether / IP / UDP / DNS Qry b'www.bing.com.'
# Ether / IP / UDP / DNS Ans b'www-www.bing.com.trafficmanager.net.'
# Ether / IP / UDP 10.106.184.11:55190 > 203.106.94.155:https / Raw
# Ether / IP / UDP 10.106.184.11:55190 > 203.106.94.155:https / Raw
# Ether / IP / UDP 10.106.184.11:55190 > 203.106.94.155:https / Raw
# Ether / IP / UDP 203.106.94.155:https > 10.106.184.11:55190 / Raw
# Ether / IP / UDP 203.106.94.155:https > 10.106.184.11:55190 / Raw
# Ether / IP / UDP 203.106.94.155:https > 10.106.184.11:55190 / Raw
# Ether / IP / UDP 10.106.184.11:55190 > 203.106.94.155:https / Raw
# Ether / IP / UDP 203.106.94.155:https > 10.106.184.11:55190 / Raw
# Ether / IP / UDP 10.106.184.11:55190 > 203.106.94.155:https / Raw
# Ether / IP / UDP 203.106.94.155:https > 10.106.184.11:55190 / Raw
# Ether / IP / UDP 203.106.94.155:https > 10.106.184.11:55190 / Raw
# Ether / IP / UDP 203.106.94.155:https > 10.106.184.11:55190 / Raw
# Ether / IP / UDP 203.106.94.155:https > 10.106.184.11:55190 / Raw
# Ether / IP / UDP 10.106.184.11:55190 > 203.106.94.155:https / Raw
# Ether / IP / UDP 10.106.184.11:55190 > 203.106.94.155:https / Raw
# Ether / IP / UDP 203.106.94.155:https > 10.106.184.11:55190 / Raw
# Ether / IP / TCP 13.69.116.104:https > 10.106.184.11:65258 A
# 802.3 00:0a:b8:30:d5:8a > 01:80:c2:00:00:00 / LLC / STP / Raw / Padding
# 802.3 00:0a:b8:30:d5:8a > 01:80:c2:00:00:00 / LLC / STP / Raw / Padding
# Ether / IP / TCP 10.106.184.11:65273 > 52.111.240.35:https A / Raw
# Ether / IP / TCP 52.111.240.35:https > 10.106.184.11:65273 A
# Ether / IP / TCP 203.106.94.176:https > 10.106.184.11:64926 PA / Raw
# Ether / IP / TCP 10.106.184.11:64926 > 203.106.94.176:https A
# 802.3 00:0a:b8:30:d5:8a > 01:80:c2:00:00:00 / LLC / STP / Raw / Padding
# 802.3 00:0a:b8:30:d5:8a > 01:80:c2:00:00:00 / LLC / STP / Raw / Padding
# 802.3 00:0a:b8:30:d5:8a > 01:00:0c:cc:cc:cc / LLC / SNAP / Raw
# Ether / IP / TCP 10.106.184.237:58425 > 10.106.184.11:ms_do S
# Ether / IP / TCP 10.106.184.11:ms_do > 10.106.184.237:58425 SA
# Ether / IP / TCP 10.106.184.237:58425 > 10.106.184.11:ms_do A / Padding
# Ether / IP / TCP 10.106.184.237:58425 > 10.106.184.11:ms_do PA / Raw
# Ether / IP / TCP 10.106.184.11:ms_do > 10.106.184.237:58425 FA
# Ether / IP / TCP 10.106.184.237:58425 > 10.106.184.11:ms_do A / Padding
# Ether / IP / TCP 10.106.184.237:58425 > 10.106.184.11:ms_do FA / Padding
# Ether / IP / TCP 10.106.184.11:ms_do > 10.106.184.237:58425 A
# 802.3 00:0a:b8:30:d5:8a > 01:80:c2:00:00:00 / LLC / STP / Raw / Padding
# Ether / IP / TCP 23.220.240.182:https > 10.106.184.11:65297 PA / Raw
# Ether / IP / TCP 23.220.240.182:https > 10.106.184.11:65297 FA / Padding
# Ether / IP / TCP 10.106.184.11:65297 > 23.220.240.182:https A
# Ether / IP / TCP 10.106.184.11:65297 > 23.220.240.182:https FA
# Ether / IP / TCP 23.220.240.182:https > 10.106.184.11:65297 A / Padding
# Ether / IP / TCP 4.144.165.14:https > 10.106.184.11:65263 PA / Raw
# Ether / IP / TCP 10.106.184.11:65263 > 4.144.165.14:https A
# Ether / IP / TCP 4.144.165.14:https > 10.106.184.11:65263 FPA / Raw
# Ether / IP / TCP 10.106.184.11:65263 > 4.144.165.14:https A
# Ether / IP / TCP 10.106.184.11:65263 > 4.144.165.14:https FA
# Ether / IP / TCP 4.144.165.14:https > 10.106.184.11:65263 A / Padding
# 802.3 00:0a:b8:30:d5:8a > 01:80:c2:00:00:00 / LLC / STP / Raw / Padding
# Ether / IP / TCP 20.212.88.117:https > 10.106.184.11:65253 PA / Raw
# Ether / IP / TCP 10.106.184.11:65253 > 20.212.88.117:https PA / Raw
# Ether / IP / TCP 20.212.88.117:https > 10.106.184.11:65253 A / Padding
# Ether / IP / TCP 52.231.230.148:https > 10.106.184.11:65286 RA / Padding
# 802.3 00:0a:b8:30:d5:8a > 01:80:c2:00:00:00 / LLC / STP / Raw / Padding
# Ether / IP / TCP 150.171.27.10:https > 10.106.184.11:65289 RA / Padding
# Ether / IP / TCP 40.126.35.153:https > 10.106.184.11:65303 RA / Padding
# 802.3 00:0a:b8:30:d5:8a > 01:80:c2:00:00:00 / LLC / STP / Raw / Padding
# Ether / IP / TCP 204.79.197.203:https > 10.106.184.11:65300 RA / Padding
# Ether / IP / TCP 204.79.197.203:https > 10.106.184.11:65284 RA / Padding
# Ether / IP / TCP 204.79.197.203:https > 10.106.184.11:65288 RA / Padding
# 802.3 00:0a:b8:30:d5:8a > 01:80:c2:00:00:00 / LLC / STP / Raw / Padding
# Ether / IP / UDP 203.106.94.155:https > 10.106.184.11:55190 / Raw
# Ether / IP / UDP 10.106.184.11:55190 > 203.106.94.155:https / Raw
# 802.3 00:0a:b8:30:d5:8a > 01:80:c2:00:00:00 / LLC / STP / Raw / Padding
# Ether / IP / UDP 203.106.94.155:https > 10.106.184.11:55190 / Raw
# Ether / IP / UDP 10.106.184.11:55190 > 203.106.94.155:https / Raw
# Ether / IP / UDP 203.106.94.155:https > 10.106.184.11:55190 / Raw
# Ether / IP / UDP 10.106.184.11:55190 > 203.106.94.155:https / Raw
# Ether / IP / TCP 13.107.6.158:https > 10.106.184.11:65302 RA / Padding
# 802.3 00:0a:b8:30:d5:8a > 01:80:c2:00:00:00 / LLC / STP / Raw / Padding
# Ether / IP / TCP 20.42.65.90:https > 10.106.184.11:65298 RA / Padding
# Ether / IP / TCP 20.42.65.90:https > 10.106.184.11:65285 RA / Padding
# 802.3 00:0a:b8:30:d5:8a > 01:80:c2:00:00:00 / LLC / STP / Raw / Padding
# Ether / IP / TCP 10.106.184.11:65287 > 18.161.180.87:https A / Raw
# Ether / IP / TCP 18.161.180.87:https > 10.106.184.11:65287 A
# Ether / IP / TCP 10.106.184.235:57153 > 10.106.184.11:ms_do S
# Ether / IP / TCP 10.106.184.11:ms_do > 10.106.184.235:57153 SA
# Ether / IP / TCP 10.106.184.235:57153 > 10.106.184.11:ms_do A / Padding
# Ether / IP / TCP 10.106.184.235:57153 > 10.106.184.11:ms_do PA / Raw
# Ether / IP / TCP 10.106.184.11:ms_do > 10.106.184.235:57153 FA
# Ether / IP / TCP 10.106.184.235:57153 > 10.106.184.11:ms_do A / Padding
# Ether / IP / TCP 10.106.184.235:57153 > 10.106.184.11:ms_do FA / Padding
# Ether / IP / TCP 10.106.184.11:ms_do > 10.106.184.235:57153 A
# 802.3 00:0a:b8:30:d5:8a > 01:80:c2:00:00:00 / LLC / STP / Raw / Padding
# Ether / IP / TCP 57.155.146.244:https > 10.106.184.11:65304 PA / Raw
# Ether / IP / TCP 10.106.184.11:65304 > 57.155.146.244:https FA
# Ether / IP / TCP 57.155.146.244:https > 10.106.184.11:65304 FA / Padding
# Ether / IP / TCP 10.106.184.11:65304 > 57.155.146.244:https A
# Ether / IP / TCP 57.155.146.244:https > 10.106.184.11:65304 A / Padding
# 802.3 00:0a:b8:30:d5:8a > 01:80:c2:00:00:00 / LLC / STP / Raw / Padding
# Ether / IP / TCP 203.106.94.176:https > 10.106.184.11:64926 PA / Raw
# Ether / IP / TCP 10.106.184.11:64926 > 203.106.94.176:https PA / Raw
# Ether / IP / TCP 203.106.94.176:https > 10.106.184.11:64926 A / Padding
# Ether / IP / TCP 203.106.94.176:https > 10.106.184.11:64926 PA / Raw
# Ether / IP / TCP 203.106.94.176:https > 10.106.184.11:64926 FA / Padding
# Ether / IP / TCP 10.106.184.11:64926 > 203.106.94.176:https A
# Ether / IP / TCP 10.106.184.11:64926 > 203.106.94.176:https FA
# Ether / IP / TCP 203.106.94.176:https > 10.106.184.11:64926 A / Padding
# Ether / IP / UDP 203.106.94.155:https > 10.106.184.11:55190 / Raw
# 802.3 00:0a:b8:30:d5:8a > 01:80:c2:00:00:00 / LLC / STP / Raw / Padding
# Ether / IP / UDP / DNS Qry b'substrate.office.com.'
# Ether / IP / UDP / DNS Ans b'outlook.office365.com.'
# Ether / IP / UDP 10.106.184.11:59440 > 40.99.10.82:https / Raw
# Ether / IP / UDP 10.106.184.11:59440 > 40.99.10.82:https / Raw
# Ether / IP / TCP 10.106.184.11:65465 > 40.99.10.82:https S
# Ether / IP / UDP 40.99.10.82:https > 10.106.184.11:59440 / Raw
# Ether / IP / UDP 10.106.184.11:59440 > 40.99.10.82:https / Raw
# Ether / IP / TCP 40.99.10.82:https > 10.106.184.11:65465 SA
# Ether / IP / TCP 10.106.184.11:65465 > 40.99.10.82:https A
# Ether / IP / TCP 10.106.184.11:65465 > 40.99.10.82:https PA / Raw
# Ether / IP / TCP 40.99.10.82:https > 10.106.184.11:65465 A / Padding
# Ether / IP / TCP 40.99.10.82:https > 10.106.184.11:65465 PA / Raw
# Ether / IP / TCP 10.106.184.11:65465 > 40.99.10.82:https PA / Raw
# Ether / IP / TCP 40.99.10.82:https > 10.106.184.11:65465 PA / Raw
# Ether / IP / TCP 10.106.184.11:65465 > 40.99.10.82:https PA / Raw
# Ether / IP / TCP 10.106.184.11:65465 > 40.99.10.82:https PA / Raw
# Ether / IP / TCP 10.106.184.11:65465 > 40.99.10.82:https PA / Raw
# Ether / IP / TCP 10.106.184.11:65465 > 40.99.10.82:https PA / Raw
# Ether / IP / TCP 40.99.10.82:https > 10.106.184.11:65465 A / Padding
# Ether / IP / TCP 40.99.10.82:https > 10.106.184.11:65465 PA / Raw
# Ether / IP / TCP 40.99.10.82:https > 10.106.184.11:65465 A / Padding
# Ether / IP / TCP 40.99.10.82:https > 10.106.184.11:65465 PA / Raw
# Ether / IP / TCP 10.106.184.11:65465 > 40.99.10.82:https A
# Ether / IP / TCP 10.106.184.11:65465 > 40.99.10.82:https PA / Raw
# Ether / IP / UDP 40.99.10.82:https > 10.106.184.11:59440 / Raw
# Ether / IP / UDP 10.106.184.11:59440 > 40.99.10.82:https / Raw
# Ether / IP / TCP 40.99.10.82:https > 10.106.184.11:65465 PA / Raw
# Ether / IP / UDP 40.99.10.82:https > 10.106.184.11:59440 / Raw
# Ether / IP / UDP 40.99.10.82:https > 10.106.184.11:59440 / Raw
# Ether / IP / UDP 10.106.184.11:59440 > 40.99.10.82:https / Raw
# Ether / IP / TCP 10.106.184.11:65465 > 40.99.10.82:https A
# Ether / IP / UDP 40.99.10.82:https > 10.106.184.11:59440 / Raw
# Ether / IP / UDP 10.106.184.11:59440 > 40.99.10.82:https / Raw
# Ether / IP / UDP 40.99.10.82:https > 10.106.184.11:59440 / Raw
# Ether / IP / TCP 40.99.10.82:https > 10.106.184.11:65465 PA / Raw
# Ether / IP / TCP 40.99.10.82:https > 10.106.184.11:65465 PA / Raw
# Ether / IP / TCP 10.106.184.11:65465 > 40.99.10.82:https A
# Ether / IP / TCP 40.99.10.82:https > 10.106.184.11:65465 PA / Raw
# Ether / IP / TCP 40.99.10.82:https > 10.106.184.11:65465 PA / Raw
# Ether / IP / TCP 10.106.184.11:65465 > 40.99.10.82:https A
# Ether / IP / UDP 10.106.184.11:59440 > 40.99.10.82:https / Raw
# Ether / IP / UDP 40.99.10.82:https > 10.106.184.11:59440 / Raw
# Ether / IP / UDP 10.106.184.11:59440 > 40.99.10.82:https / Raw
# 802.3 00:0a:b8:30:d5:8a > 01:80:c2:00:00:00 / LLC / STP / Raw / Padding
# 802.3 00:0a:b8:30:d5:8a > 01:80:c2:00:00:00 / LLC / STP / Raw / Padding
# Ether / IP / TCP 10.106.184.11:65466 > 10.106.184.235:ms_do S
# Ether / IP / TCP 10.106.184.11:65467 > 10.106.184.237:ms_do S
# Ether / IP / TCP 10.106.184.235:ms_do > 10.106.184.11:65466 SA
# Ether / IP / TCP 10.106.184.11:65466 > 10.106.184.235:ms_do A
# Ether / IP / TCP 10.106.184.11:65466 > 10.106.184.235:ms_do PA / Raw
# Ether / IP / TCP 10.106.184.235:ms_do > 10.106.184.11:65466 PA / Raw
# Ether / IP / TCP 10.106.184.11:65466 > 10.106.184.235:ms_do PA / Raw
# Ether / IP / TCP 10.106.184.235:ms_do > 10.106.184.11:65466 PA / Raw
# Ether / IP / TCP 10.106.184.237:ms_do > 10.106.184.11:65467 SA
# Ether / IP / TCP 10.106.184.11:65467 > 10.106.184.237:ms_do A
# Ether / IP / TCP 10.106.184.11:65467 > 10.106.184.237:ms_do PA / Raw
# Ether / IP / TCP 10.106.184.235:ms_do > 10.106.184.11:65466 FA / Padding
# Ether / IP / TCP 10.106.184.11:65466 > 10.106.184.235:ms_do A
# Ether / IP / TCP 10.106.184.11:65466 > 10.106.184.235:ms_do FA
# Ether / IP / TCP 10.106.184.235:ms_do > 10.106.184.11:65466 A / Padding
# Ether / IP / TCP 10.106.184.237:ms_do > 10.106.184.11:65467 FA / Padding
# Ether / IP / TCP 10.106.184.11:65467 > 10.106.184.237:ms_do A
# Ether / IP / TCP 10.106.184.11:65467 > 10.106.184.237:ms_do FA
# Ether / IP / TCP 10.106.184.237:ms_do > 10.106.184.11:65467 A / Padding
# 802.3 00:0a:b8:30:d5:8a > 01:80:c2:00:00:00 / LLC / STP / Raw / Padding
# Ether / IP / TCP 13.69.116.104:https > 10.106.184.11:65258 RA / Padding
# 802.3 00:0a:b8:30:d5:8a > 01:80:c2:00:00:00 / LLC / STP / Raw / Padding
# Ether / IP / TCP 10.106.184.11:65274 > 13.107.21.239:https A / Raw
# Ether / IP / TCP 13.107.21.239:https > 10.106.184.11:65274 A
# Ether / IP / TCP 10.106.184.11:65468 > 10.106.184.237:ms_do S
# Ether / IP / TCP 10.106.184.237:ms_do > 10.106.184.11:65468 SA
# Ether / IP / TCP 10.106.184.11:65468 > 10.106.184.237:ms_do A
# Ether / IP / TCP 10.106.184.11:65468 > 10.106.184.237:ms_do PA / Raw
# Ether / IP / TCP 10.106.184.237:ms_do > 10.106.184.11:65468 PA / Raw
# Ether / IP / TCP 10.106.184.11:65468 > 10.106.184.237:ms_do PA / Raw
# Ether / IP / TCP 10.106.184.237:ms_do > 10.106.184.11:65468 PA / Raw
# Ether / IP / TCP 10.106.184.237:ms_do > 10.106.184.11:65468 FA / Padding
# Ether / IP / TCP 10.106.184.11:65468 > 10.106.184.237:ms_do A
# Ether / IP / TCP 10.106.184.11:65468 > 10.106.184.237:ms_do FA
# Ether / IP / TCP 10.106.184.237:ms_do > 10.106.184.11:65468 A / Padding
# 802.3 00:0a:b8:30:d5:8a > 01:80:c2:00:00:00 / LLC / STP / Raw / Padding
# Ether / IP / UDP 10.106.184.11:53134 > 203.106.94.144:https / Raw
# Ether / IP / UDP 10.106.184.11:53134 > 203.106.94.144:https / Raw
# Ether / IP / UDP 10.106.184.11:53134 > 203.106.94.144:https / Raw
# Ether / IP / UDP 203.106.94.144:https > 10.106.184.11:53134 / Raw
# Ether / IP / UDP 203.106.94.144:https > 10.106.184.11:53134 / Raw
# Ether / IP / UDP 203.106.94.144:https > 10.106.184.11:53134 / Raw
# Ether / IP / UDP 10.106.184.11:53134 > 203.106.94.144:https / Raw
# Ether / IP / UDP 10.106.184.11:53134 > 203.106.94.144:https / Raw
# Ether / IP / UDP 10.106.184.11:53134 > 203.106.94.144:https / Raw
# Ether / IP / UDP 10.106.184.11:53134 > 203.106.94.144:https / Raw
# Ether / IP / UDP 203.106.94.144:https > 10.106.184.11:53134 / Raw
# Ether / IP / UDP 203.106.94.144:https > 10.106.184.11:53134 / Raw
# Ether / IP / UDP 10.106.184.11:53134 > 203.106.94.144:https / Raw
# Ether / IP / UDP 203.106.94.144:https > 10.106.184.11:53134 / Raw
# Ether / IP / UDP 203.106.94.144:https > 10.106.184.11:53134 / Raw
# Ether / IP / UDP 10.106.184.11:53134 > 203.106.94.144:https / Raw
# Ether / IP / UDP 203.106.94.144:https > 10.106.184.11:53134 / Raw
# Ether / IP / UDP 203.106.94.144:https > 10.106.184.11:53134 / Raw
# Ether / IP / UDP 203.106.94.144:https > 10.106.184.11:53134 / Raw
# Ether / IP / UDP 10.106.184.11:53134 > 203.106.94.144:https / Raw
# Ether / IP / UDP 10.106.184.11:53134 > 203.106.94.144:https / Raw
# Ether / IP / UDP 10.106.184.11:53134 > 203.106.94.144:https / Raw
# Ether / IP / UDP 203.106.94.144:https > 10.106.184.11:53134 / Raw
# Ether / IP / UDP 203.106.94.144:https > 10.106.184.11:53134 / Raw
# Ether / IP / UDP 203.106.94.144:https > 10.106.184.11:53134 / Raw
# Ether / IP / UDP 10.106.184.11:53134 > 203.106.94.144:https / Raw
# Ether / IP / UDP 203.106.94.144:https > 10.106.184.11:53134 / Raw
# Ether / IP / TCP 10.106.184.11:65299 > 202.188.238.201:https A / Raw
# Ether / IP / TCP 202.188.238.201:https > 10.106.184.11:65299 A
# 802.3 00:0a:b8:30:d5:8a > 01:80:c2:00:00:00 / LLC / STP / Raw / Padding
# 802.3 00:0a:b8:30:d5:8a > 01:80:c2:00:00:00 / LLC / STP / Raw / Padding
# 802.3 00:0a:b8:30:d5:8a > 01:80:c2:00:00:00 / LLC / STP / Raw / Padding
# Ether / IP / UDP / DNS Qry b'clientservices.googleapis.com.'
# Ether / IP / UDP / DNS Ans 172.217.26.67
# Ether / IP / UDP / DNS Qry b'wpad.mmu.edu.my.'
# Ether / IP / UDP 10.106.184.11:60954 > 172.217.26.67:https / Raw
# Ether / IP / UDP 10.106.184.11:60954 > 172.217.26.67:https / Raw
# Ether / IP / UDP 10.106.184.11:60954 > 172.217.26.67:https / Raw
# Ether / IP / UDP 10.106.184.11:60954 > 172.217.26.67:https / Raw
# Ether / IP / UDP 10.106.184.11:60954 > 172.217.26.67:https / Raw
# Ether / IP / UDP / DNS Ans name-error
# Ether / IP / UDP 172.217.26.67:https > 10.106.184.11:60954 / Raw
# Ether / IP / UDP 172.217.26.67:https > 10.106.184.11:60954 / Raw
# Ether / IP / UDP 172.217.26.67:https > 10.106.184.11:60954 / Raw
# Ether / IP / UDP 172.217.26.67:https > 10.106.184.11:60954 / Raw
# Ether / IP / UDP 172.217.26.67:https > 10.106.184.11:60954 / Raw
# Ether / IP / UDP 172.217.26.67:https > 10.106.184.11:60954 / Raw
# Ether / IP / UDP 10.106.184.11:60954 > 172.217.26.67:https / Raw
# Ether / IP / UDP 172.217.26.67:https > 10.106.184.11:60954 / Raw
# Ether / IP / UDP 10.106.184.11:60954 > 172.217.26.67:https / Raw
# Ether / IP / UDP 10.106.184.11:60954 > 172.217.26.67:https / Raw
# Ether / IP / UDP 172.217.26.67:https > 10.106.184.11:60954 / Raw
# Ether / IP / UDP 172.217.26.67:https > 10.106.184.11:60954 / Raw
# Ether / IP / UDP 172.217.26.67:https > 10.106.184.11:60954 / Raw
# Ether / IP / UDP 172.217.26.67:https > 10.106.184.11:60954 / Raw
# Ether / IP / UDP 10.106.184.11:60954 > 172.217.26.67:https / Raw
# Ether / IP / UDP 172.217.26.67:https > 10.106.184.11:60954 / Raw
# Ether / IP / UDP 10.106.184.11:60954 > 172.217.26.67:https / Raw
# Ether / IP / UDP 172.217.26.67:https > 10.106.184.11:60954 / Raw
# Ether / IP / UDP 10.106.184.11:60954 > 172.217.26.67:https / Raw
# Ether / IP / UDP 172.217.26.67:https > 10.106.184.11:60954 / Raw
# Ether / IP / UDP 10.106.184.11:60954 > 172.217.26.67:https / Raw
# Ether / IP / UDP 172.217.26.67:https > 10.106.184.11:60954 / Raw
# 802.3 00:0a:b8:30:d5:8a > 01:80:c2:00:00:00 / LLC / STP / Raw / Padding
# Ether / IP / TCP 10.106.184.11:65273 > 52.111.240.35:https A / Raw
# Ether / IP / TCP 52.111.240.35:https > 10.106.184.11:65273 A
# Ether / IP / TCP 10.106.184.237:58444 > 10.106.184.11:ms_do S
# Ether / IP / TCP 10.106.184.11:ms_do > 10.106.184.237:58444 SA
# Ether / IP / TCP 10.106.184.237:58444 > 10.106.184.11:ms_do A / Padding
# Ether / IP / TCP 10.106.184.237:58444 > 10.106.184.11:ms_do PA / Raw
# Ether / IP / TCP 10.106.184.11:ms_do > 10.106.184.237:58444 FA
# Ether / IP / TCP 10.106.184.237:58444 > 10.106.184.11:ms_do A / Padding
# Ether / IP / TCP 10.106.184.237:58444 > 10.106.184.11:ms_do FA / Padding
# Ether / IP / TCP 10.106.184.11:ms_do > 10.106.184.237:58444 A
# 802.3 00:0a:b8:30:d5:8a > 01:80:c2:00:00:00 / LLC / STP / Raw / Padding
# Ether / IP / TCP 10.106.184.11:65461 > 204.79.197.203:https RA
# Ether / ARP who has 169.254.169.254 says 10.106.184.237 / Padding
# Ether / ARP who has 169.254.169.254 says 10.106.184.237 / Padding
# 802.3 00:0a:b8:30:d5:8a > 01:80:c2:00:00:00 / LLC / STP / Raw / Padding
# Ether / ARP who has 169.254.169.254 says 10.106.184.237 / Padding
# 802.3 00:0a:b8:30:d5:8a > 01:80:c2:00:00:00 / LLC / STP / Raw / Padding
# 802.3 00:0a:b8:30:d5:8a > 01:80:c2:00:00:00 / LLC / STP / Raw / Padding
# 802.3 00:0a:b8:30:d5:8a > 01:80:c2:00:00:00 / LLC / STP / Raw / Padding
# Ether / IP / TCP 10.106.184.11:65253 > 20.212.88.117:https A / Raw
# Ether / IP / TCP 20.212.88.117:https > 10.106.184.11:65253 A
# Ether / IP / UDP 10.106.184.11:55538 > 203.106.94.155:https / Raw
# Ether / IP / UDP 10.106.184.11:55538 > 203.106.94.155:https / Raw
# Ether / IP / UDP 10.106.184.11:55538 > 203.106.94.155:https / Raw
# Ether / IP / UDP 203.106.94.155:https > 10.106.184.11:55538 / Raw
# Ether / IP / UDP 203.106.94.155:https > 10.106.184.11:55538 / Raw
# Ether / IP / UDP 203.106.94.155:https > 10.106.184.11:55538 / Raw
# Ether / IP / UDP 10.106.184.11:55538 > 203.106.94.155:https / Raw
# Ether / IP / UDP 203.106.94.155:https > 10.106.184.11:55538 / Raw
# Ether / IP / UDP 203.106.94.155:https > 10.106.184.11:55538 / Raw
# Ether / IP / UDP 203.106.94.155:https > 10.106.184.11:55538 / Raw
# Ether / IP / UDP 203.106.94.155:https > 10.106.184.11:55538 / Raw
# Ether / IP / UDP 203.106.94.155:https > 10.106.184.11:55538 / Raw
# Ether / IP / UDP 10.106.184.11:55538 > 203.106.94.155:https / Raw
# Ether / IP / UDP 10.106.184.11:55538 > 203.106.94.155:https / Raw
# Ether / IP / UDP 203.106.94.155:https > 10.106.184.11:55538 / Raw
# 802.3 00:0a:b8:30:d5:8a > 01:80:c2:00:00:00 / LLC / STP / Raw / Padding
# Ether / IP / TCP 10.106.184.11:65459 > 40.69.76.189:https FA
# 802.3 00:0a:b8:30:d5:8a > 01:80:c2:00:00:00 / LLC / STP / Raw / Padding
# Ether / IP / TCP 40.69.76.189:https > 10.106.184.11:65459 FA / Padding
# Ether / IP / TCP 10.106.184.11:65459 > 40.69.76.189:https A
# 802.3 00:0a:b8:30:d5:8a > 01:80:c2:00:00:00 / LLC / STP / Raw / Padding
# Ether / IP / TCP 10.106.184.235:57156 > 10.106.184.11:ms_do S
# Ether / IP / TCP 10.106.184.11:ms_do > 10.106.184.235:57156 SA
# Ether / IP / TCP 10.106.184.235:57156 > 10.106.184.11:ms_do A / Padding
# Ether / IP / TCP 10.106.184.235:57156 > 10.106.184.11:ms_do PA / Raw
# Ether / IP / TCP 10.106.184.11:ms_do > 10.106.184.235:57156 FA
# Ether / IP / TCP 10.106.184.235:57156 > 10.106.184.11:ms_do A / Padding
# Ether / IP / TCP 10.106.184.235:57156 > 10.106.184.11:ms_do FA / Padding
# Ether / IP / TCP 10.106.184.11:ms_do > 10.106.184.235:57156 A
# 802.3 00:0a:b8:30:d5:8a > 01:80:c2:00:00:00 / LLC / STP / Raw / Padding
# 802.3 00:0a:b8:30:d5:8a > 01:00:0c:cc:cc:cc / LLC / SNAP / Raw
# 802.3 00:0a:b8:30:d5:8a > 01:80:c2:00:00:00 / LLC / STP / Raw / Padding
# Ether / IP / TCP 10.106.184.11:65287 > 18.161.180.87:https A / Raw
# Ether / IP / TCP 18.161.180.87:https > 10.106.184.11:65287 A
# Ether / IP / UDP / DNS Qry b'catalog.gamepass.com.'
# Ether / IP / UDP / DNS Ans b'catalog.gamepass.com.edgesuite.net.'
# Ether / IP / TCP 10.106.184.11:65469 > 202.188.238.219:https S
# Ether / IP / TCP 202.188.238.219:https > 10.106.184.11:65469 SA
# Ether / IP / TCP 10.106.184.11:65469 > 202.188.238.219:https A
# Ether / IP / TCP 10.106.184.11:65469 > 202.188.238.219:https PA / Raw
# Ether / IP / TCP 202.188.238.219:https > 10.106.184.11:65469 A / Padding
# Ether / IP / TCP 202.188.238.219:https > 10.106.184.11:65469 A / Raw
# Ether / IP / TCP 202.188.238.219:https > 10.106.184.11:65469 PA / Raw
# Ether / IP / TCP 10.106.184.11:65469 > 202.188.238.219:https A
# Ether / IP / TCP 202.188.238.219:https > 10.106.184.11:65469 PA / Raw
# Ether / IP / TCP 10.106.184.11:65469 > 202.188.238.219:https PA / Raw
# Ether / IP / TCP 202.188.238.219:https > 10.106.184.11:65469 A / Padding
# Ether / IP / TCP 202.188.238.219:https > 10.106.184.11:65469 PA / Raw
# Ether / IP / TCP 10.106.184.11:65469 > 202.188.238.219:https PA / Raw
# Ether / IP / TCP 10.106.184.11:65469 > 202.188.238.219:https PA / Raw
# Ether / IP / TCP 202.188.238.219:https > 10.106.184.11:65469 A / Padding
# Ether / IP / TCP 202.188.238.219:https > 10.106.184.11:65469 PA / Raw
# Ether / IP / TCP 202.188.238.219:https > 10.106.184.11:65469 PA / Raw
# Ether / IP / TCP 202.188.238.219:https > 10.106.184.11:65469 PA / Raw
# Ether / IP / TCP 10.106.184.11:65469 > 202.188.238.219:https A
# Ether / IP / TCP 10.106.184.11:65469 > 202.188.238.219:https A
# Ether / IP / TCP 10.106.184.11:65469 > 202.188.238.219:https PA / Raw
# Ether / IP / TCP 202.188.238.219:https > 10.106.184.11:65469 PA / Raw
# Ether / IP / TCP 10.106.184.11:65469 > 202.188.238.219:https A
# Ether / IP / TCP 10.106.184.11:65469 > 202.188.238.219:https FA
# Ether / IP / TCP 202.188.238.219:https > 10.106.184.11:65469 PA / Raw
# Ether / IP / TCP 10.106.184.11:65469 > 202.188.238.219:https RA
# 802.3 00:0a:b8:30:d5:8a > 01:80:c2:00:00:00 / LLC / STP / Raw / Padding
# Ether / IP / UDP 10.106.184.11:62097 > 202.188.238.154:https / Raw
# Ether / IP / UDP 10.106.184.11:62097 > 202.188.238.154:https / Raw
# Ether / IP / UDP 202.188.238.154:https > 10.106.184.11:62097 / Raw
# Ether / IP / UDP 202.188.238.154:https > 10.106.184.11:62097 / Raw
# Ether / IP / UDP 202.188.238.154:https > 10.106.184.11:62097 / Raw
# Ether / IP / UDP 10.106.184.11:62097 > 202.188.238.154:https / Raw
# Ether / IP / UDP 10.106.184.11:62097 > 202.188.238.154:https / Raw
# Ether / IP / UDP 202.188.238.154:https > 10.106.184.11:62097 / Raw
# Ether / IP / UDP 202.188.238.154:https > 10.106.184.11:62097 / Raw
# Ether / IP / UDP 202.188.238.154:https > 10.106.184.11:62097 / Raw
# Ether / IP / UDP 202.188.238.154:https > 10.106.184.11:62097 / Raw
# Ether / IP / UDP 10.106.184.11:62097 > 202.188.238.154:https / Raw
# Ether / IP / UDP 202.188.238.154:https > 10.106.184.11:62097 / Raw
# Ether / IP / UDP 10.106.184.11:62097 > 202.188.238.154:https / Raw
# Ether / IP / UDP 202.188.238.154:https > 10.106.184.11:62097 / Raw
# Ether / IP / UDP 202.188.238.154:https > 10.106.184.11:62097 / Raw
# Ether / IP / UDP 202.188.238.154:https > 10.106.184.11:62097 / Raw
# Ether / IP / UDP 10.106.184.11:62097 > 202.188.238.154:https / Raw
# Ether / IP / UDP 10.106.184.11:62097 > 202.188.238.154:https / Raw
# Ether / IP / UDP 202.188.238.154:https > 10.106.184.11:62097 / Raw
# 802.3 00:0a:b8:30:d5:8a > 01:80:c2:00:00:00 / LLC / STP / Raw / Padding
# Ether / IP / TCP 13.107.21.239:https > 10.106.184.11:65274 RA / Padding
# 802.3 00:0a:b8:30:d5:8a > 01:80:c2:00:00:00 / LLC / STP / Raw / Padding
# Ether / IP / TCP 10.106.184.11:65465 > 40.99.10.82:https A / Raw
# Ether / IP / TCP 40.99.10.82:https > 10.106.184.11:65465 A
# Ether / IP / TCP 10.106.184.11:65470 > 10.106.184.235:ms_do S
# Ether / IP / TCP 10.106.184.11:65471 > 10.106.184.237:ms_do S
# Ether / IP / TCP 10.106.184.235:ms_do > 10.106.184.11:65470 SA
# Ether / IP / TCP 10.106.184.11:65470 > 10.106.184.235:ms_do A
# Ether / IP / TCP 10.106.184.11:65470 > 10.106.184.235:ms_do PA / Raw
# Ether / IP / TCP 10.106.184.235:ms_do > 10.106.184.11:65470 PA / Raw
# Ether / IP / TCP 10.106.184.11:65470 > 10.106.184.235:ms_do PA / Raw
# Ether / IP / TCP 10.106.184.235:ms_do > 10.106.184.11:65470 PA / Raw
# Ether / IP / TCP 10.106.184.237:ms_do > 10.106.184.11:65471 SA
# Ether / IP / TCP 10.106.184.11:65471 > 10.106.184.237:ms_do A
# Ether / IP / TCP 10.106.184.11:65471 > 10.106.184.237:ms_do PA / Raw
# Ether / IP / TCP 10.106.184.235:ms_do > 10.106.184.11:65470 FA / Padding
# Ether / IP / TCP 10.106.184.11:65470 > 10.106.184.235:ms_do A
# Ether / IP / TCP 10.106.184.11:65470 > 10.106.184.235:ms_do FA
# Ether / IP / TCP 10.106.184.235:ms_do > 10.106.184.11:65470 A / Padding
# Ether / IP / TCP 10.106.184.237:ms_do > 10.106.184.11:65471 A / Padding
# Ether / IP / TCP 10.106.184.237:ms_do > 10.106.184.11:65471 FA / Padding
# Ether / IP / TCP 10.106.184.11:65471 > 10.106.184.237:ms_do A
# Ether / IP / TCP 10.106.184.11:65471 > 10.106.184.237:ms_do FA
# Ether / IP / TCP 10.106.184.237:ms_do > 10.106.184.11:65471 A / Padding
# 802.3 00:0a:b8:30:d5:8a > 01:80:c2:00:00:00 / LLC / STP / Raw / Padding
# 802.3 00:0a:b8:30:d5:8a > 01:80:c2:00:00:00 / LLC / STP / Raw / Padding
# Ether / IP / UDP 203.106.94.155:https > 10.106.184.11:55538 / Raw
# Ether / IP / UDP 10.106.184.11:55538 > 203.106.94.155:https / Raw
# Ether / IP / UDP 203.106.94.155:https > 10.106.184.11:55538 / Raw
# Ether / IP / UDP 10.106.184.11:55538 > 203.106.94.155:https / Raw
# Ether / IP / TCP 10.106.184.11:65472 > 10.106.184.237:ms_do S
# Ether / IP / TCP 10.106.184.237:ms_do > 10.106.184.11:65472 SA
# Ether / IP / TCP 10.106.184.11:65472 > 10.106.184.237:ms_do A
# Ether / IP / TCP 10.106.184.11:65472 > 10.106.184.237:ms_do PA / Raw
# Ether / IP / TCP 10.106.184.237:ms_do > 10.106.184.11:65472 PA / Raw
# Ether / IP / TCP 10.106.184.11:65472 > 10.106.184.237:ms_do PA / Raw
# Ether / IP / TCP 10.106.184.237:ms_do > 10.106.184.11:65472 PA / Raw
# Ether / IP / TCP 10.106.184.237:ms_do > 10.106.184.11:65472 FA / Padding
# Ether / IP / TCP 10.106.184.11:65472 > 10.106.184.237:ms_do A
# Ether / IP / TCP 10.106.184.11:65472 > 10.106.184.237:ms_do FA
# Ether / IP / TCP 10.106.184.237:ms_do > 10.106.184.11:65472 A / Padding
# Ether / IP / UDP 203.106.94.155:https > 10.106.184.11:55538 / Raw
# Ether / IP / UDP 10.106.184.11:55538 > 203.106.94.155:https / Raw
# 802.3 00:0a:b8:30:d5:8a > 01:80:c2:00:00:00 / LLC / STP / Raw / Padding
# 802.3 00:0a:b8:30:d5:8a > 01:80:c2:00:00:00 / LLC / STP / Raw / Padding
# 802.3 00:0a:b8:30:d5:8a > 01:80:c2:00:00:00 / LLC / STP / Raw / Padding
# Ether / IP / TCP 10.106.184.11:65299 > 202.188.238.201:https A / Raw
# Ether / IP / TCP 202.188.238.201:https > 10.106.184.11:65299 A
# Ether / IP / TCP 52.111.240.35:https > 10.106.184.11:65273 RA / Padding
# 802.3 00:0a:b8:30:d5:8a > 01:80:c2:00:00:00 / LLC / STP / Raw / Padding
# 802.3 00:0a:b8:30:d5:8a > 01:80:c2:00:00:00 / LLC / STP / Raw / Padding
# Ether / IP / TCP 10.106.184.237:58455 > 10.106.184.11:ms_do S
# Ether / IP / TCP 10.106.184.11:ms_do > 10.106.184.237:58455 SA
# Ether / IP / TCP 10.106.184.237:58455 > 10.106.184.11:ms_do A / Padding
# Ether / IP / TCP 10.106.184.237:58455 > 10.106.184.11:ms_do PA / Raw
# Ether / IP / TCP 10.106.184.11:ms_do > 10.106.184.237:58455 FA
# Ether / IP / TCP 10.106.184.237:58455 > 10.106.184.11:ms_do A / Padding
# Ether / IP / TCP 10.106.184.237:58455 > 10.106.184.11:ms_do FA / Padding
# Ether / IP / TCP 10.106.184.11:ms_do > 10.106.184.237:58455 A
# Ether / IP / UDP 203.106.94.155:https > 10.106.184.11:55538 / Raw
# 802.3 00:0a:b8:30:d5:8a > 01:80:c2:00:00:00 / LLC / STP / Raw / Padding
# 802.3 00:0a:b8:30:d5:8a > 01:80:c2:00:00:00 / LLC / STP / Raw / Padding
# 802.3 00:0a:b8:30:d5:8a > 01:80:c2:00:00:00 / LLC / STP / Raw / Padding
# Ether / IP / TCP 40.69.76.189:https > 10.106.184.11:65457 RA / Padding
# 802.3 00:0a:b8:30:d5:8a > 01:80:c2:00:00:00 / LLC / STP / Raw / Padding
# 802.3 00:0a:b8:30:d5:8a > 01:80:c2:00:00:00 / LLC / STP / Raw / Padding
# 802.3 00:0a:b8:30:d5:8a > 01:80:c2:00:00:00 / LLC / STP / Raw / Padding
# <Sniffed: TCP:0 UDP:0 ICMP:0 Other:0>
