# %%
#LSTM-XGB-250
import pandas as pd
import xgboost as xgb
import scapy.all as scapy
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score, confusion_matrix
import pickle
from concurrent.futures import ThreadPoolExecutor
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers
# Global variables
initial_bandwidth = 0
initial_packet_rate = 0
initial_total_packets = 0
initial_total_time = 0
label = ""
source_ip = ""
destination_ip = ""
def calculate_total_packets_and_time(packets):
    total_packets = len(packets)
    total_time = packets[-1].time - packets[0].time
    return total_packets, total_time

def calculate_bandwidth_and_packet_rate(packets, total_length, total_time):
    bandwidth = total_length / total_time
    packet_rate = len(packets) / total_time
    return round(bandwidth, 2), round(packet_rate, 2)

def calculate_initial_features(pcap_file):
    packets = scapy.rdpcap(pcap_file)
    total_length = sum(len(packet) for packet in packets)

    with ThreadPoolExecutor() as executor:
        total_packets_and_time_future = executor.submit(calculate_total_packets_and_time, packets)
        total_packets, total_time = total_packets_and_time_future.result()

        bandwidth_and_packet_rate_future = executor.submit(calculate_bandwidth_and_packet_rate, packets, total_length, total_time)
        bandwidth, packet_rate = bandwidth_and_packet_rate_future.result()

    return packets, round(bandwidth, 2), round(packet_rate, 2), round(total_packets, 2), round(total_time, 2)

def load_pretrained_models():
    lstm_model = keras.models.load_model('Original-LSTM-XGB-Dataset-A-1-80-20-LSTM-Model.h5')
    with open('Original-LSTM-XGB-Dataset-A-1-80-20-XGB-model.pkl', 'rb') as f:
        xgb_model = pickle.load(f)
    with open('Original-LSTM-XGB-Dataset-A-1-80-20-scaler.pkl', 'rb') as f:
        scaler = pickle.load(f)
    with open('Original-LSTM-XGB-Dataset-A-1-80-20-label_encoder.pkl', 'rb') as f:
        label_encoder = pickle.load(f)
    with open('Original-LSTM-XGB-Dataset-A-1-80-20-class_names.pkl', 'rb') as f:
        class_names = pickle.load(f)
    return lstm_model, xgb_model, scaler, label_encoder, class_names
def predict_with_models(lstm_model, xgb_model, scaler, label_encoder, class_names, features):
    features_df = pd.DataFrame([features], columns=[
        'Protocol', 'Source Port', 'Destination Port', 'Total Fwd Pkt', 'Total Bwd Pkt', 'Total Fwd Len', 'Total Bwd Len', 
        'Min Fwd Len', 'Max Fwd Len', 'Mean Fwd Len', 'Std Fwd Len', 'Min Bwd Len', 'Max Bwd Len', 
        'Mean Bwd Len', 'Std Bwd Len', 'Flow Bytes/s', 'Flow Pkt/s', 'Flow Duration', 
        'Bandwidth', 'Packet Rate'
    ])
    features_scaled = scaler.transform(features_df)

    # Reshape features_scaled to 3D for LSTM input
    features_scaled_reshaped = features_scaled.reshape((features_scaled.shape[0], 1, features_scaled.shape[1]))

    # Get intermediate output from LSTM
    intermediate_output = lstm_model.predict(features_scaled_reshaped)

    # Print the shapes to debug
   # print("Features scaled shape:", features_scaled.shape)
   # print("Intermediate output shape:", intermediate_output.shape)

    # Predict with XGBoost
    xgb_predictions = xgb_model.predict(intermediate_output)
    
    # Map predicted class indices to class names
    predicted_class_name = class_names[xgb_predictions[0]]
    
    return predicted_class_name

def evaluate_model(y_true, y_pred):
    accuracy = accuracy_score(y_true, y_pred)
    precision = precision_score(y_true, y_pred, average='weighted', zero_division=0)
    recall = recall_score(y_true, y_pred, average='weighted', zero_division=0)
    f1 = f1_score(y_true, y_pred, average='weighted', zero_division=0)

    labels = sorted(set(y_true) | set(y_pred))
    cm = confusion_matrix(y_true, y_pred, labels=labels)

    tn, fp, fn, tp = cm.ravel() if cm.size == 4 else (0, 0, 0, 0)
    return accuracy, precision, recall, f1, tp, tn, fp, fn

def group_packets_by_flow(packets):
    flow_dict = {}
    
    for packet in packets:
        if scapy.IP in packet and scapy.TCP in packet:
            src_ip = packet[scapy.IP].src
            dst_ip = packet[scapy.IP].dst
            src_port = packet[scapy.TCP].sport
            dst_port = packet[scapy.TCP].dport
            proto = packet[scapy.IP].proto

            flow_key = (src_ip, dst_ip, src_port, dst_port, proto)
            
            if flow_key not in flow_dict:
                flow_dict[flow_key] = []
            flow_dict[flow_key].append(packet)
    
    return flow_dict
def calculate_features_for_flow(flow, initial_bandwidth, initial_packet_rate, initial_total_packets, initial_total_time):
    features = {}
    packets = flow

    if packets and scapy.IP in packets[0] and scapy.TCP in packets[0]:
        src_ip = packets[0][scapy.IP].src
        dst_ip = packets[0][scapy.IP].dst
        packet_len = len(packets[0])

    # Calculate other features if not a special packet
    total_len = sum(len(pkt) for pkt in packets)
    min_len = min(len(pkt) for pkt in packets)
    max_len = max(len(pkt) for pkt in packets)
    mean_len = total_len / len(packets)
    std_len = pd.Series([len(pkt) for pkt in packets]).std()
    
    first_time = packets[0].time
    last_time = packets[-1].time
    flow_duration = last_time - first_time

    # Ensure flow_duration is not zero to avoid DivisionByZero error
    if flow_duration == 0:
        flow_duration = 0.000012

    flow_bytes_s = total_len / flow_duration
    flow_pkt_s = len(packets) / flow_duration

    features = {
        'Protocol': packets[0][scapy.IP].proto,
        'Source Port': packets[0][scapy.TCP].sport,
        'Destination Port': packets[0][scapy.TCP].dport,
        'Total Fwd Pkt': len(packets) if src_ip == source_ip else 0,
        'Total Fwd Len': total_len if src_ip == source_ip else 0,
        'Min Fwd Len': min_len if src_ip == source_ip else 0,
        'Max Fwd Len': max_len if src_ip == source_ip else 0,
        'Mean Fwd Len': mean_len if src_ip == source_ip else 0,
        'Std Fwd Len': std_len if src_ip == source_ip else 0,
        'Total Bwd Pkt': len(packets) if src_ip != source_ip else 0,
        'Total Bwd Len': total_len if src_ip != source_ip else 0,
        'Min Bwd Len': min_len if src_ip != source_ip else 0,
        'Max Bwd Len': max_len if src_ip != source_ip else 0,
        'Mean Bwd Len': mean_len if src_ip != source_ip else 0,
        'Std Bwd Len': std_len if src_ip != source_ip else 0,
        'Flow Bytes/s': flow_bytes_s,
        'Flow Pkt/s': flow_pkt_s,
        'Flow Duration': flow_duration,
        'Bandwidth': initial_bandwidth,
        'Packet Rate': initial_packet_rate,
        'Total-Pkt': initial_total_packets,
        'T-Time': initial_total_time
    }

    return features, None  
def is_request(packet):
    return packet.haslayer(scapy.IP) and packet.haslayer(scapy.TCP)

def is_reply(packet):
    return packet.haslayer(scapy.IP) and packet.haslayer(scapy.TCP)

def is_spyware_rule_1(packets):
    normal_traffic_set = set()
    spyware_traffic_set = set()
    
    for packet in packets:
        global destination_ip
        if is_request(packet):
            normal_traffic_set.add((packet[scapy.IP].src, packet[scapy.IP].dst, 'RQ'))
        elif is_reply(packet):
            normal_traffic_set.add((packet[scapy.IP].dst, packet[scapy.IP].src, 'RP'))
        destination_ip = packet[scapy.IP].dst
    
    for packet in packets:
        if is_request(packet):
            spyware_traffic_set.add((packet[scapy.IP].src, packet[scapy.IP].dst, 'RQ'))
        elif is_reply(packet):
            spyware_traffic_set.add((packet[scapy.IP].dst, packet[scapy.IP].src, 'RP'))
    for flow in spyware_traffic_set:
        if flow not in normal_traffic_set:
            return True
    
    return False

def is_spyware_rule_2():
    global destination_ip
    unique_dest_ips = len(set(destination_ip))
    return unique_dest_ips > 3

def is_spyware_rule_3(total_fwd_len, total_bwd_len):
    return total_fwd_len > total_bwd_len

def main():
    pcap_file = 'Eyezy-100.pcap'
    csv_files = ['1-All-Together-Update-Single-26-8-24.csv', '2-All-Together-Update-Single-26-8-24.csv',
                 '3-All-Together-Update-Single-26-8-24.csv','4-All-Together-Update-Single-26-8-24.csv',
                 '5-All-Together-Update-Single-26-8-24.csv']
    
    lstm_model, xgb_model, scaler, label_encoder, class_names = load_pretrained_models()
    
    previous_samples = pd.concat([pd.read_csv(f) for f in csv_files], ignore_index=True)
    y_true = previous_samples['Label']
    y_true_encoded = label_encoder.transform(y_true)

    packets, initial_bandwidth, initial_packet_rate, initial_total_packets, initial_total_time = calculate_initial_features(pcap_file)
    
    

    packet_count = 0
    predictions = []
    true_labels = []
    captured_packets = []

    sniff_packets = scapy.sniff(offline=pcap_file)
    for packet in sniff_packets:
        captured_packets.append(packet)
        packet_count += 1

        if packet_count % 250 == 0:
            flow_dict = group_packets_by_flow(captured_packets)
            
            for flow_key, flow_packets in flow_dict.items():
                features, special_label = calculate_features_for_flow(flow_packets, initial_bandwidth, initial_packet_rate, initial_total_packets, initial_total_time)

                if special_label:
                    true_labels.append(special_label)
                    predicted_label = special_label
                else:
                    if is_spyware_rule_1(flow_packets) or is_spyware_rule_2() or is_spyware_rule_3(features['Total Fwd Len'], features['Total Bwd Len']):
                        label_row = previous_samples[previous_samples['Bandwidth'] == initial_bandwidth]
                        if not label_row.empty:
                            label = label_row['Label'].values[0]
                        else:
                            label = 'Unknown'
                    else:
                        label = 'Normal Traffic'
                    true_labels.append(label)
                    predicted_label = predict_with_models(lstm_model, xgb_model, scaler, label_encoder, class_names, features)
                
               
                predicted_label_encoded = label_encoder.transform([predicted_label])[0]
                predictions.append(predicted_label_encoded)
                true_labels_encoded = label_encoder.transform(true_labels)
                y_pred = predictions[-len(true_labels_encoded):]
                accuracy, precision, recall, f1, tp, tn, fp, fn = evaluate_model(true_labels_encoded[:len(y_pred)], y_pred)
                
                
                print(f"Predicted Label: {predicted_label}")
                print(f"Accuracy: {accuracy}")
                print(f"Precision: {precision}")
                print(f"Recall: {recall}")
                print(f"F1-Score: {f1}")
                
            
            captured_packets = []
            packet_count = 0

if __name__ == '__main__':
    main()
# Out:
# WARNING:absl:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 120ms/st ━━━━━━━━━━━━━━━━━━━━ 0s 123ms/step
# C:\Users\mimi\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\metrics\_classification.py:409: UserWarning: A single label was found in 'y_true' and 'y_pred'. For the confusion matrix to have the correct shape, use the 'labels' parameter to pass all known labels.
#   warnings.warn(
# Predicted Label: Eyezy
# Accuracy: 1.0
# Precision: 1.0
# Recall: 1.0
# F1-Score: 1.0
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/ste ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# C:\Users\mimi\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\metrics\_classification.py:409: UserWarning: A single label was found in 'y_true' and 'y_pred'. For the confusion matrix to have the correct shape, use the 'labels' parameter to pass all known labels.
#   warnings.warn(
# Predicted Label: Eyezy
# Accuracy: 1.0
# Precision: 1.0
# Recall: 1.0
# F1-Score: 1.0
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/ste ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# C:\Users\mimi\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\metrics\_classification.py:409: UserWarning: A single label was found in 'y_true' and 'y_pred'. For the confusion matrix to have the correct shape, use the 'labels' parameter to pass all known labels.
#   warnings.warn(
# Predicted Label: Eyezy
# Accuracy: 1.0
# Precision: 1.0
# Recall: 1.0
# F1-Score: 1.0
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/ste ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# C:\Users\mimi\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\metrics\_classification.py:409: UserWarning: A single label was found in 'y_true' and 'y_pred'. For the confusion matrix to have the correct shape, use the 'labels' parameter to pass all known labels.
#   warnings.warn(
# Predicted Label: Eyezy
# Accuracy: 1.0
# Precision: 1.0
# Recall: 1.0
# F1-Score: 1.0
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/ste ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# C:\Users\mimi\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\metrics\_classification.py:409: UserWarning: A single label was found in 'y_true' and 'y_pred'. For the confusion matrix to have the correct shape, use the 'labels' parameter to pass all known labels.
#   warnings.warn(
# Predicted Label: Eyezy
# Accuracy: 1.0
# Precision: 1.0
# Recall: 1.0
# F1-Score: 1.0
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/ste ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# C:\Users\mimi\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\metrics\_classification.py:409: UserWarning: A single label was found in 'y_true' and 'y_pred'. For the confusion matrix to have the correct shape, use the 'labels' parameter to pass all known labels.
#   warnings.warn(
# Predicted Label: Eyezy
# Accuracy: 1.0
# Precision: 1.0
# Recall: 1.0
# F1-Score: 1.0
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/ste ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# C:\Users\mimi\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\metrics\_classification.py:409: UserWarning: A single label was found in 'y_true' and 'y_pred'. For the confusion matrix to have the correct shape, use the 'labels' parameter to pass all known labels.
#   warnings.warn(
# Predicted Label: Eyezy
# Accuracy: 1.0
# Precision: 1.0
# Recall: 1.0
# F1-Score: 1.0
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/ste ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# C:\Users\mimi\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\metrics\_classification.py:409: UserWarning: A single label was found in 'y_true' and 'y_pred'. For the confusion matrix to have the correct shape, use the 'labels' parameter to pass all known labels.
#   warnings.warn(
# Predicted Label: Eyezy
# Accuracy: 1.0
# Precision: 1.0
# Recall: 1.0
# F1-Score: 1.0
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/ste ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# C:\Users\mimi\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\metrics\_classification.py:409: UserWarning: A single label was found in 'y_true' and 'y_pred'. For the confusion matrix to have the correct shape, use the 'labels' parameter to pass all known labels.
#   warnings.warn(
# Predicted Label: Eyezy
# Accuracy: 1.0
# Precision: 1.0
# Recall: 1.0
# F1-Score: 1.0
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/ste ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# C:\Users\mimi\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\metrics\_classification.py:409: UserWarning: A single label was found in 'y_true' and 'y_pred'. For the confusion matrix to have the correct shape, use the 'labels' parameter to pass all known labels.
#   warnings.warn(
# Predicted Label: Eyezy
# Accuracy: 1.0
# Precision: 1.0
# Recall: 1.0
# F1-Score: 1.0
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/ste ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# C:\Users\mimi\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\metrics\_classification.py:409: UserWarning: A single label was found in 'y_true' and 'y_pred'. For the confusion matrix to have the correct shape, use the 'labels' parameter to pass all known labels.
#   warnings.warn(
# Predicted Label: Eyezy
# Accuracy: 1.0
# Precision: 1.0
# Recall: 1.0
# F1-Score: 1.0
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/ste ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# C:\Users\mimi\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\metrics\_classification.py:409: UserWarning: A single label was found in 'y_true' and 'y_pred'. For the confusion matrix to have the correct shape, use the 'labels' parameter to pass all known labels.
#   warnings.warn(
# Predicted Label: Eyezy
# Accuracy: 1.0
# Precision: 1.0
# Recall: 1.0
# F1-Score: 1.0
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/ste ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# C:\Users\mimi\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\metrics\_classification.py:409: UserWarning: A single label was found in 'y_true' and 'y_pred'. For the confusion matrix to have the correct shape, use the 'labels' parameter to pass all known labels.
#   warnings.warn(
# Predicted Label: Eyezy
# Accuracy: 1.0
# Precision: 1.0
# Recall: 1.0
# F1-Score: 1.0
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/ste ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# C:\Users\mimi\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\metrics\_classification.py:409: UserWarning: A single label was found in 'y_true' and 'y_pred'. For the confusion matrix to have the correct shape, use the 'labels' parameter to pass all known labels.
#   warnings.warn(
# Predicted Label: Eyezy
# Accuracy: 1.0
# Precision: 1.0
# Recall: 1.0
# F1-Score: 1.0
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/ste ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# C:\Users\mimi\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\metrics\_classification.py:409: UserWarning: A single label was found in 'y_true' and 'y_pred'. For the confusion matrix to have the correct shape, use the 'labels' parameter to pass all known labels.
#   warnings.warn(
# Predicted Label: Eyezy
# Accuracy: 1.0
# Precision: 1.0
# Recall: 1.0
# F1-Score: 1.0
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/ste ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# C:\Users\mimi\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\metrics\_classification.py:409: UserWarning: A single label was found in 'y_true' and 'y_pred'. For the confusion matrix to have the correct shape, use the 'labels' parameter to pass all known labels.
#   warnings.warn(
# Predicted Label: Eyezy
# Accuracy: 1.0
# Precision: 1.0
# Recall: 1.0
# F1-Score: 1.0
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/ste ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# C:\Users\mimi\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\metrics\_classification.py:409: UserWarning: A single label was found in 'y_true' and 'y_pred'. For the confusion matrix to have the correct shape, use the 'labels' parameter to pass all known labels.
#   warnings.warn(
# Predicted Label: Eyezy
# Accuracy: 1.0
# Precision: 1.0
# Recall: 1.0
# F1-Score: 1.0
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/ste ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# C:\Users\mimi\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\metrics\_classification.py:409: UserWarning: A single label was found in 'y_true' and 'y_pred'. For the confusion matrix to have the correct shape, use the 'labels' parameter to pass all known labels.
#   warnings.warn(
# Predicted Label: Eyezy
# Accuracy: 1.0
# Precision: 1.0
# Recall: 1.0
# F1-Score: 1.0
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/ste ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# C:\Users\mimi\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\metrics\_classification.py:409: UserWarning: A single label was found in 'y_true' and 'y_pred'. For the confusion matrix to have the correct shape, use the 'labels' parameter to pass all known labels.
#   warnings.warn(
# Predicted Label: Eyezy
# Accuracy: 1.0
# Precision: 1.0
# Recall: 1.0
# F1-Score: 1.0
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/ste ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# C:\Users\mimi\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\metrics\_classification.py:409: UserWarning: A single label was found in 'y_true' and 'y_pred'. For the confusion matrix to have the correct shape, use the 'labels' parameter to pass all known labels.
#   warnings.warn(
# Predicted Label: Eyezy
# Accuracy: 1.0
# Precision: 1.0
# Recall: 1.0
# F1-Score: 1.0
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/ste ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# C:\Users\mimi\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\metrics\_classification.py:409: UserWarning: A single label was found in 'y_true' and 'y_pred'. For the confusion matrix to have the correct shape, use the 'labels' parameter to pass all known labels.
#   warnings.warn(
# Predicted Label: Eyezy
# Accuracy: 1.0
# Precision: 1.0
# Recall: 1.0
# F1-Score: 1.0
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/ste ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# C:\Users\mimi\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\metrics\_classification.py:409: UserWarning: A single label was found in 'y_true' and 'y_pred'. For the confusion matrix to have the correct shape, use the 'labels' parameter to pass all known labels.
#   warnings.warn(
# Predicted Label: Eyezy
# Accuracy: 1.0
# Precision: 1.0
# Recall: 1.0
# F1-Score: 1.0
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/ste ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# Predicted Label: mLite
# Accuracy: 0.9565217391304348
# Precision: 0.9580757391304349
# Recall: 0.9565217391304348
# F1-Score: 0.9572981084715032
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/ste ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# Predicted Label: Eyezy
# Accuracy: 0.9583333333333334
# Precision: 0.9598873333333334
# Recall: 0.9583333333333334
# F1-Score: 0.9591097038656079
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/ste ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# Predicted Label: Eyezy
# Accuracy: 0.96
# Precision: 0.961554
# Recall: 0.96
# F1-Score: 0.9607763716242167
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/ste ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# Predicted Label: Eyezy
# Accuracy: 0.9615384615384616
# Precision: 0.9630924615384616
# Recall: 0.9615384615384616
# F1-Score: 0.9623148341672677
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/ste ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# Predicted Label: KidsGuardPro
# Accuracy: 0.9259259259259259
# Precision: 0.927479925925926
# Recall: 0.9259259259259259
# F1-Score: 0.9267022744453024
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/ste ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# Predicted Label: Eyezy
# Accuracy: 0.9285714285714286
# Precision: 0.9301254285714287
# Recall: 0.9285714285714286
# F1-Score: 0.9293477789453235
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/ste ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# Predicted Label: Eyezy
# Accuracy: 0.9310344827586207
# Precision: 0.9325884827586207
# Recall: 0.9310344827586207
# F1-Score: 0.93181083484967
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/ste ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# Predicted Label: Eyezy
# Accuracy: 0.9333333333333333
# Precision: 0.9348873333333334
# Recall: 0.9333333333333333
# F1-Score: 0.9341096870188902
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/ste ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# Predicted Label: Eyezy
# Accuracy: 0.9354838709677419
# Precision: 0.9370378709677419
# Recall: 0.9354838709677419
# F1-Score: 0.936260226137846
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/ste ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# Predicted Label: mLite
# Accuracy: 0.90625
# Precision: 0.907804
# Recall: 0.90625
# F1-Score: 0.9070263343869588
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/ste ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# Predicted Label: Eyezy
# Accuracy: 0.9090909090909091
# Precision: 0.9106449090909091
# Recall: 0.9090909090909091
# F1-Score: 0.9098672455561323
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/ste ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# Predicted Label: Eyezy
# Accuracy: 0.9117647058823529
# Precision: 0.913318705882353
# Recall: 0.9117647058823529
# F1-Score: 0.9125410442917691
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/ste ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# Predicted Label: Eyezy
# Accuracy: 0.9142857142857143
# Precision: 0.9158397142857143
# Recall: 0.9142857142857143
# F1-Score: 0.9150620545178202
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/ste ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# Predicted Label: Eyezy
# Accuracy: 0.9166666666666666
# Precision: 0.9182206666666667
# Recall: 0.9166666666666666
# F1-Score: 0.917443008611004
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/ste ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# Predicted Label: Eyezy
# Accuracy: 0.918918918918919
# Precision: 0.920472918918919
# Recall: 0.918918918918919
# F1-Score: 0.9196952624747753
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/ste ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# Predicted Label: Eyezy
# Accuracy: 0.9210526315789473
# Precision: 0.9226066315789474
# Recall: 0.9210526315789473
# F1-Score: 0.9218289766542419
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/ste ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# Predicted Label: mLite
# Accuracy: 0.8974358974358975
# Precision: 0.8989898974358975
# Recall: 0.8974358974358975
# F1-Score: 0.8982122252912403
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/ste ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# Predicted Label: Eyezy
# Accuracy: 0.9
# Precision: 0.9015540000000001
# Recall: 0.9
# F1-Score: 0.9007763297686331
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/ste ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# Predicted Label: Eyezy
# Accuracy: 0.9024390243902439
# Precision: 0.903993024390244
# Recall: 0.9024390243902439
# F1-Score: 0.9032153559687549
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/ste ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# Predicted Label: Eyezy
# Accuracy: 0.9047619047619048
# Precision: 0.9063159047619048
# Recall: 0.9047619047619048
# F1-Score: 0.9055382380550446
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/ste ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# Predicted Label: mLite
# Accuracy: 0.8837209302325582
# Precision: 0.8852749302325582
# Recall: 0.8837209302325582
# F1-Score: 0.8844972476656697
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/ste ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# Predicted Label: Eyezy
# Accuracy: 0.8863636363636364
# Precision: 0.8879176363636364
# Recall: 0.8863636363636364
# F1-Score: 0.8871399558300488
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/ste ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# Predicted Label: Eyezy
# Accuracy: 0.8888888888888888
# Precision: 0.8904428888888889
# Recall: 0.8888888888888888
# F1-Score: 0.8896652102869468
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/ste ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# Predicted Label: Eyezy
# Accuracy: 0.8913043478260869
# Precision: 0.892858347826087
# Recall: 0.8913043478260869
# F1-Score: 0.8920806710615727
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/ste ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# Predicted Label: Eyezy
# Accuracy: 0.8936170212765957
# Precision: 0.8951710212765958
# Recall: 0.8936170212765957
# F1-Score: 0.8943933462620209
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/ste ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# Predicted Label: Eyezy
# Accuracy: 0.8958333333333334
# Precision: 0.8973873333333334
# Recall: 0.8958333333333334
# F1-Score: 0.8966096599873128
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/ste ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# Predicted Label: Eyezy
# Accuracy: 0.8979591836734694
# Precision: 0.8995131836734694
# Recall: 0.8979591836734694
# F1-Score: 0.8987355119201663
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/ste ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# Predicted Label: Eyezy
# Accuracy: 0.9
# Precision: 0.9015540000000001
# Recall: 0.9
# F1-Score: 0.9007763297686331
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/ste ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# Predicted Label: Eyezy
# Accuracy: 0.9019607843137255
# Precision: 0.9035147843137256
# Recall: 0.9019607843137255
# F1-Score: 0.9027371155381293
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/ste ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# Predicted Label: Eyezy
# Accuracy: 0.9038461538461539
# Precision: 0.9054001538461539
# Recall: 0.9038461538461539
# F1-Score: 0.9046224864643857
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/ste ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# Predicted Label: Eyezy
# Accuracy: 0.9056603773584906
# Precision: 0.9072143773584906
# Recall: 0.9056603773584906
# F1-Score: 0.906436711312479
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/ste ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# Predicted Label: mLite
# Accuracy: 0.8888888888888888
# Precision: 0.8904428888888889
# Recall: 0.8888888888888888
# F1-Score: 0.8896652102869468
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/ste ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# Predicted Label: Eyezy
# Accuracy: 0.8909090909090909
# Precision: 0.8924630909090909
# Recall: 0.8909090909090909
# F1-Score: 0.8916854138445879
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/ste ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# Predicted Label: Eyezy
# Accuracy: 0.8928571428571429
# Precision: 0.894411142857143
# Recall: 0.8928571428571429
# F1-Score: 0.8936334672685872
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/ste ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# Predicted Label: Eyezy
# Accuracy: 0.8947368421052632
# Precision: 0.8962908421052632
# Recall: 0.8947368421052632
# F1-Score: 0.8955131679347796
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/ste ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# Predicted Label: Eyezy
# Accuracy: 0.896551724137931
# Precision: 0.8981057241379311
# Recall: 0.896551724137931
# F1-Score: 0.8973280513309834
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/ste ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# Predicted Label: mLite
# Accuracy: 0.8813559322033898
# Precision: 0.8829099322033899
# Recall: 0.8813559322033898
# F1-Score: 0.88213224780654
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/ste ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# Predicted Label: Eyezy
# Accuracy: 0.8833333333333333
# Precision: 0.8848873333333334
# Recall: 0.8833333333333333
# F1-Score: 0.8841096504672054
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/ste ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# Predicted Label: Eyezy
# Accuracy: 0.8852459016393442
# Precision: 0.8867999016393443
# Recall: 0.8852459016393442
# F1-Score: 0.8860222202472506
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/ste ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# Predicted Label: Eyezy
# Accuracy: 0.8870967741935484
# Precision: 0.8886507741935484
# Recall: 0.8870967741935484
# F1-Score: 0.8878730942218931
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/ste ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# Predicted Label: Eyezy
# Accuracy: 0.8888888888888888
# Precision: 0.8904428888888889
# Recall: 0.8888888888888888
# F1-Score: 0.8896652102869468
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/ste ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# Predicted Label: Eyezy
# Accuracy: 0.890625
# Precision: 0.892179
# Recall: 0.890625
# F1-Score: 0.8914013227197157
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/ste ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# Predicted Label: Normal-Traffic
# Accuracy: 0.8769230769230769
# Precision: 0.878477076923077
# Recall: 0.8769230769230769
# F1-Score: 0.8776993890696565
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/ste ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# Predicted Label: Eyezy
# Accuracy: 0.8787878787878788
# Precision: 0.8803418787878788
# Recall: 0.8787878787878788
# F1-Score: 0.8795641923928048
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/ste ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# Predicted Label: Eyezy
# Accuracy: 0.8805970149253731
# Precision: 0.8821510149253732
# Recall: 0.8805970149253731
# F1-Score: 0.8813733299392155
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/ste ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# Predicted Label: Eyezy
# Accuracy: 0.8823529411764706
# Precision: 0.8839069411764706
# Recall: 0.8823529411764706
# F1-Score: 0.88312925755227
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/ste ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# Predicted Label: Eyezy
# Accuracy: 0.8840579710144928
# Precision: 0.8856119710144928
# Recall: 0.8840579710144928
# F1-Score: 0.8848342887075997
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/ste ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# Predicted Label: Normal-Traffic
# Accuracy: 0.8714285714285714
# Precision: 0.8729825714285715
# Recall: 0.8714285714285714
# F1-Score: 0.8722048792419818
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/ste ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# Predicted Label: Eyezy
# Accuracy: 0.8732394366197183
# Precision: 0.8747934366197183
# Recall: 0.8732394366197183
# F1-Score: 0.8740157458672625
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/ste ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# Predicted Label: Eyezy
# Accuracy: 0.875
# Precision: 0.876554
# Recall: 0.875
# F1-Score: 0.875776310636155
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/ste ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# Predicted Label: Eyezy
# Accuracy: 0.8767123287671232
# Precision: 0.8782663287671233
# Recall: 0.8767123287671232
# F1-Score: 0.8774886407484999
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/ste ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# Predicted Label: Eyezy
# Accuracy: 0.8783783783783784
# Precision: 0.8799323783783785
# Recall: 0.8783783783783784
# F1-Score: 0.8791546916635896
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/ste ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# Predicted Label: Eyezy
# Accuracy: 0.88
# Precision: 0.8815540000000001
# Recall: 0.88
# F1-Score: 0.8807763145495398
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/ste ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/ste ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# Predicted Label: Eyezy
# Accuracy: 0.8831168831168831
# Precision: 0.8846708831168831
# Recall: 0.8831168831168831
# F1-Score: 0.8838932000835331
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/ste ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# Predicted Label: mLite
# Accuracy: 0.8774193548387097
# Precision: 0.8789733548387098
# Recall: 0.8774193548387097
# F1-Score: 0.8781956673740025
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/ste ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# Predicted Label: Eyezy
# Accuracy: 0.8782051282051282
# Precision: 0.8797591282051282
# Recall: 0.8782051282051282
# F1-Score: 0.8789814413549858
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/ste ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# Predicted Label: Eyezy
# Accuracy: 0.8789808917197452
# Precision: 0.8805348917197453
# Recall: 0.8789808917197452
# F1-Score: 0.8797572054752618
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/ste ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# Predicted Label: Eyezy
# Accuracy: 0.879746835443038
# Precision: 0.881300835443038
# Recall: 0.879746835443038
# F1-Score: 0.8805231497955
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/ste ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# Predicted Label: Eyezy
# Accuracy: 0.8805031446540881
# Precision: 0.8820571446540881
# Recall: 0.8805031446540881
# F1-Score: 0.8812794595949686
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/ste ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# Predicted Label: Eyezy
# Accuracy: 0.88125
# Precision: 0.882804
# Recall: 0.88125
# F1-Score: 0.8820263155209535
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/ste ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# Predicted Label: Eyezy
# Accuracy: 0.8819875776397516
# Precision: 0.8835415776397516
# Recall: 0.8819875776397516
# F1-Score: 0.8827638937326088
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/ste ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# Predicted Label: Eyezy
# Accuracy: 0.8827160493827161
# Precision: 0.8842700493827161
# Recall: 0.8827160493827161
# F1-Score: 0.8834923660394793
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/ste ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# Predicted Label: Eyezy
# Accuracy: 0.8834355828220859
# Precision: 0.884989582822086
# Recall: 0.8834355828220859
# F1-Score: 0.8842119000349239
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/ste ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# Predicted Label: Eyezy
# Accuracy: 0.8841463414634146
# Precision: 0.8857003414634147
# Recall: 0.8841463414634146
# F1-Score: 0.8849226592246583
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/ste ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# Predicted Label: Eyezy
# Accuracy: 0.8848484848484849
# Precision: 0.8864024848484849
# Recall: 0.8848484848484849
# F1-Score: 0.8856248031506224
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/ste ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# Predicted Label: Eyezy
# Accuracy: 0.8855421686746988
# Precision: 0.8870961686746989
# Recall: 0.8855421686746988
# F1-Score: 0.8863184875103719
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/ste ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# Predicted Label: Eyezy
# Accuracy: 0.8862275449101796
# Precision: 0.8877815449101797
# Recall: 0.8862275449101796
# F1-Score: 0.887003864272179
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/ste ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# Predicted Label: Eyezy
# Accuracy: 0.8869047619047619
# Precision: 0.8884587619047619
# Recall: 0.8869047619047619
# F1-Score: 0.8876810817860235
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/ste ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# Predicted Label: Normal-Traffic
# Accuracy: 0.8816568047337278
# Precision: 0.8832108047337278
# Recall: 0.8816568047337278
# F1-Score: 0.8824331205702282
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/ste ━━━━━━━━━━━━━━━━━━━━ 0s 85ms/step
# Predicted Label: Eyezy
# Accuracy: 0.8823529411764706
# Precision: 0.8839069411764706
# Recall: 0.8823529411764706
# F1-Score: 0.88312925755227
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/ste ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# Predicted Label: Eyezy
# Accuracy: 0.8830409356725146
# Precision: 0.8845949356725147
# Recall: 0.8830409356725146
# F1-Score: 0.883817252580471
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/ste ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# Predicted Label: Eyezy
# Accuracy: 0.8837209302325582
# Precision: 0.8852749302325582
# Recall: 0.8837209302325582
# F1-Score: 0.8844972476656697
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/ste ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# Predicted Label: Eyezy
# Accuracy: 0.884393063583815
# Precision: 0.885947063583815
# Recall: 0.884393063583815
# F1-Score: 0.885169381535218
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/ste ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# Predicted Label: Eyezy
# Accuracy: 0.8850574712643678
# Precision: 0.8866114712643679
# Recall: 0.8850574712643678
# F1-Score: 0.8858337897273318
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/ste ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# Predicted Label: Eyezy
# Accuracy: 0.8857142857142857
# Precision: 0.8872682857142857
# Recall: 0.8857142857142857
# F1-Score: 0.8864906046822105
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/ste ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# Predicted Label: Eyezy
# Accuracy: 0.8863636363636364
# Precision: 0.8879176363636364
# Recall: 0.8863636363636364
# F1-Score: 0.8871399558300488
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/ste ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# Predicted Label: Normal-Traffic
# Accuracy: 0.8813559322033898
# Precision: 0.8829099322033899
# Recall: 0.8813559322033898
# F1-Score: 0.88213224780654
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/ste ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# Predicted Label: Eyezy
# Accuracy: 0.8820224719101124
# Precision: 0.8835764719101125
# Recall: 0.8820224719101124
# F1-Score: 0.8827987880300024
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/ste ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# Predicted Label: Eyezy
# Accuracy: 0.88268156424581
# Precision: 0.8842355642458101
# Recall: 0.88268156424581
# F1-Score: 0.8834578808758995
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/ste ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# Predicted Label: Eyezy
# Accuracy: 0.8833333333333333
# Precision: 0.8848873333333334
# Recall: 0.8833333333333333
# F1-Score: 0.8841096504672054
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/ste ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# Predicted Label: Eyezy
# Accuracy: 0.8839779005524862
# Precision: 0.8855319005524862
# Recall: 0.8839779005524862
# F1-Score: 0.8847542181838443
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/ste ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# Predicted Label: Eyezy
# Accuracy: 0.8846153846153846
# Precision: 0.8861693846153846
# Recall: 0.8846153846153846
# F1-Score: 0.8853917027380492
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/ste ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# Predicted Label: Eyezy
# Accuracy: 0.8852459016393442
# Precision: 0.8867999016393443
# Recall: 0.8852459016393442
# F1-Score: 0.8860222202472506
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/ste ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# Predicted Label: Eyezy
# Accuracy: 0.8858695652173914
# Precision: 0.8874235652173914
# Recall: 0.8858695652173914
# F1-Score: 0.8866458843045861
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/ste ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# Predicted Label: Eyezy
# Accuracy: 0.8864864864864865
# Precision: 0.8880404864864866
# Recall: 0.8864864864864865
# F1-Score: 0.8872628060471253
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/ste ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# Predicted Label: mLite
# Accuracy: 0.8817204301075269
# Precision: 0.8832744301075269
# Recall: 0.8817204301075269
# F1-Score: 0.8824967459933534
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/ste ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# Predicted Label: KidsGuardPro
# Accuracy: 0.8770053475935828
# Precision: 0.8785593475935829
# Recall: 0.8770053475935828
# F1-Score: 0.8777816598046319
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/ste ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# Predicted Label: Eyezy
# Accuracy: 0.8776595744680851
# Precision: 0.8792135744680851
# Recall: 0.8776595744680851
# F1-Score: 0.8784358871913738
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/ste ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# Predicted Label: Eyezy
# Accuracy: 0.8783068783068783
# Precision: 0.8798608783068783
# Recall: 0.8783068783068783
# F1-Score: 0.8790831915362357
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/ste ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# Predicted Label: Eyezy
# Accuracy: 0.8789473684210526
# Precision: 0.8805013684210526
# Recall: 0.8789473684210526
# F1-Score: 0.8797236821504186
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/ste ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# Predicted Label: Eyezy
# Accuracy: 0.8795811518324608
# Precision: 0.8811351518324608
# Recall: 0.8795811518324608
# F1-Score: 0.8803574660558836
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/ste ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# Predicted Label: Eyezy
# Accuracy: 0.8802083333333334
# Precision: 0.8817623333333334
# Recall: 0.8802083333333334
# F1-Score: 0.8809846480449668
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/ste ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# Predicted Label: Eyezy
# Accuracy: 0.8808290155440415
# Precision: 0.8823830155440415
# Recall: 0.8808290155440415
# F1-Score: 0.8816053307381425
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/ste ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# Predicted Label: Eyezy
# Accuracy: 0.8814432989690721
# Precision: 0.8829972989690722
# Recall: 0.8814432989690721
# F1-Score: 0.8822196146399984
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/ste ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# Predicted Label: Eyezy
# Accuracy: 0.882051282051282
# Precision: 0.8836052820512821
# Recall: 0.882051282051282
# F1-Score: 0.8828275981934898
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/ste ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# Predicted Label: Eyezy
# Accuracy: 0.8826530612244898
# Precision: 0.8842070612244899
# Recall: 0.8826530612244898
# F1-Score: 0.8834293778325311
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/ste ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# Predicted Label: Eyezy
# Accuracy: 0.883248730964467
# Precision: 0.884802730964467
# Recall: 0.883248730964467
# F1-Score: 0.884025048032988
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/ste ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# Predicted Label: Eyezy
# Accuracy: 0.8838383838383839
# Precision: 0.8853923838383839
# Recall: 0.8838383838383839
# F1-Score: 0.8846147013621225
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/ste ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# Predicted Label: Normal-Traffic
# Accuracy: 0.8793969849246231
# Precision: 0.8809509849246232
# Recall: 0.8793969849246231
# F1-Score: 0.8801732990045548
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/ste ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# Predicted Label: Eyezy
# Accuracy: 0.88
# Precision: 0.8815540000000001
# Recall: 0.88
# F1-Score: 0.8807763145495398
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/ste ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# Predicted Label: Eyezy
# Accuracy: 0.8805970149253731
# Precision: 0.8821510149253732
# Recall: 0.8805970149253731
# F1-Score: 0.8813733299392155
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/ste ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# Predicted Label: Eyezy
# Accuracy: 0.8811881188118812
# Precision: 0.8827421188118812
# Recall: 0.8811881188118812
# F1-Score: 0.8819644342848096
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/ste ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# Predicted Label: Eyezy
# Accuracy: 0.8817733990147784
# Precision: 0.8833273990147784
# Recall: 0.8817733990147784
# F1-Score: 0.882549714941664
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/ste ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# Predicted Label: Eyezy
# Accuracy: 0.8823529411764706
# Precision: 0.8839069411764706
# Recall: 0.8823529411764706
# F1-Score: 0.88312925755227
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/ste ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# Predicted Label: mLite
# Accuracy: 0.8780487804878049
# Precision: 0.8796027804878049
# Recall: 0.8780487804878049
# F1-Score: 0.8788250935154682
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/ste ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# Predicted Label: Eyezy
# Accuracy: 0.8786407766990292
# Precision: 0.8801947766990292
# Recall: 0.8786407766990292
# F1-Score: 0.8794170901891405
# ...
# Predicted Label: Eyezy
# Accuracy: 0.8558648111332008
# Precision: 0.8574188111332008
# Recall: 0.8558648111332008
# F1-Score: 0.8566411063707293
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/ste ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# Predicted Label: Eyezy
# Accuracy: 0.8559364133134625
# Precision: 0.8574904133134625
# Recall: 0.8559364133134625
# F1-Score: 0.8567127086098936
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/ste ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# Predicted Label: Eyezy
# Accuracy: 0.8560079443892751
# Precision: 0.8575619443892751
# Recall: 0.8560079443892751
# F1-Score: 0.8567842397445402
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/ste ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# Predicted Label: Eyezy
# Accuracy: 0.8560794044665012
# Precision: 0.8576334044665013
# Recall: 0.8560794044665012
# F1-Score: 0.8568556998805322
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/ste ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# Predicted Label: Eyezy
# Accuracy: 0.8561507936507936
# Precision: 0.8577047936507937
# Recall: 0.8561507936507936
# F1-Score: 0.8569270891235226
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/ste ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# Predicted Label: Eyezy
# Accuracy: 0.8562221120475955
# Precision: 0.8577761120475955
# Recall: 0.8562221120475955
# F1-Score: 0.8569984075789543
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/ste ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# Predicted Label: Eyezy
# Accuracy: 0.8562933597621407
# Precision: 0.8578473597621408
# Recall: 0.8562933597621407
# F1-Score: 0.8570696553520616
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/ste ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# Predicted Label: Eyezy
# Accuracy: 0.8563645368994551
# Precision: 0.8579185368994552
# Recall: 0.8563645368994551
# F1-Score: 0.8571408325478702
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/ste ━━━━━━━━━━━━━━━━━━━━ 0s 188ms/step
# Predicted Label: mLite
# Accuracy: 0.8559405940594059
# Precision: 0.857494594059406
# Recall: 0.8559405940594059
# F1-Score: 0.8567168893592758
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/ste ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# Predicted Label: Eyezy
# Accuracy: 0.8560118753092528
# Precision: 0.8575658753092529
# Recall: 0.8560118753092528
# F1-Score: 0.8567881706677508
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/ste ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# Predicted Label: Eyezy
# Accuracy: 0.8560830860534124
# Precision: 0.8576370860534125
# Recall: 0.8560830860534124
# F1-Score: 0.8568593814704708
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/ste ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# Predicted Label: Eyezy
# Accuracy: 0.8561542263964409
# Precision: 0.857708226396441
# Recall: 0.8561542263964409
# F1-Score: 0.8569305218719921
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/ste ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# Predicted Label: Eyezy
# Accuracy: 0.8562252964426877
# Precision: 0.8577792964426878
# Recall: 0.8562252964426877
# F1-Score: 0.8570015919766641
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/ste ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# Predicted Label: Eyezy
# Accuracy: 0.8562962962962963
# Precision: 0.8578502962962964
# Recall: 0.8562962962962963
# F1-Score: 0.8570725918886307
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/ste ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# Predicted Label: Eyezy
# Accuracy: 0.8563672260612043
# Precision: 0.8579212260612044
# Recall: 0.8563672260612043
# F1-Score: 0.8571435217118293
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/ste ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# Predicted Label: Eyezy
# Accuracy: 0.8564380858411446
# Precision: 0.8579920858411446
# Recall: 0.8564380858411446
# F1-Score: 0.857214381549993
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/ste ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# Predicted Label: Eyezy
# Accuracy: 0.856508875739645
# Precision: 0.858062875739645
# Recall: 0.856508875739645
# F1-Score: 0.8572851715066497
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/ste ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# Predicted Label: Eyezy
# Accuracy: 0.8565795958600295
# Precision: 0.8581335958600296
# Recall: 0.8565795958600295
# F1-Score: 0.8573558916851239
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/ste ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# Predicted Label: Eyezy
# Accuracy: 0.8566502463054187
# Precision: 0.8582042463054188
# Recall: 0.8566502463054187
# F1-Score: 0.8574265421885359
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/ste ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# Predicted Label: Eyezy
# Accuracy: 0.8567208271787297
# Precision: 0.8582748271787297
# Recall: 0.8567208271787297
# F1-Score: 0.8574971231198029
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/ste ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# Predicted Label: Eyezy
# Accuracy: 0.8567913385826772
# Precision: 0.8583453385826773
# Recall: 0.8567913385826772
# F1-Score: 0.8575676345816398
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/ste ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# Predicted Label: Eyezy
# Accuracy: 0.8568617806197737
# Precision: 0.8584157806197737
# Recall: 0.8568617806197737
# F1-Score: 0.8576380766765593
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/ste ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step
# Predicted Label: Eyezy
# Accuracy: 0.8569321533923304
# Precision: 0.8584861533923305
# Recall: 0.8569321533923304
# F1-Score: 0.8577084495068727
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/ste ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# Predicted Label: Eyezy
# Accuracy: 0.857002457002457
# Precision: 0.8585564570024571
# Recall: 0.857002457002457
# F1-Score: 0.8577787531746899
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/ste ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# Predicted Label: Eyezy
# Accuracy: 0.8570726915520629
# Precision: 0.858626691552063
# Recall: 0.8570726915520629
# F1-Score: 0.85784898778192
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/ste ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# Predicted Label: Eyezy
# Accuracy: 0.8571428571428571
# Precision: 0.8586968571428572
# Recall: 0.8571428571428571
# F1-Score: 0.8579191534302726
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/ste ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# Predicted Label: Normal-Traffic
# Accuracy: 0.8567222767419038
# Precision: 0.8582762767419039
# Recall: 0.8567222767419038
# F1-Score: 0.8574985726841672
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/ste ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# Predicted Label: Eyezy
# Accuracy: 0.8567925453653752
# Precision: 0.8583465453653752
# Recall: 0.8567925453653752
# F1-Score: 0.8575688413653285
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/ste ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# Predicted Label: Eyezy
# Accuracy: 0.8568627450980392
# Precision: 0.8584167450980392
# Recall: 0.8568627450980392
# F1-Score: 0.8576390411556164
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/ste ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# Predicted Label: Eyezy
# Accuracy: 0.8569328760411563
# Precision: 0.8584868760411564
# Recall: 0.8569328760411563
# F1-Score: 0.8577091721562917
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/ste ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# Predicted Label: Eyezy
# Accuracy: 0.8570029382957884
# Precision: 0.8585569382957885
# Recall: 0.8570029382957884
# F1-Score: 0.8577792344684161
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/ste ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# Predicted Label: Eyezy
# Accuracy: 0.8570729319627998
# Precision: 0.8586269319627998
# Recall: 0.8570729319627998
# F1-Score: 0.8578492281928541
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/ste ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# Predicted Label: Eyezy
# Accuracy: 0.8571428571428571
# Precision: 0.8586968571428572
# Recall: 0.8571428571428571
# F1-Score: 0.8579191534302726
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/ste ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# Predicted Label: Eyezy
# Accuracy: 0.8572127139364303
# Precision: 0.8587667139364303
# Recall: 0.8572127139364303
# F1-Score: 0.8579890102811415
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/ste ━━━━━━━━━━━━━━━━━━━━ 0s 102ms/step
# Predicted Label: Eyezy
# Accuracy: 0.8572825024437928
# Precision: 0.8588365024437928
# Recall: 0.8572825024437928
# F1-Score: 0.8580587988457343
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/ste ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# Predicted Label: Eyezy
# Accuracy: 0.857352222765022
# Precision: 0.858906222765022
# Recall: 0.857352222765022
# F1-Score: 0.8581285192241287
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/ste ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# Predicted Label: Normal-Traffic
# Accuracy: 0.85693359375
# Precision: 0.85848759375
# Recall: 0.85693359375
# F1-Score: 0.8577098898657244
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/ste ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# Predicted Label: Eyezy
# Accuracy: 0.8570034163006345
# Precision: 0.8585574163006345
# Recall: 0.8570034163006345
# F1-Score: 0.8577797124736544
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/ste ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# Predicted Label: Eyezy
# Accuracy: 0.8570731707317073
# Precision: 0.8586271707317074
# Recall: 0.8570731707317073
# F1-Score: 0.8578494669619575
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/ste ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# Predicted Label: Eyezy
# Accuracy: 0.8571428571428571
# Precision: 0.8586968571428572
# Recall: 0.8571428571428571
# F1-Score: 0.8579191534302726
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/ste ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# Predicted Label: Eyezy
# Accuracy: 0.8572124756335283
# Precision: 0.8587664756335284
# Recall: 0.8572124756335283
# F1-Score: 0.857988771978044
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/ste ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# Predicted Label: Eyezy
# Accuracy: 0.8572820263029712
# Precision: 0.8588360263029713
# Recall: 0.8572820263029712
# F1-Score: 0.8580583227045223
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/ste ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# Predicted Label: Normal-Traffic
# Accuracy: 0.8568646543330087
# Precision: 0.8584186543330088
# Recall: 0.8568646543330087
# F1-Score: 0.857640950392153
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/ste ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# Predicted Label: Eyezy
# Accuracy: 0.8569343065693431
# Precision: 0.8584883065693432
# Recall: 0.8569343065693431
# F1-Score: 0.8577106026856525
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/ste ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# Predicted Label: mLite
# Accuracy: 0.8565175097276264
# Precision: 0.8580715097276265
# Recall: 0.8565175097276264
# F1-Score: 0.8572938055017238
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/ste ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# Predicted Label: Eyezy
# Accuracy: 0.8565872630043753
# Precision: 0.8581412630043753
# Recall: 0.8565872630043753
# F1-Score: 0.8573635588357669
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/ste ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# Predicted Label: Eyezy
# Accuracy: 0.8566569484936832
# Precision: 0.8582109484936833
# Recall: 0.8566569484936832
# F1-Score: 0.8574332443823042
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/ste ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# Predicted Label: Eyezy
# Accuracy: 0.8567265662943176
# Precision: 0.8582805662943177
# Recall: 0.8567265662943176
# F1-Score: 0.857502862240103
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/ste ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# Predicted Label: Eyezy
# Accuracy: 0.8567961165048543
# Precision: 0.8583501165048544
# Recall: 0.8567961165048543
# F1-Score: 0.8575724125077393
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/ste ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# Predicted Label: Eyezy
# Accuracy: 0.8568655992236778
# Precision: 0.8584195992236778
# Recall: 0.8568655992236778
# F1-Score: 0.8576418952835978
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/ste ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# Predicted Label: Eyezy
# Accuracy: 0.8569350145489816
# Precision: 0.8584890145489816
# Recall: 0.8569350145489816
# F1-Score: 0.8577113106658719
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/ste ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# Predicted Label: Eyezy
# Accuracy: 0.8570043625787688
# Precision: 0.8585583625787688
# Recall: 0.8570043625787688
# F1-Score: 0.8577806587525652
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/ste ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# Predicted Label: Eyezy
# Accuracy: 0.8570736434108527
# Precision: 0.8586276434108527
# Recall: 0.8570736434108527
# F1-Score: 0.8578499396414907
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/ste ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# Predicted Label: Normal-Traffic
# Accuracy: 0.8566585956416465
# Precision: 0.8582125956416465
# Recall: 0.8566585956416465
# F1-Score: 0.8574348915316199
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/ste ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# Predicted Label: Eyezy
# Accuracy: 0.856727976766699
# Precision: 0.858281976766699
# Recall: 0.856727976766699
# F1-Score: 0.8575042727136423
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/ste ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# Predicted Label: Eyezy
# Accuracy: 0.8567972907595549
# Precision: 0.858351290759555
# Recall: 0.8567972907595549
# F1-Score: 0.8575735867634038
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/ste ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# Predicted Label: Eyezy
# Accuracy: 0.8568665377176016
# Precision: 0.8584205377176016
# Recall: 0.8568665377176016
# F1-Score: 0.8576428337782918
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/ste ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# Predicted Label: Eyezy
# Accuracy: 0.8569357177380377
# Precision: 0.8584897177380377
# Recall: 0.8569357177380377
# F1-Score: 0.8577120138555051
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/ste ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# Predicted Label: Eyezy
# Accuracy: 0.8570048309178744
# Precision: 0.8585588309178744
# Recall: 0.8570048309178744
# F1-Score: 0.857781127092055
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/ste ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# Predicted Label: Eyezy
# Accuracy: 0.8570738773539353
# Precision: 0.8586278773539353
# Recall: 0.8570738773539353
# F1-Score: 0.8578501735847652
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/ste ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# Predicted Label: Eyezy
# Accuracy: 0.8571428571428571
# Precision: 0.8586968571428572
# Recall: 0.8571428571428571
# F1-Score: 0.8579191534302726
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/ste ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# Predicted Label: Eyezy
# Accuracy: 0.8572117703810902
# Precision: 0.8587657703810903
# Recall: 0.8572117703810902
# F1-Score: 0.8579880667250276
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/ste ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# Predicted Label: Eyezy
# Accuracy: 0.8572806171648988
# Precision: 0.8588346171648988
# Recall: 0.8572806171648988
# F1-Score: 0.8580569135652943
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/ste ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# Predicted Label: mLite
# Accuracy: 0.8568674698795181
# Precision: 0.8584214698795182
# Recall: 0.8568674698795181
# F1-Score: 0.8576437659409735
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/ste ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# Predicted Label: Eyezy
# Accuracy: 0.8569364161849711
# Precision: 0.8584904161849711
# Recall: 0.8569364161849711
# F1-Score: 0.8577127123030117
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/ste ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# Predicted Label: Eyezy
# Accuracy: 0.8570052961001444
# Precision: 0.8585592961001445
# Recall: 0.8570052961001444
# F1-Score: 0.8577815922747068
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/ste ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# Predicted Label: Eyezy
# Accuracy: 0.8570741097208855
# Precision: 0.8586281097208855
# Recall: 0.8570741097208855
# F1-Score: 0.8578504059519061
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/ste ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# Predicted Label: Eyezy
# Accuracy: 0.8571428571428571
# Precision: 0.8586968571428572
# Recall: 0.8571428571428571
# F1-Score: 0.8579191534302726
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/ste ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# Predicted Label: mLite
# Accuracy: 0.8567307692307692
# Precision: 0.8582847692307692
# Recall: 0.8567307692307692
# F1-Score: 0.8575070651800053
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/ste ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# Predicted Label: Eyezy
# Accuracy: 0.8567996155694377
# Precision: 0.8583536155694378
# Recall: 0.8567996155694377
# F1-Score: 0.8575759115751952
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/ste ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# Predicted Label: Eyezy
# Accuracy: 0.8568683957732949
# Precision: 0.8584223957732949
# Recall: 0.8568683957732949
# F1-Score: 0.8576446918355102
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/ste ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# Predicted Label: Eyezy
# Accuracy: 0.85693710993759
# Precision: 0.85849110993759
# Recall: 0.85693710993759
# F1-Score: 0.8577134060562
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/ste ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# Predicted Label: Eyezy
# Accuracy: 0.8570057581573897
# Precision: 0.8585597581573897
# Recall: 0.8570057581573897
# F1-Score: 0.8577820543323311
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/ste ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# Predicted Label: Eyezy
# Accuracy: 0.8570743405275779
# Precision: 0.858628340527578
# Recall: 0.8570743405275779
# F1-Score: 0.8578506367587879
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/ste ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# Predicted Label: Eyezy
# Accuracy: 0.8571428571428571
# Precision: 0.8586968571428572
# Recall: 0.8571428571428571
# F1-Score: 0.8579191534302726
# 1/1 ━━━━━━━━━━━━━━━━━━━━
# IOPub message rate exceeded.
# The Jupyter server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--ServerApp.iopub_msg_rate_limit`.
#
# Current values:
# ServerApp.iopub_msg_rate_limit=1000.0 (msgs/sec)
# ServerApp.rate_limit_window=3.0 (secs)
